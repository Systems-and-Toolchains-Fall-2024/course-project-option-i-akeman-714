# %% [markdown]
# <div align="center">
#
# # **Course Project**
#
# ## Option 1
#
# **Daren Yao & Jinsong Yuan**
#
# </div>

# %% [markdown]
# ## **TASK I**

# %%
# Uncomment the following lines if you are using Windows!
import findspark
findspark.init()
findspark.find()
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SQLContext

# Create Configuration object for Spark.
conf = pyspark.SparkConf()\
 .set('spark.driver.host','127.0.0.1')\
 .setAppName('SPARK-POSTGRES')\
 .setMaster("local[*]")\
 .set("spark.jars", "C:\spark\spark-3.5.2-bin-hadoop3\postgresql-42.7.4.jar")

# need to change the postgresql path 

# Create Spark Context with the new configurations rather than relying on the default 
sc = SparkContext.getOrCreate(conf=conf)
# You need to create SQL Context to conduct some database operations like what we will
sqlContext = SQLContext(sc)
# If you have SQL context, you create the session from the Spark Context
spark = sqlContext.sparkSession.builder.getOrCreate()

# %%
from pyspark.sql.functions import col, when, isnull, count, lit, avg, sum, isnan, desc, row_number, expr, regexp_extract, concat
from pyspark.sql.functions import *
from pyspark.sql import Row
from pyspark.sql.types import StringType, IntegerType, FloatType, DoubleType

# %%
# change the username, password, table name.
db_properties={}
db_properties['username']="postgres"  
# db_properties['password']='714179'
db_properties['password']="YYAAOOdaren200@"
db_properties['url']= "jdbc:postgresql://localhost:5432/postgres"
# db_properties['table']=Your Table name and Schema
db_properties['table']="fifa.fifa_uncleaned"   
db_properties['driver']="org.postgresql.Driver"

# %% [markdown]
# ### **A. Reading the data**

# %%
df_list=[]
for i in range(15,23,1):
    df_list.append(spark.read.csv(r"./data/players_{}.csv".format(i),header=True, inferSchema= True))

# %%
df_list_female=[]
for i in range(16,23,1):
    df_list_female.append(spark.read.csv(r"./data/female_players_{}.csv".format(i),header=True, inferSchema= True))

# %% [markdown]
# ### **B. Add new column**

# %%
for i in range(15,23,1):
    df_list[i-15]=df_list[i-15].withColumn('year',lit(2000+i))
    df_list[i-15]=df_list[i-15].withColumn('gender',lit(1))

# %%
for i in range(16,23,1):
    df_list_female[i-16]=df_list_female[i-16].withColumn('year',lit(2000+i))
    df_list_female[i-16]=df_list_female[i-16].withColumn('gender',lit(0))

# %% [markdown]
# ### **C. Merge the data**

# %%
# union function needs to be used when two df have the same structure
def union_df(df_list,df_list_female):
    df_union=df_list[0]
    for i in range(15,22,1):
        df_union=df_union.union(df_list[i-14])
    for i in range(16,23,1):
        df_union=df_union.union(df_list_female[i-16])
    return df_union

# %%
# check if the dfs have the same structure
len(df_list[0].columns)
# Out:
# 112

# %%
len(df_list_female[0].columns)
# Out:
# 112

# %%
df_union=union_df(df_list,df_list_female)

# %%
# Create a unique identifier unique_id, combining sofifa_id and year
df_union = df_union.withColumn('unique_id', concat(col('sofifa_id'), lit('_'), col('year')))

# checking the result
df_union.select('sofifa_id', 'year', 'unique_id').show(5)
# Out:
# +---------+----+-----------+
# |sofifa_id|year|  unique_id|
# +---------+----+-----------+
# |   158023|2015|158023_2015|
# |    20801|2015| 20801_2015|
# |     9014|2015|  9014_2015|
# |    41236|2015| 41236_2015|
# |   167495|2015|167495_2015|
# +---------+----+-----------+
# only showing top 5 rows

# %%
# Check whether the UID is unique or not
df_union.select('unique_id').distinct().count()
# Out:
# 144323

# %%
df_union.summary().show()
# Out:
# +-------+-----------------+--------------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+--------------------+-----------+-------------------------+-----------------+----------------+-----------------+---------------+--------------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+-----------+-------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-------------------+-----------+
# |summary|        sofifa_id|          player_url|short_name|           long_name|player_positions|          overall|        potential|         value_eur|          wage_eur|              age|         height_cm|        weight_kg|      club_team_id|           club_name|         league_name|      league_level|club_position|club_jersey_number|    club_loaned_from|club_joined|club_contract_valid_until|   nationality_id|nationality_name|   nation_team_id|nation_position|nation_jersey_number|preferred_foot|         weak_foot|       skill_moves|international_reputation|    work_rate|  body_type|real_face|  release_clause_eur|player_tags|player_traits|              pace|          shooting|           passing|         dribbling|         defending|           physic|attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing| attacking_volleys|   skill_dribbling|       skill_curve| skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|  movement_agility|movement_reactions| movement_balance| power_shot_power|     power_jumping|     power_stamina|    power_strength|  power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|  mentality_vision|mentality_penalties|mentality_composure|defending_marking_awareness|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes| goalkeeping_speed|                ls|                st|                rs|                lw|                lf|                cf|                rf|                rw|              lam|              cam|              ram|                lm|               lcm|                cm|               rcm|                rm|               lwb|               ldm|               cdm|               rdm|               rwb|                lb|              lcb|               cb|              rcb|                rb|                gk|     player_face_url|       club_logo_url|       club_flag_url|     nation_logo_url|     nation_flag_url|              year|             gender|  unique_id|
# +-------+-----------------+--------------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+--------------------+-----------+-------------------------+-----------------+----------------+-----------------+---------------+--------------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+-----------+-------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-------------------+-----------+
# |  count|           144323|              144323|    144323|              144323|          144323|           144323|           144323|            140228|            140503|           144323|            144323|           144323|            140449|              140449|              140449|            140064|       140449|            140449|                8305|     132144|                   140449|           144323|          144323|            10688|          10688|               10688|        144323|            144323|            144323|                  144323|       144323|     144323|   144323|               86543|      11690|        64138|            128249|            128249|            128249|            128249|            128249|           128249|            144323|             144323|                    144323|                 144323|            144323|            144323|            144323|            144323|            144323|            144323|               144323|               144323|            144323|            144323|           144323|           144323|            144323|            144323|            144323|            144323|              144323|                 144323|               144323|            144323|             144323|             112297|                     144323|                   144323|                  144323|            144323|              144323|             144323|                 144323|              144323|             16074|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|           144323|           144323|           144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|           144323|           144323|           144323|            144323|            144323|              144323|              140449|              140449|               10688|              144323|            144323|             144323|     144323|
# |   mean|211967.0790864935|                NULL|      NULL|                NULL|            NULL|65.87099076377292|70.86494183186325|2269630.0881421682|11110.377358490567|25.13769808000111|181.01369844030404|75.03270441994692|44486.178762397736|                NULL|                NULL|1.3785840758510395|         NULL| 19.99129933285392|                NULL|       NULL|       2019.9270838525017|55.69959050186041|            NULL|48179.61910553892|           NULL|  12.115269461077844|          NULL| 2.941007323849975|2.3306818732980883|      1.1229395176098058|         NULL|       NULL|     NULL|   4686886.264631455|       NULL|         NULL|  68.0648192188633| 52.31459114690953| 57.01834712161499| 62.14579450911898| 51.16110067135026|64.88116866408315|49.820915585180465|  45.66066392744053|         52.42257990756844|     58.416780416149884| 43.17719975333107| 55.25433229630759|47.343181613464246|43.166127367086325| 52.61782252309057| 58.32273442209488|    64.77217075587397|    64.95886310567269| 63.40764119371133|61.800648545276914|  64.035836283891|56.66906175730826| 65.00749707253868| 63.22737193655897| 65.18889574080362| 47.32516646688331|  55.767382884224965|      46.67863750060628|    50.05596474574392| 53.03182444932547|   48.8759934314004|  57.93766529827155|          45.75312320281591|        47.69115802748003|       45.72127796678284|16.578265418540358|  16.326905621418625| 16.187385240051828|     16.334215613588963|  16.690513639544633| 39.51748164738086| 54.84716442753537| 54.84716442753537| 54.84716442753537|55.218112826062196| 54.97691415149071| 54.97691415149071| 54.97691415149071|55.218112826062196|55.77282390633889|55.77282390633889|55.77282390633889| 56.40396178616122|  54.7294420861128|  54.7294420861128|  54.7294420861128| 56.40396178616122| 54.07243479330709|53.645390070921984|53.645390070921984|53.645390070921984| 54.07243479330709| 52.94140736285651|53.36732524142819|53.36732524142819|53.36732524142819| 52.94140736285651| 19.99489958559133|                NULL|                NULL|                NULL|                NULL|                NULL|2018.6535687312487| 0.9844515427201486|       NULL|
# | stddev|34700.15102127671|                NULL|      NULL|                NULL|            NULL|7.165768763091288| 6.35522435346123| 5779837.296903276| 22248.69179859546| 4.65159121161672| 6.900499819409998|7.184165890463856|53281.055198273956|                NULL|                NULL|0.7484169613886598|         NULL|16.662096242167355|                NULL|       NULL|        2.460571780952665|47.98865708256204|            NULL|54621.36165198883|           NULL|   6.751646316974512|          NULL|0.6622066105582111|0.7536315978884554|     0.41930061107308275|         NULL|       NULL|     NULL|1.1694195806430833E7|       NULL|         NULL|11.118310904120671|14.023970247872565|10.608972968441796|10.448122381208908|16.774698128733267|9.734473429337786| 18.10704605345718| 19.298064746746665|        17.185308220855013|       14.8193931219371|17.498429194520174|18.652808824738113|18.166695007976294|17.324565424168973|15.375967421332938| 16.64721654130104|   14.681117268180554|   14.413999503125499|14.666365224814959| 9.305932299344303|13.98519506514301|15.84037525344252|11.828016250955278|15.782610102712095|12.625285536233548|19.059216849577524|   17.30337226754678|      20.44735158060637|   19.221942651926604|14.453258499129781| 15.711526044712821| 12.474358418291247|          20.54938167453722|       21.439923679212455|      21.048260468990538| 17.75232106189288|  16.906811174245064|  16.53055312969889|     17.071150843263972|  18.059600871737356|10.427285191610823|12.774082648574025|12.774082648574025|12.774082648574025|14.361492110696576|14.098162229234507|14.098162229234507|14.098162229234507|14.361492110696576| 13.4726796824318| 13.4726796824318| 13.4726796824318|13.056764871105674|12.621811718015781|12.621811718015781|12.621811718015781|13.056764871105674|12.546059113362725| 12.64349106228192| 12.64349106228192| 12.64349106228192|12.546059113362725|12.943888137207304| 13.9921558573347| 13.9921558573347| 13.9921558573347|12.943888137207304|15.558149522830847|                NULL|                NULL|                NULL|                NULL|                NULL| 2.274309403445543|0.12372068871233469|       NULL|
# |    min|                2|https://sofifa.co...|     A Lan|A. Benjamin Chiam...|             CAM|               40|               40|           1.005E8|            1000.0|               16|               150|               45|               1.0|1. FC Heidenheim ...|Argentina Primera...|                 1|          CAM|                 1|1. FC Heidenheim ...| 1991-06-01|                     2014|                1|     Afghanistan|            974.0|            CAM|                   1|          Left|                 1|                 1|                       1|    High/High|Lean (170-)|       No|              100000|   #Acrobat|  1-on-1 Rush|                21|                14|                20|                22|                14|               27|                 5|                  2|                         4|                      7|                 3|                 2|                 4|                 3|                 5|                 5|                   11|                   11|                11|                20|               10|                2|                13|                10|                12|                 3|                   2|                      3|                    2|                 5|                  5|                 11|                          1|                        2|                       3|                 1|                   1|                  1|                      1|                   1|                12|              14+1|              14+1|              14+1|                13|                14|                14|                14|                13|             14+2|             14+2|             14+2|              15+1|              15+1|              15+1|              15+1|              15+1|              14+1|              15+1|              15+1|              15+1|              14+1|              14+1|             15+2|             15+2|             15+2|              14+1|                10|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|              2015|                  0|100143_2015|
# |    25%|           197527|                NULL|      NULL|                NULL|            NULL|               61|               66|          300000.0|            2000.0|               21|               176|               70|             449.0|                NULL|                NULL|               1.0|         NULL|               8.0|                NULL|       NULL|                   2018.0|               21|            NULL|           1355.0|           NULL|                   6|          NULL|                 3|                 2|                       1|         NULL|       NULL|     NULL|            578000.0|       NULL|         NULL|                62|                42|                50|                56|                36|               59|                38|                 30|                        45|                     53|                30|                48|                34|                31|                43|                54|                   57|                   57|                55|                55|               56|               47|                58|                56|                58|                32|                  44|                     26|                   38|                43|                 39|               50.0|                         25|                       26|                      25|                 8|                   8|                  8|                      8|                   8|                32|              48.0|              48.0|              48.0|              49.0|              48.0|              48.0|              48.0|              49.0|             49.0|             49.0|             49.0|              50.0|              49.0|              49.0|              49.0|              50.0|              48.0|              46.0|              46.0|              46.0|              48.0|              45.0|             42.0|             42.0|             42.0|              45.0|              13.0|                NULL|                NULL|                NULL|                NULL|                NULL|              2017|                  1|       NULL|
# |    50%|           217544|                NULL|      NULL|                NULL|            NULL|               66|               71|          700000.0|            4000.0|               25|               181|               75|            1887.0|                NULL|                NULL|               1.0|         NULL|              17.0|                NULL|       NULL|                   2020.0|               45|            NULL|           1387.0|           NULL|                  12|          NULL|                 3|                 2|                       1|         NULL|       NULL|     NULL|           1300000.0|       NULL|         NULL|                69|                54|                58|                63|                56|               66|                54|                 49|                        55|                     62|                44|                61|                48|                42|                56|                63|                   67|                   67|                65|                62|               66|               59|                66|                66|                66|                51|                  58|                     52|                   55|                55|                 50|               59.0|                         50|                       54|                      52|                11|                  11|                 11|                     11|                  11|                41|              57.0|              57.0|              57.0|              59.0|              58.0|              58.0|              58.0|              59.0|             58.0|             58.0|             58.0|              59.0|              57.0|              57.0|              57.0|              59.0|              56.0|              55.0|              55.0|              55.0|              56.0|              55.0|             56.0|             56.0|             56.0|              55.0|              15.0|                NULL|                NULL|                NULL|                NULL|                NULL|              2019|                  1|       NULL|
# |    75%|           234492|                NULL|      NULL|                NULL|            NULL|               71|               75|         1800000.0|           10000.0|               28|               186|               80|          110781.0|                NULL|                NULL|               2.0|         NULL|              26.0|                NULL|       NULL|                   2022.0|               56|            NULL|         111466.0|           NULL|                  18|          NULL|                 3|                 3|                       1|         NULL|       NULL|     NULL|           3600000.0|       NULL|         NULL|                76|                63|                64|                69|                65|               72|                64|                 62|                        64|                     68|                57|                68|                62|                57|                64|                69|                   75|                   75|                74|                68|               74|               68|                73|                74|                74|                62|                  69|                     64|                   64|                64|                 61|               67.0|                         63|                       66|                      64|                14|                  14|                 14|                     14|                  14|                47|              64.0|              64.0|              64.0|              65.0|              65.0|              65.0|              65.0|              65.0|             65.0|             65.0|             65.0|              66.0|              63.0|              63.0|              63.0|              66.0|              63.0|              63.0|              63.0|              63.0|              63.0|              63.0|             65.0|             65.0|             65.0|              63.0|              17.0|                NULL|                NULL|                NULL|                NULL|                NULL|              2021|                  1|       NULL|
# |    max|           264640|https://sofifa.co...|Ș. Vlădoiu|              李相旭|     ST, RWB, RM|               94|               95|          975000.0|           95000.0|               54|               208|              110|             983.0|       Śląsk Wrocław|Venezuelan Primer...|                 5|          SUB|                99|       Śląsk Wrocław| 2021-09-15|                     2031|              219|        Zimbabwe|         115682.0|            SUB|                  51|         Right|                 5|                 5|                       5|Medium/Medium|     Unique|      Yes|            99900000|#Tactician | Through Ball|                97|                94|                93|                96|                91|               92|                94|                 95|                        95|                     95|                93|                97|                94|                95|                95|                96|                   97|                   97|                96|                96|               98|               96|                97|                97|                98|                94|                  96|                     93|                   96|                96|                 96|                 96|                         94|                       94|                      95|                91|                  92|                 95|                     92|                  94|                68|              92+2|              92+2|              92+2|              93+1|              93+1|              93+1|              93+1|              93+1|               94|               94|               94|              92+2|              89+2|              89+2|              89+2|              92+2|              88-1|              89+2|              89+2|              89+2|              88-1|              88+3|             90+2|             90+2|             90+2|              88+3|              90+2|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|https://cdn.sofif...|              2022|                  1|  9833_2019|
# +-------+-----------------+--------------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+--------------------+-----------+-------------------------+-----------------+----------------+-----------------+---------------+--------------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+-----------+-------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-------------------+-----------+

# %%
df_union.groupBy('year').count().show()
# Out:
# +----+-----+
# |year|count|
# +----+-----+
# |2015|16155|
# |2016|15871|
# |2017|17895|
# |2018|18271|
# |2019|18384|
# |2020|18828|
# |2021|19289|
# |2022|19630|
# +----+-----+

# %%
# saving the data count for each year
# number_of_data[0] --> row(2015,16155)
number_of_data=df_union.groupBy('year').count().collect()
number_of_data[0][1]
# Out:
# 16155

# %%
df_union.groupBy('gender').count().show()
# Out:
# +------+------+
# |gender| count|
# +------+------+
# |     1|142079|
# |     0|  2244|
# +------+------+

# %%
df_union.groupBy('gender').agg(count('club_team_id').alias('club_team_id_count')).show()
# Out:
# +------+------------------+
# |gender|club_team_id_count|
# +------+------------------+
# |     1|            140449|
# |     0|                 0|
# +------+------------------+

# %%
df_union.select('club_team_id').distinct().count()
# Out:
# 1017

# %%
#overwrite it to PostgresSQL database
df_union.write.format("jdbc")\
.mode("overwrite")\
.option("url", db_properties['url'])\
.option("dbtable", db_properties['table'])\
.option("user", db_properties['username'])\
.option("password", db_properties['password'])\
.option("Driver", db_properties['driver'])\
.save()

# %% [markdown]
# ### **D. Data Cleaning**

# %% [markdown]
# #### D.1 Dropping columns with high nullValue ratio

# %%
# read back the df
df_uncleaned  = sqlContext.read.format("jdbc")\
 .option("url", db_properties['url'])\
 .option("dbtable", db_properties['table'])\
 .option("user", db_properties['username'])\
 .option("password", db_properties['password'])\
 .option("Driver", db_properties['driver'])\
 .load()

# %%
missing_values = ['NA', 'NULL', 'NAN', 'NaN', 'na', 'null', 'nan', '']
def replace_missing_values(df, missing_values):
    for c in df.columns:
        df = df.withColumn(c, when(col(c).isin(missing_values), None).otherwise(col(c)))
    return df
# Transferring all the nullValues into None
df_null_transferred = replace_missing_values(df_uncleaned, missing_values)

# %%
# Function to calculate the null ratio

def show_null_ratio(df):
    total_count = df.count()
    columns = df.columns
    null_count_expr = [
        count(when(col(c).isNull() , c)).alias(f'{c}_null_count') for c in columns
    ]
    
    null_counts_df = df.agg(*null_count_expr)
    
    # Calculate the percentage of null values in each column
    for c in columns:
        null_counts_df = null_counts_df.withColumn(c, col(f'{c}_null_count') / total_count)
        null_counts_df=null_counts_df.drop(f'{c}_null_count')
    
    null_counts_df.show(vertical=True)
    # return the null_ratio df for further use
    return null_counts_df

# %%
df_uncleaned.printSchema
# Out:
# <bound method DataFrame.printSchema of DataFrame[sofifa_id: int, player_url: string, short_name: string, long_name: string, player_positions: string, overall: int, potential: int, value_eur: string, wage_eur: string, age: int, dob: date, height_cm: int, weight_kg: int, club_team_id: string, club_name: string, league_name: string, league_level: string, club_position: string, club_jersey_number: string, club_loaned_from: string, club_joined: string, club_contract_valid_until: string, nationality_id: int, nationality_name: string, nation_team_id: double, nation_position: string, nation_jersey_number: int, preferred_foot: string, weak_foot: int, skill_moves: int, international_reputation: int, work_rate: string, body_type: string, real_face: string, release_clause_eur: string, player_tags: string, player_traits: string, pace: int, shooting: int, passing: int, dribbling: int, defending: int, physic: int, attacking_crossing: int, attacking_finishing: int, attacking_heading_accuracy: int, attacking_short_passing: int, attacking_volleys: int, skill_dribbling: int, skill_curve: int, skill_fk_accuracy: int, skill_long_passing: int, skill_ball_control: int, movement_acceleration: int, movement_sprint_speed: int, movement_agility: int, movement_reactions: int, movement_balance: int, power_shot_power: int, power_jumping: int, power_stamina: int, power_strength: int, power_long_shots: int, mentality_aggression: int, mentality_interceptions: int, mentality_positioning: int, mentality_vision: int, mentality_penalties: int, mentality_composure: string, defending_marking_awareness: int, defending_standing_tackle: int, defending_sliding_tackle: int, goalkeeping_diving: int, goalkeeping_handling: int, goalkeeping_kicking: int, goalkeeping_positioning: int, goalkeeping_reflexes: int, goalkeeping_speed: int, ls: string, st: string, rs: string, lw: string, lf: string, cf: string, rf: string, rw: string, lam: string, cam: string, ram: string, lm: string, lcm: string, cm: string, rcm: string, rm: string, lwb: string, ldm: string, cdm: string, rdm: string, rwb: string, lb: string, lcb: string, cb: string, rcb: string, rb: string, gk: string, player_face_url: string, club_logo_url: string, club_flag_url: string, nation_logo_url: string, nation_flag_url: string, year: int, gender: int, unique_id: string]>

# %%
# A table showing the null ratio of each columns vertically
null_ratio_df=show_null_ratio(df_null_transferred)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 0.0
#  player_url                  | 0.0
#  short_name                  | 0.0
#  long_name                   | 0.0
#  player_positions            | 0.0
#  overall                     | 0.0
#  potential                   | 0.0
#  value_eur                   | 0.028373855864969547
#  wage_eur                    | 0.026468407668909323
#  age                         | 0.0
#  dob                         | 0.0
#  height_cm                   | 0.0
#  weight_kg                   | 0.0
#  club_team_id                | 0.02684256840559024
#  club_name                   | 0.02684256840559024
#  league_name                 | 0.02684256840559024
#  league_level                | 0.029510195880074554
#  club_position               | 0.02684256840559024
#  club_jersey_number          | 0.02684256840559024
#  club_loaned_from            | 0.9424554644789812
#  club_joined                 | 0.08438710392660906
#  club_contract_valid_until   | 0.02684256840559024
#  nationality_id              | 0.0
#  nationality_name            | 0.0
#  nation_team_id              | 0.9259438897473029
#  nation_position             | 0.9259438897473029
#  nation_jersey_number        | 0.9259438897473029
#  preferred_foot              | 0.0
#  weak_foot                   | 0.0
#  skill_moves                 | 0.0
#  international_reputation    | 0.0
#  work_rate                   | 0.0
#  body_type                   | 0.0
#  real_face                   | 0.0
#  release_clause_eur          | 0.4003519882485813
#  player_tags                 | 0.9190011294111126
#  player_traits               | 0.5555940494585062
#  pace                        | 0.111375179285353
#  shooting                    | 0.111375179285353
#  passing                     | 0.111375179285353
#  dribbling                   | 0.111375179285353
#  defending                   | 0.111375179285353
#  physic                      | 0.111375179285353
#  attacking_crossing          | 0.0
#  attacking_finishing         | 0.0
#  attacking_heading_accuracy  | 0.0
#  attacking_short_passing     | 0.0
#  attacking_volleys           | 0.0
#  skill_dribbling             | 0.0
#  skill_curve                 | 0.0
#  skill_fk_accuracy           | 0.0
#  skill_long_passing          | 0.0
#  skill_ball_control          | 0.0
#  movement_acceleration       | 0.0
#  movement_sprint_speed       | 0.0
#  movement_agility            | 0.0
#  movement_reactions          | 0.0
#  movement_balance            | 0.0
#  power_shot_power            | 0.0
#  power_jumping               | 0.0
#  power_stamina               | 0.0
#  power_strength              | 0.0
#  power_long_shots            | 0.0
#  mentality_aggression        | 0.0
#  mentality_interceptions     | 0.0
#  mentality_positioning       | 0.0
#  mentality_vision            | 0.0
#  mentality_penalties         | 0.0
#  mentality_composure         | 0.22190503246190835
#  defending_marking_awareness | 0.0
#  defending_standing_tackle   | 0.0
#  defending_sliding_tackle    | 0.0
#  goalkeeping_diving          | 0.0
#  goalkeeping_handling        | 0.0
#  goalkeeping_kicking         | 0.0
#  goalkeeping_positioning     | 0.0
#  goalkeeping_reflexes        | 0.0
#  goalkeeping_speed           | 0.888624820714647
#  ls                          | 0.0
#  st                          | 0.0
#  rs                          | 0.0
#  lw                          | 0.0
#  lf                          | 0.0
#  cf                          | 0.0
#  rf                          | 0.0
#  rw                          | 0.0
#  lam                         | 0.0
#  cam                         | 0.0
#  ram                         | 0.0
#  lm                          | 0.0
#  lcm                         | 0.0
#  cm                          | 0.0
#  rcm                         | 0.0
#  rm                          | 0.0
#  lwb                         | 0.0
#  ldm                         | 0.0
#  cdm                         | 0.0
#  rdm                         | 0.0
#  rwb                         | 0.0
#  lb                          | 0.0
#  lcb                         | 0.0
#  cb                          | 0.0
#  rcb                         | 0.0
#  rb                          | 0.0
#  gk                          | 0.0
#  player_face_url             | 0.0
#  club_logo_url               | 0.02684256840559024
#  club_flag_url               | 0.02684256840559024
#  nation_logo_url             | 0.9259438897473029
#  nation_flag_url             | 0.0
#  year                        | 0.0
#  gender                      | 0.0
#  unique_id                   | 0.0

# %%
#getting a list of ratios
ratio_row = null_ratio_df.collect()[0]
col_toomuchnull = [null_ratio_df.columns[i] for i in range(len(ratio_row)) if ratio_row[i] > 0.5]
print(col_toomuchnull)
# now we know the columns with nullValue ratio over 50%.
# Out:
# ['club_loaned_from', 'nation_team_id', 'nation_position', 'nation_jersey_number', 'player_tags', 'player_traits', 'goalkeeping_speed', 'nation_logo_url']

# %%
# dropping the columns with high nullValue ratio
df_afterdrop=df_null_transferred
for c in col_toomuchnull:
    df_afterdrop=df_afterdrop.drop(c)

# %% [markdown]
# Besides, all of the url colums are useless

# %%
columns_to_drop = [col_name for col_name in df_afterdrop.columns if 'url' in col_name]

# drop the columns that contain url
df_afterdrop = df_afterdrop.drop(*columns_to_drop)

# %% [markdown]
# #### D.2 Checking the dtypes

# %%
# Getting a list of the rest null cols
col_ratio = show_null_ratio(df_afterdrop).collect()[0]
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 0.0
#  short_name                  | 0.0
#  long_name                   | 0.0
#  player_positions            | 0.0
#  overall                     | 0.0
#  potential                   | 0.0
#  value_eur                   | 0.028373855864969547
#  wage_eur                    | 0.026468407668909323
#  age                         | 0.0
#  dob                         | 0.0
#  height_cm                   | 0.0
#  weight_kg                   | 0.0
#  club_team_id                | 0.02684256840559024
#  club_name                   | 0.02684256840559024
#  league_name                 | 0.02684256840559024
#  league_level                | 0.029510195880074554
#  club_position               | 0.02684256840559024
#  club_jersey_number          | 0.02684256840559024
#  club_joined                 | 0.08438710392660906
#  club_contract_valid_until   | 0.02684256840559024
#  nationality_id              | 0.0
#  nationality_name            | 0.0
#  preferred_foot              | 0.0
#  weak_foot                   | 0.0
#  skill_moves                 | 0.0
#  international_reputation    | 0.0
#  work_rate                   | 0.0
#  body_type                   | 0.0
#  real_face                   | 0.0
#  release_clause_eur          | 0.4003519882485813
#  pace                        | 0.111375179285353
#  shooting                    | 0.111375179285353
#  passing                     | 0.111375179285353
#  dribbling                   | 0.111375179285353
#  defending                   | 0.111375179285353
#  physic                      | 0.111375179285353
#  attacking_crossing          | 0.0
#  attacking_finishing         | 0.0
#  attacking_heading_accuracy  | 0.0
#  attacking_short_passing     | 0.0
#  attacking_volleys           | 0.0
#  skill_dribbling             | 0.0
#  skill_curve                 | 0.0
#  skill_fk_accuracy           | 0.0
#  skill_long_passing          | 0.0
#  skill_ball_control          | 0.0
#  movement_acceleration       | 0.0
#  movement_sprint_speed       | 0.0
#  movement_agility            | 0.0
#  movement_reactions          | 0.0
#  movement_balance            | 0.0
#  power_shot_power            | 0.0
#  power_jumping               | 0.0
#  power_stamina               | 0.0
#  power_strength              | 0.0
#  power_long_shots            | 0.0
#  mentality_aggression        | 0.0
#  mentality_interceptions     | 0.0
#  mentality_positioning       | 0.0
#  mentality_vision            | 0.0
#  mentality_penalties         | 0.0
#  mentality_composure         | 0.22190503246190835
#  defending_marking_awareness | 0.0
#  defending_standing_tackle   | 0.0
#  defending_sliding_tackle    | 0.0
#  goalkeeping_diving          | 0.0
#  goalkeeping_handling        | 0.0
#  goalkeeping_kicking         | 0.0
#  goalkeeping_positioning     | 0.0
#  goalkeeping_reflexes        | 0.0
#  ls                          | 0.0
#  st                          | 0.0
#  rs                          | 0.0
#  lw                          | 0.0
#  lf                          | 0.0
#  cf                          | 0.0
#  rf                          | 0.0
#  rw                          | 0.0
#  lam                         | 0.0
#  cam                         | 0.0
#  ram                         | 0.0
#  lm                          | 0.0
#  lcm                         | 0.0
#  cm                          | 0.0
#  rcm                         | 0.0
#  rm                          | 0.0
#  lwb                         | 0.0
#  ldm                         | 0.0
#  cdm                         | 0.0
#  rdm                         | 0.0
#  rwb                         | 0.0
#  lb                          | 0.0
#  lcb                         | 0.0
#  cb                          | 0.0
#  rcb                         | 0.0
#  rb                          | 0.0
#  gk                          | 0.0
#  year                        | 0.0
#  gender                      | 0.0
#  unique_id                   | 0.0

# %%
col_have_null = [df_afterdrop.columns[i] for i in range(len(col_ratio)) if col_ratio[i] > 0]
print(col_have_null)
# now we know the columns that have null value.
# Out:
# ['value_eur', 'wage_eur', 'club_team_id', 'club_name', 'league_name', 'league_level', 'club_position', 'club_jersey_number', 'club_joined', 'club_contract_valid_until', 'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'mentality_composure']

# %%
df_afterdrop.select(col_have_null).show(3)
# Out:
# +---------+--------+------------+----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+------------------+----+--------+-------+---------+---------+------+-------------------+
# |value_eur|wage_eur|club_team_id|       club_name|         league_name|league_level|club_position|club_jersey_number|club_joined|club_contract_valid_until|release_clause_eur|pace|shooting|passing|dribbling|defending|physic|mentality_composure|
# +---------+--------+------------+----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+------------------+----+--------+-------+---------+---------+------+-------------------+
# | 425000.0|  9000.0|      2007.0|Sporting Lokeren|Belgian Jupiler P...|           1|          RCB|                 5| 2010-07-01|                     2020|            616000|  35|      55|     49|       46|       70|    75|                 62|
# | 350000.0|  5000.0|    110839.0|       SD Huesca|Spanish Segunda D...|           2|          CAM|                10| 2013-08-08|                     2019|            560000|  34|      72|     75|       64|       57|    59|                 72|
# | 325000.0|  5000.0|    110178.0|   SV Sandhausen|German 2. Bundesliga|           2|          RDM|                31| 2013-07-01|                     2018|            504000|  58|      55|     54|       64|       69|    75|                 64|
# +---------+--------+------------+----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+------------------+----+--------+-------+---------+---------+------+-------------------+
# only showing top 3 rows

# %%
# checking the true dtype (because there's a lot of NULL in this column, I'm not sure if it's a int)
df_afterdrop.groupby('mentality_composure').count().orderBy(col('count').desc()).show(truncate=False)
# Out:
# +-------------------+-----+
# |mentality_composure|count|
# +-------------------+-----+
# |NULL               |32026|
# |60                 |4248 |
# |65                 |4160 |
# |58                 |4038 |
# |55                 |3996 |
# |62                 |3966 |
# |64                 |3705 |
# |59                 |3642 |
# |63                 |3498 |
# |68                 |3381 |
# |66                 |3348 |
# |57                 |3323 |
# |56                 |3255 |
# |67                 |3237 |
# |61                 |3165 |
# |70                 |3017 |
# |52                 |2878 |
# |54                 |2756 |
# |50                 |2749 |
# |69                 |2648 |
# +-------------------+-----+
# only showing top 20 rows

# %%
df_afterdrop.select(col_have_null).dtypes
# Out:
# [('value_eur', 'string'),
#  ('wage_eur', 'string'),
#  ('club_team_id', 'string'),
#  ('club_name', 'string'),
#  ('league_name', 'string'),
#  ('league_level', 'string'),
#  ('club_position', 'string'),
#  ('club_jersey_number', 'string'),
#  ('club_joined', 'string'),
#  ('club_contract_valid_until', 'string'),
#  ('release_clause_eur', 'string'),
#  ('pace', 'int'),
#  ('shooting', 'int'),
#  ('passing', 'int'),
#  ('dribbling', 'int'),
#  ('defending', 'int'),
#  ('physic', 'int'),
#  ('mentality_composure', 'string')]

# %% [markdown]
# _Some of the columns that have null value has a wrong dtype_

# %%
col_int=['value_eur','wage_eur','club_team_id','league_level','club_jersey_number','club_contract_valid_until','release_clause_eur','pace','shooting','passing','dribbling','defending','physic','mentality_composure']

# %%
# Transferring the data type
def cast_columns(df, columns_to_cast):
    for col_name in columns_to_cast:
        df = df.withColumn(col_name, df[col_name].cast(IntegerType()))
    return df

df_transferType = cast_columns(df_afterdrop, col_int)

# %%
df_transferType.describe().show()
# Out:
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-----------+
# |summary|        sofifa_id|short_name|           long_name|player_positions|          overall|        potential|         value_eur|          wage_eur|              age|         height_cm|        weight_kg|      club_team_id|           club_name|         league_name|      league_level|club_position|club_jersey_number|club_joined|club_contract_valid_until|   nationality_id|nationality_name|preferred_foot|         weak_foot|       skill_moves|international_reputation|    work_rate|  body_type|real_face|  release_clause_eur|              pace|          shooting|          passing|         dribbling|         defending|           physic|attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing| attacking_volleys|  skill_dribbling|       skill_curve| skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|  movement_agility|movement_reactions|  movement_balance|  power_shot_power|     power_jumping|    power_stamina|    power_strength|  power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|  mentality_vision|mentality_penalties|mentality_composure|defending_marking_awareness|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes|                ls|                st|                rs|                lw|               lf|               cf|               rf|                rw|               lam|               cam|               ram|                lm|               lcm|                cm|               rcm|                rm|               lwb|               ldm|               cdm|               rdm|               rwb|                lb|               lcb|                cb|               rcb|                rb|                gk|              year|             gender|  unique_id|
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-----------+
# |  count|           144323|    144323|              144323|          144323|           144323|           144323|            133588|            140503|           144323|            144323|           144323|            140449|              140449|              140449|            140064|       140449|            140449|     132144|                   140449|           144323|          144323|        144323|            144323|            144323|                  144323|       144323|     144323|   144323|               86543|            128249|            128249|           128249|            128249|            128249|           128249|            144323|             144323|                    144323|                 144323|            144323|           144323|            144323|            144323|            144323|            144323|               144323|               144323|            144323|            144323|            144323|            144323|            144323|           144323|            144323|            144323|              144323|                 144323|               144323|            144323|             144323|             112297|                     144323|                   144323|                  144323|            144323|              144323|             144323|                 144323|              144323|            144323|            144323|            144323|            144323|           144323|           144323|           144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|             144323|     144323|
# |   mean|211967.0790864935|      NULL|                NULL|            NULL|65.87099076377292|70.86494183186325| 1312132.736473336|11110.377358490567|25.13769808000111|181.01369844030404|75.03270441994692|44486.178762397736|                NULL|                NULL|1.3785840758510395|         NULL| 19.99129933285392|       NULL|       2019.9270838525017|55.69959050186041|            NULL|          NULL| 2.941007323849975|2.3306818732980883|      1.1229395176098058|         NULL|       NULL|     NULL|   4686886.264631455|  68.0648192188633| 52.31459114690953|57.01834712161499| 62.14579450911898| 51.16110067135026|64.88116866408315|49.820915585180465|  45.66066392744053|         52.42257990756844|     58.416780416149884| 43.17719975333107|55.25433229630759|47.343181613464246|43.166127367086325| 52.61782252309057| 58.32273442209488|    64.77217075587397|    64.95886310567269| 63.40764119371133|61.800648545276914|   64.035836283891| 56.66906175730826| 65.00749707253868|63.22737193655897| 65.18889574080362| 47.32516646688331|  55.767382884224965|      46.67863750060628|    50.05596474574392| 53.03182444932547|   48.8759934314004|  57.93766529827155|          45.75312320281591|        47.69115802748003|       45.72127796678284|16.578265418540358|  16.326905621418625| 16.187385240051828|     16.334215613588963|  16.690513639544633| 54.84716442753537| 54.84716442753537| 54.84716442753537|55.218112826062196|54.97691415149071|54.97691415149071|54.97691415149071|55.218112826062196| 55.77282390633889| 55.77282390633889| 55.77282390633889| 56.40396178616122|  54.7294420861128|  54.7294420861128|  54.7294420861128| 56.40396178616122| 54.07243479330709|53.645390070921984|53.645390070921984|53.645390070921984| 54.07243479330709| 52.94140736285651| 53.36732524142819| 53.36732524142819| 53.36732524142819| 52.94140736285651| 19.99489958559133|2018.6535687312487| 0.9844515427201486|       NULL|
# | stddev|34700.15102127631|      NULL|                NULL|            NULL|7.165768763091273|6.355224353461223|1737061.6428102609|22248.691798595348|4.651591211616735| 6.900499819410023|7.184165890463798|53281.055198274014|                NULL|                NULL|0.7484169613886593|         NULL|16.662096242167312|       NULL|        2.460571780947897|47.98865708256163|            NULL|          NULL|0.6622066105582134|0.7536315978884567|      0.4193006110730786|         NULL|       NULL|     NULL|1.1694195806430878E7|11.118310904120735|14.023970247872581|10.60897296844176|10.448122381208924|16.774698128733156|9.734473429337783|18.107046053457122|   19.2980647467468|        17.185308220854942|     14.819393121937047|17.498429194520156|18.65280882473812|18.166695007976365|17.324565424169133|15.375967421332978|16.647216541301034|   14.681117268180566|   14.413999503125588|14.666365224814983| 9.305932299344299|13.985195065143074|15.840375253442508|11.828016250955244|15.78261010271217|12.625285536233637|19.059216849577716|  17.303372267546955|      20.44735158060648|   19.221942651926526|14.453258499129758| 15.711526044712764| 12.474358418291388|         20.549381674537248|        21.43992367921235|      21.048260468990645|17.752321061892765|  16.906811174244996|  16.53055312969902|     17.071150843263876|  18.059600871737512|12.774082648574032|12.774082648574032|12.774082648574032|14.361492110696654|14.09816222923454|14.09816222923454|14.09816222923454|14.361492110696654|13.472679682431696|13.472679682431696|13.472679682431696|13.056764871105635|12.621811718015788|12.621811718015788|12.621811718015788|13.056764871105635|12.546059113362734| 12.64349106228191| 12.64349106228191| 12.64349106228191|12.546059113362734|12.943888137207255|13.992155857334698|13.992155857334698|13.992155857334698|12.943888137207255|15.558149522830861|2.2743094034364737|0.12372068871233373|       NULL|
# |    min|                2|     A Lan|A. Benjamin Chiam...|             CAM|               40|               40|              1000|               500|               16|               150|               45|                 1|1. FC Heidenheim ...|Argentina Primera...|                 1|          CAM|                 1| 1991-06-01|                     2014|                1|     Afghanistan|          Left|                 1|                 1|                       1|    High/High|Lean (170-)|       No|                9000|                21|                14|               20|                22|                14|               27|                 5|                  2|                         4|                      7|                 3|                2|                 4|                 3|                 5|                 5|                   11|                   11|                11|                20|                10|                 2|                13|               10|                12|                 3|                   2|                      3|                    2|                 5|                  5|                  3|                          1|                        2|                       3|                 1|                   1|                  1|                      1|                   1|              14+1|              14+1|              14+1|                13|               14|               14|               14|                13|              14+2|              14+2|              14+2|              15+1|              15+1|              15+1|              15+1|              15+1|              14+1|              15+1|              15+1|              15+1|              14+1|              14+1|              15+2|              15+2|              15+2|              14+1|                10|              2015|                  0|100143_2015|
# |    max|           264640|Ș. Vlădoiu|              李相旭|     ST, RWB, RM|               94|               95|           9500000|            575000|               54|               208|              110|            115820|       Śląsk Wrocław|Venezuelan Primer...|                 5|          SUB|                99| 2021-09-15|                     2031|              219|        Zimbabwe|         Right|                 5|                 5|                       5|Medium/Medium|     Unique|      Yes|           373500000|                97|                94|               93|                96|                91|               92|                94|                 95|                        95|                     95|                93|               97|                94|                95|                95|                96|                   97|                   97|                96|                96|                98|                96|                97|               97|                98|                94|                  96|                     93|                   96|                96|                 96|                 96|                         94|                       94|                      95|                91|                  92|                 95|                     92|                  94|              92+2|              92+2|              92+2|              93+1|             93+1|             93+1|             93+1|              93+1|                94|                94|                94|              92+2|              89+2|              89+2|              89+2|              92+2|              88-1|              89+2|              89+2|              89+2|              88-1|              88+3|              90+2|              90+2|              90+2|              88+3|              90+2|              2022|                  1|  9833_2019|
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+--------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-----------+

# %% [markdown]
# Except the columns that has nullValue, some other columns are inferred incorrectly

# %%
def add_schema_row(df, num_rows=5):
    # Get column names and data types
    schema_info = [(field.name, str(field.dataType)) for field in df.schema.fields]
    columns = [name for name, dtype in schema_info]
    data_types = [dtype for name, dtype in schema_info]
    
    # Create a row containing the data type
    schema_row = Row(*data_types)
    schema_df = spark.createDataFrame([schema_row], columns)
    
    # Getting the first few rows of data
    data_df = df.limit(num_rows)
    
    combined_df = schema_df.union(data_df)
    
    return combined_df

# Creating a df to easily check whether the data type is inferred correctly.
combined_df = add_schema_row(df_transferType, num_rows=5)
combined_df.show(truncate=False)

# I used GPT for constructing the code to show the df with the data type[1].
# [1]OpenAI. (2024). *ChatGPT* [Large language model]. https://chat.openai.com/
# Out:
# +-------------+------------+-------------------------+----------------+-------------+-------------+-------------+-------------+-------------+----------+-------------+-------------+-------------+----------------+---------------------------+-------------+-------------+------------------+------------+-------------------------+--------------+----------------+--------------+-------------+-------------+------------------------+-------------+----------------+------------+------------------+-------------+-------------+-------------+-------------+-------------+-------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-------------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+------------+
# |sofifa_id    |short_name  |long_name                |player_positions|overall      |potential    |value_eur    |wage_eur     |age          |dob       |height_cm    |weight_kg    |club_team_id |club_name       |league_name                |league_level |club_position|club_jersey_number|club_joined |club_contract_valid_until|nationality_id|nationality_name|preferred_foot|weak_foot    |skill_moves  |international_reputation|work_rate    |body_type       |real_face   |release_clause_eur|pace         |shooting     |passing      |dribbling    |defending    |physic       |attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing|attacking_volleys|skill_dribbling|skill_curve  |skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|movement_agility|movement_reactions|movement_balance|power_shot_power|power_jumping|power_stamina|power_strength|power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|mentality_vision|mentality_penalties|mentality_composure|defending_marking_awareness|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes|ls          |st          |rs          |lw          |lf          |cf          |rf          |rw          |lam         |cam         |ram         |lm          |lcm         |cm          |rcm         |rm          |lwb         |ldm         |cdm         |rdm         |rwb         |lb          |lcb         |cb          |rcb         |rb          |gk          |year         |gender       |unique_id   |
# +-------------+------------+-------------------------+----------------+-------------+-------------+-------------+-------------+-------------+----------+-------------+-------------+-------------+----------------+---------------------------+-------------+-------------+------------------+------------+-------------------------+--------------+----------------+--------------+-------------+-------------+------------------------+-------------+----------------+------------+------------------+-------------+-------------+-------------+-------------+-------------+-------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-------------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+------------+
# |IntegerType()|StringType()|StringType()             |StringType()    |IntegerType()|IntegerType()|IntegerType()|IntegerType()|IntegerType()|DateType()|IntegerType()|IntegerType()|IntegerType()|StringType()    |StringType()               |IntegerType()|StringType() |IntegerType()     |StringType()|IntegerType()            |IntegerType() |StringType()    |StringType()  |IntegerType()|IntegerType()|IntegerType()           |StringType() |StringType()    |StringType()|IntegerType()     |IntegerType()|IntegerType()|IntegerType()|IntegerType()|IntegerType()|IntegerType()|IntegerType()     |IntegerType()      |IntegerType()             |IntegerType()          |IntegerType()    |IntegerType()  |IntegerType()|IntegerType()    |IntegerType()     |IntegerType()     |IntegerType()        |IntegerType()        |IntegerType()   |IntegerType()     |IntegerType()   |IntegerType()   |IntegerType()|IntegerType()|IntegerType() |IntegerType()   |IntegerType()       |IntegerType()          |IntegerType()        |IntegerType()   |IntegerType()      |IntegerType()      |IntegerType()              |IntegerType()            |IntegerType()           |IntegerType()     |IntegerType()       |IntegerType()      |IntegerType()          |IntegerType()       |StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|StringType()|IntegerType()|IntegerType()|StringType()|
# |52340        |M. Marić    |Mijat Marić              |CB              |69           |69           |425000       |9000         |33           |1984-04-30|188          |83           |2007         |Sporting Lokeren|Belgian Jupiler Pro League |1            |RCB          |5                 |2010-07-01  |2020                     |47            |Switzerland     |Right         |4            |2            |1                       |Low/Medium   |Normal (185+)   |No          |616000            |35           |55           |49           |46           |70           |75           |39                |47                 |72                        |53                     |40               |38             |52           |58               |52                |59                |38                   |32                   |34              |59                |58              |70              |65           |70           |79            |57              |74                  |71                     |44                   |45              |75                 |62                 |69                         |70                       |67                      |13                |8                   |13                 |14                     |6                   |54+1        |54+1        |54+1        |46          |49          |49          |49          |46          |48+1        |48+1        |48+1        |47+1        |54+1        |54+1        |54+1        |47+1        |58+1        |63+1        |63+1        |63+1        |58+1        |60+1        |68+1        |68+1        |68+1        |60+1        |16+1        |2018         |1            |52340_2018  |
# |52842        |Camacho     |Juan José Camacho Barnola|CAM, LM         |69           |69           |350000       |5000         |36           |1980-08-02|181          |75           |110839       |SD Huesca       |Spanish Segunda División   |2            |CAM          |10                |2013-08-08  |2019                     |45            |Spain           |Left          |2            |3            |1                       |Medium/Medium|Lean (170-185)  |No          |560000            |34           |72           |75           |64           |57           |59           |72                |70                 |68                        |76                     |57               |67             |80           |77               |75                |68                |32                   |35                   |33              |72                |56              |78              |35           |36           |70            |71              |66                  |61                     |73                   |74              |86                 |72                 |49                         |59                       |55                      |9                 |7                   |8                  |15                     |10                  |68+1        |68+1        |68+1        |65          |67          |67          |67          |65          |68+1        |68+1        |68+1        |65+1        |69          |69          |69          |65+1        |59+1        |64+1        |64+1        |64+1        |59+1        |57+1        |61+1        |61+1        |61+1        |57+1        |17+1        |2018         |1            |52842_2018  |
# |53073        |S. Kulovits |Stefan Kulovits          |CDM             |69           |69           |325000       |5000         |34           |1983-04-19|177          |70           |110178       |SV Sandhausen   |German 2. Bundesliga       |2            |RDM          |31                |2013-07-01  |2018                     |4             |Austria         |Right         |3            |2            |1                       |Medium/High  |Lean (170-185)  |No          |504000            |58           |55           |54           |64           |69           |75           |48                |51                 |58                        |62                     |43               |59             |55           |40               |53                |63                |64                   |53                   |76              |74                |76              |61              |77           |85           |65            |65              |87                  |68                     |37                   |51              |47                 |64                 |73                         |69                       |73                      |13                |16                  |8                  |12                     |16                  |57+1        |57+1        |57+1        |57          |57          |57          |57          |57          |58+1        |58+1        |58+1        |58+1        |61+1        |61+1        |61+1        |58+1        |66+1        |68+1        |68+1        |68+1        |66+1        |67+1        |69          |69          |69          |67+1        |21+1        |2018         |1            |53073_2018  |
# |53412        |A. Ferdinand|Anton Ferdinand          |CB              |69           |69           |600000       |7000         |32           |1985-02-18|183          |71           |1954         |Southend United |English League One         |3            |LCB          |5                 |2016-08-27  |2019                     |14            |England         |Right         |4            |2            |2                       |Low/Medium   |Normal (170-185)|No          |1100000           |65           |41           |53           |52           |69           |70           |43                |35                 |70                        |58                     |42               |51             |44           |42               |63                |46                |63                   |67                   |64              |65                |60              |55              |81           |63           |73            |43              |67                  |68                     |25                   |52              |51                 |65                 |68                         |69                       |68                      |7                 |11                  |12                 |7                      |14                  |50+1        |50+1        |50+1        |49          |49          |49          |49          |49          |50+1        |50+1        |50+1        |51+1        |55+1        |55+1        |55+1        |51+1        |61+1        |63+1        |63+1        |63+1        |61+1        |63+1        |68+1        |68+1        |68+1        |63+1        |16+1        |2018         |1            |53412_2018  |
# |53593        |G. O'Neil   |Gary O'Neil              |CDM, CM         |69           |69           |325000       |20000        |34           |1983-05-18|173          |61           |1919         |Bristol City    |English League Championship|2            |SUB          |28                |2016-07-01  |2018                     |14            |England         |Right         |3            |3            |1                       |Low/Medium   |Lean (170-185)  |Yes         |618000            |52           |64           |70           |68           |63           |70           |68                |62                 |54                        |72                     |65               |65             |70           |66               |68                |70                |53                   |51                   |67              |70                |78              |67              |67           |73           |66            |67              |75                  |65                     |58                   |71              |64                 |67                 |63                         |65                       |58                      |12                |8                   |15                 |8                      |14                  |63+1        |63+1        |63+1        |65          |65          |65          |65          |65          |67+1        |67+1        |67+1        |66+1        |69          |69          |69          |66+1        |65+1        |68+1        |68+1        |68+1        |65+1        |64+1        |64+1        |64+1        |64+1        |64+1        |17+1        |2018         |1            |53593_2018  |
# +-------------+------------+-------------------------+----------------+-------------+-------------+-------------+-------------+-------------+----------+-------------+-------------+-------------+----------------+---------------------------+-------------+-------------+------------------+------------+-------------------------+--------------+----------------+--------------+-------------+-------------+------------------------+-------------+----------------+------------+------------------+-------------+-------------+-------------+-------------+-------------+-------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-------------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+------------+

# %% [markdown]
# There are several potential problems with the datatype. Further work could be done when optimizing different ML models. Among them, the position rating (i.e. ls          |st          |rs          |lw .....) should be IntegerType() to represent the players capability of different roles.

# %%
# dob is a DataType(), maybe could also be changed into Timestamp? 
# club_joined could be changed to timestamp (now it's StringType)
# body_type is like Normal (170-) ,Normal (170-185). Maybe it could also be changed to integers?

# %%
# The Position Ratings has a format of n+3, which means the boost a player can gain in the FIFA game. 
# For example, player performance can be influenced by team chemistry and player morale, leading to temporary boosts.
# However, it got inferred as StringType(), which isn't helpful for ML modeling.
# Therefore, I transferred it into IntegerType():
position_columns = [
    'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw',
    'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm',
    'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
    'lcb', 'cb', 'rcb', 'rb', 'gk'
]
# Pyspark has a built-in funcion for this : imported before (regexp_extract)

# Split the string and calculate the sum (by overwriting the original columns)
# colums have scenarios that players position ratings are N+m, N-m or N
# Pattern to extract the base number (N)
pattern_base = r'^(\d+)'

# Pattern to extract the modifier with its sign (+M or -M)
pattern_modifier = r'([+-]\d+)$'

df_position_calculated=df_transferType
for col_name in position_columns:
    # Extract the base rating
    base = regexp_extract(col(col_name), pattern_base, 1).cast(IntegerType())
    
    # Extract the modifier (if any), including the sign
    modifier = regexp_extract(col(col_name), pattern_modifier, 1).cast(IntegerType())
    
    # Compute the effective rating
    df_position_calculated = df_position_calculated.withColumn(
        col_name,
        base + when(modifier.isNotNull(), modifier).otherwise(0)
    )

# I used GPT for constructing the code. Also, GPT inspired me to use regexp_extract[2].
# [2]OpenAI. (2024). *ChatGPT* [Large language model]. https://chat.openai.com/

# %%
df_position_calculated.select(position_columns).show()
df_transferType.select(position_columns).show()
# Out:
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# | ls| st| rs| lw| lf| cf| rf| rw|lam|cam|ram| lm|lcm| cm|rcm| rm|lwb|ldm|cdm|rdm|rwb| lb|lcb| cb|rcb| rb| gk|
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# | 55| 55| 55| 46| 49| 49| 49| 46| 49| 49| 49| 48| 55| 55| 55| 48| 59| 64| 64| 64| 59| 61| 69| 69| 69| 61| 17|
# | 69| 69| 69| 65| 67| 67| 67| 65| 69| 69| 69| 66| 69| 69| 69| 66| 60| 65| 65| 65| 60| 58| 62| 62| 62| 58| 18|
# | 58| 58| 58| 57| 57| 57| 57| 57| 59| 59| 59| 59| 62| 62| 62| 59| 67| 69| 69| 69| 67| 68| 69| 69| 69| 68| 22|
# | 51| 51| 51| 49| 49| 49| 49| 49| 51| 51| 51| 52| 56| 56| 56| 52| 62| 64| 64| 64| 62| 64| 69| 69| 69| 64| 17|
# | 64| 64| 64| 65| 65| 65| 65| 65| 68| 68| 68| 67| 69| 69| 69| 67| 66| 69| 69| 69| 66| 65| 65| 65| 65| 65| 18|
# | 63| 63| 63| 69| 68| 68| 68| 69| 69| 69| 69| 69| 68| 68| 68| 69| 54| 53| 53| 53| 54| 49| 40| 40| 40| 49| 13|
# | 65| 65| 65| 69| 67| 67| 67| 69| 68| 68| 68| 69| 64| 64| 64| 69| 57| 53| 53| 53| 57| 53| 46| 46| 46| 53| 17|
# | 69| 69| 69| 69| 69| 69| 69| 69| 69| 69| 69| 69| 67| 67| 67| 69| 63| 62| 62| 62| 63| 62| 62| 62| 62| 62| 19|
# | 62| 62| 62| 61| 62| 62| 62| 61| 64| 64| 64| 63| 66| 66| 66| 63| 65| 69| 69| 69| 65| 66| 69| 69| 69| 66| 20|
# | 46| 46| 46| 48| 45| 45| 45| 48| 47| 47| 47| 53| 53| 53| 53| 53| 67| 66| 66| 66| 67| 69| 69| 69| 69| 69| 16|
# | 51| 51| 51| 49| 50| 50| 50| 49| 54| 54| 54| 52| 60| 60| 60| 52| 60| 67| 67| 67| 60| 61| 69| 69| 69| 61| 20|
# | 44| 44| 44| 36| 37| 37| 37| 36| 38| 38| 38| 39| 44| 44| 44| 39| 54| 60| 60| 60| 54| 57| 69| 69| 69| 57| 17|
# | 64| 64| 64| 68| 66| 66| 66| 68| 69| 69| 69| 69| 68| 68| 68| 69| 62| 62| 62| 62| 62| 59| 55| 55| 55| 59| 18|
# | 25| 25| 25| 26| 26| 26| 26| 26| 29| 29| 29| 29| 29| 29| 29| 29| 28| 30| 30| 30| 28| 28| 28| 28| 28| 28| 69|
# | 60| 60| 60| 61| 61| 61| 61| 61| 65| 65| 65| 63| 68| 68| 68| 63| 65| 69| 69| 69| 65| 64| 67| 67| 67| 64| 19|
# | 65| 65| 65| 68| 67| 67| 67| 68| 68| 68| 68| 69| 63| 63| 63| 69| 55| 53| 53| 53| 55| 52| 45| 45| 45| 52| 19|
# | 46| 46| 46| 44| 44| 44| 44| 44| 45| 45| 45| 49| 51| 51| 51| 49| 60| 62| 62| 62| 60| 62| 69| 69| 69| 62| 17|
# | 65| 65| 65| 66| 66| 66| 66| 66| 69| 69| 69| 67| 66| 66| 66| 67| 55| 55| 55| 55| 55| 53| 48| 48| 48| 53| 19|
# | 62| 62| 62| 65| 63| 63| 63| 65| 65| 65| 65| 67| 66| 66| 66| 67| 69| 68| 68| 68| 69| 69| 67| 67| 67| 69| 20|
# | 66| 66| 66| 65| 66| 66| 66| 65| 68| 68| 68| 66| 69| 69| 69| 66| 65| 69| 69| 69| 65| 66| 69| 69| 69| 66| 18|
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# only showing top 20 rows
#
# +----+----+----+---+---+---+---+---+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# |  ls|  st|  rs| lw| lf| cf| rf| rw| lam| cam| ram|  lm| lcm|  cm| rcm|  rm| lwb| ldm| cdm| rdm| rwb|  lb| lcb|  cb| rcb|  rb|  gk|
# +----+----+----+---+---+---+---+---+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# |54+1|54+1|54+1| 46| 49| 49| 49| 46|48+1|48+1|48+1|47+1|54+1|54+1|54+1|47+1|58+1|63+1|63+1|63+1|58+1|60+1|68+1|68+1|68+1|60+1|16+1|
# |68+1|68+1|68+1| 65| 67| 67| 67| 65|68+1|68+1|68+1|65+1|  69|  69|  69|65+1|59+1|64+1|64+1|64+1|59+1|57+1|61+1|61+1|61+1|57+1|17+1|
# |57+1|57+1|57+1| 57| 57| 57| 57| 57|58+1|58+1|58+1|58+1|61+1|61+1|61+1|58+1|66+1|68+1|68+1|68+1|66+1|67+1|  69|  69|  69|67+1|21+1|
# |50+1|50+1|50+1| 49| 49| 49| 49| 49|50+1|50+1|50+1|51+1|55+1|55+1|55+1|51+1|61+1|63+1|63+1|63+1|61+1|63+1|68+1|68+1|68+1|63+1|16+1|
# |63+1|63+1|63+1| 65| 65| 65| 65| 65|67+1|67+1|67+1|66+1|  69|  69|  69|66+1|65+1|68+1|68+1|68+1|65+1|64+1|64+1|64+1|64+1|64+1|17+1|
# |62+1|62+1|62+1| 69| 68| 68| 68| 69|70-1|70-1|70-1|68+1|67+1|67+1|67+1|68+1|53+1|52+1|52+1|52+1|53+1|48+1|39+1|39+1|39+1|48+1|12+1|
# |64+1|64+1|64+1| 69| 67| 67| 67| 69|67+1|67+1|67+1|68+1|63+1|63+1|63+1|68+1|56+1|52+1|52+1|52+1|56+1|52+1|45+1|45+1|45+1|52+1|16+1|
# |70-1|70-1|70-1| 69| 69| 69| 69| 69|  69|  69|  69|  69|66+1|66+1|66+1|  69|62+1|61+1|61+1|61+1|62+1|61+1|61+1|61+1|61+1|61+1|18+1|
# |61+1|61+1|61+1| 61| 62| 62| 62| 61|63+1|63+1|63+1|62+1|65+1|65+1|65+1|62+1|64+1|68+1|68+1|68+1|64+1|65+1|68+1|68+1|68+1|65+1|19+1|
# |45+1|45+1|45+1| 48| 45| 45| 45| 48|46+1|46+1|46+1|52+1|52+1|52+1|52+1|52+1|66+1|65+1|65+1|65+1|66+1|68+1|70-1|70-1|70-1|68+1|15+1|
# |50+1|50+1|50+1| 49| 50| 50| 50| 49|53+1|53+1|53+1|51+1|59+1|59+1|59+1|51+1|59+1|66+1|66+1|66+1|59+1|60+1|68+1|68+1|68+1|60+1|19+1|
# |43+1|43+1|43+1| 36| 37| 37| 37| 36|37+1|37+1|37+1|38+1|43+1|43+1|43+1|38+1|53+1|59+1|59+1|59+1|53+1|56+1|68+1|68+1|68+1|56+1|16+1|
# |63+1|63+1|63+1| 68| 66| 66| 66| 68|68+1|68+1|68+1|68+1|67+1|67+1|67+1|68+1|61+1|61+1|61+1|61+1|61+1|58+1|54+1|54+1|54+1|58+1|17+1|
# |24+1|24+1|24+1| 26| 26| 26| 26| 26|28+1|28+1|28+1|28+1|28+1|28+1|28+1|28+1|27+1|29+1|29+1|29+1|27+1|27+1|27+1|27+1|27+1|27+1|68+1|
# |59+1|59+1|59+1| 61| 61| 61| 61| 61|64+1|64+1|64+1|62+1|67+1|67+1|67+1|62+1|64+1|68+1|68+1|68+1|64+1|63+1|66+1|66+1|66+1|63+1|18+1|
# |64+1|64+1|64+1| 68| 67| 67| 67| 68|67+1|67+1|67+1|68+1|62+1|62+1|62+1|68+1|54+1|52+1|52+1|52+1|54+1|51+1|44+1|44+1|44+1|51+1|18+1|
# |45+1|45+1|45+1| 44| 44| 44| 44| 44|44+1|44+1|44+1|48+1|50+1|50+1|50+1|48+1|59+1|61+1|61+1|61+1|59+1|61+1|68+1|68+1|68+1|61+1|16+1|
# |64+1|64+1|64+1| 66| 66| 66| 66| 66|68+1|68+1|68+1|66+1|65+1|65+1|65+1|66+1|54+1|54+1|54+1|54+1|54+1|52+1|47+1|47+1|47+1|52+1|18+1|
# |61+1|61+1|61+1| 65| 63| 63| 63| 65|64+1|64+1|64+1|66+1|65+1|65+1|65+1|66+1|  69|67+1|67+1|67+1|  69|68+1|66+1|66+1|66+1|68+1|19+1|
# |65+1|65+1|65+1| 65| 66| 66| 66| 65|67+1|67+1|67+1|65+1|68+1|68+1|68+1|65+1|64+1|68+1|68+1|68+1|64+1|65+1|  69|  69|  69|65+1|17+1|
# +----+----+----+---+---+---+---+---+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# only showing top 20 rows

# %% [markdown]
# #### D.3 Null Value Handling

# %% [markdown]
# ##### D.3.1 _Female players_

# %% [markdown]
# All of the female players have a lot of null columns. Therefore, female players' data should be seperately treated since treating the whole data with imputation may cause some unexpected bias.

# %%
df_female=df_position_calculated.filter(col('gender')==0)
df_male=df_position_calculated.filter(col('gender')==1)

# %%
#getting a list of the rest null cols
col_ratio_female = show_null_ratio(df_female).collect()[0]
# Out:
# -RECORD 0------------------------------------------
#  sofifa_id                   | 0.0
#  short_name                  | 0.0
#  long_name                   | 0.0
#  player_positions            | 0.0
#  overall                     | 0.0
#  potential                   | 0.0
#  value_eur                   | 0.9808377896613191
#  wage_eur                    | 0.9795008912655971
#  age                         | 0.0
#  dob                         | 0.0
#  height_cm                   | 0.0
#  weight_kg                   | 0.0
#  club_team_id                | 1.0
#  club_name                   | 1.0
#  league_name                 | 1.0
#  league_level                | 1.0
#  club_position               | 1.0
#  club_jersey_number          | 1.0
#  club_joined                 | 1.0
#  club_contract_valid_until   | 1.0
#  nationality_id              | 0.0
#  nationality_name            | 0.0
#  preferred_foot              | 0.0
#  weak_foot                   | 0.0
#  skill_moves                 | 0.0
#  international_reputation    | 0.0
#  work_rate                   | 0.0
#  body_type                   | 0.0
#  real_face                   | 0.0
#  release_clause_eur          | 0.9795008912655971
#  pace                        | 0.12611408199643495
#  shooting                    | 0.12611408199643495
#  passing                     | 0.12611408199643495
#  dribbling                   | 0.12611408199643495
#  defending                   | 0.12611408199643495
#  physic                      | 0.12611408199643495
#  attacking_crossing          | 0.0
#  attacking_finishing         | 0.0
#  attacking_heading_accuracy  | 0.0
#  attacking_short_passing     | 0.0
#  attacking_volleys           | 0.0
#  skill_dribbling             | 0.0
#  skill_curve                 | 0.0
#  skill_fk_accuracy           | 0.0
#  skill_long_passing          | 0.0
#  skill_ball_control          | 0.0
#  movement_acceleration       | 0.0
#  movement_sprint_speed       | 0.0
#  movement_agility            | 0.0
#  movement_reactions          | 0.0
#  movement_balance            | 0.0
#  power_shot_power            | 0.0
#  power_jumping               | 0.0
#  power_stamina               | 0.0
#  power_strength              | 0.0
#  power_long_shots            | 0.0
#  mentality_aggression        | 0.0
#  mentality_interceptions     | 0.0
#  mentality_positioning       | 0.0
#  mentality_vision            | 0.0
#  mentality_penalties         | 0.0
#  mentality_composure         | 0.11051693404634581
#  defending_marking_awareness | 0.0
#  defending_standing_tackle   | 0.0
#  defending_sliding_tackle    | 0.0
#  goalkeeping_diving          | 0.0
#  goalkeeping_handling        | 0.0
#  goalkeeping_kicking         | 0.0
#  goalkeeping_positioning     | 0.0
#  goalkeeping_reflexes        | 0.0
#  ls                          | 0.0
#  st                          | 0.0
#  rs                          | 0.0
#  lw                          | 0.0
#  lf                          | 0.0
#  cf                          | 0.0
#  rf                          | 0.0
#  rw                          | 0.0
#  lam                         | 0.0
#  cam                         | 0.0
#  ram                         | 0.0
#  lm                          | 0.0
#  lcm                         | 0.0
#  cm                          | 0.0
#  rcm                         | 0.0
#  rm                          | 0.0
#  lwb                         | 0.0
#  ldm                         | 0.0
#  cdm                         | 0.0
#  rdm                         | 0.0
#  rwb                         | 0.0
#  lb                          | 0.0
#  lcb                         | 0.0
#  cb                          | 0.0
#  rcb                         | 0.0
#  rb                          | 0.0
#  gk                          | 0.0
#  year                        | 0.0
#  gender                      | 0.0
#  unique_id                   | 0.0

# %%
# showing the lists that female players has a very high ratio of nullValue
col_have_null = [df_female.columns[i] for i in range(len(col_ratio_female)) if col_ratio_female[i]>0.9]
print(col_have_null)
# Out:
# ['value_eur', 'wage_eur', 'club_team_id', 'club_name', 'league_name', 'league_level', 'club_position', 'club_jersey_number', 'club_joined', 'club_contract_valid_until', 'release_clause_eur']

# %%
col_female_high_null=['value_eur', 'wage_eur', 'club_team_id', 'club_name', 'league_name', 'league_level', 'club_position', 'club_jersey_number', 'club_joined', 'club_contract_valid_until', 'release_clause_eur']

# %%
df_female.select(col_female_high_null).printSchema()
# Out:
# root
#  |-- value_eur: integer (nullable = true)
#  |-- wage_eur: integer (nullable = true)
#  |-- club_team_id: integer (nullable = true)
#  |-- club_name: string (nullable = true)
#  |-- league_name: string (nullable = true)
#  |-- league_level: integer (nullable = true)
#  |-- club_position: string (nullable = true)
#  |-- club_jersey_number: integer (nullable = true)
#  |-- club_joined: string (nullable = true)
#  |-- club_contract_valid_until: integer (nullable = true)
#  |-- release_clause_eur: integer (nullable = true)

# %%
# filling all the null string columns with Unknown
df_female = df_female.fillna({'club_name': 'Unknown','league_name': 'Unknown','club_position': 'Unknown','club_joined': 'Unknown'})

# %% [markdown]
# - Although it may cause bias without seperately treating null columns, for most of the integer columns in the female df, there isn't much other data for correspondence.
# - So we still have to put them back together

# %%
df_all_gender=df_male.union(df_female)

# %% [markdown]
# ##### D.3.2 _All players_

# %%
schema = df_all_gender.schema

# obtaining the string cols
string_columns = [field.name for field in schema.fields if isinstance(field.dataType, StringType)]

# obtaining the numeric cols
numeric_columns = [field.name for field in schema.fields if isinstance(field.dataType, (IntegerType, FloatType, DoubleType))]

# %%
# Finding cols with nullValues in StringTypes
string_columns_with_null = []
for col_name in string_columns:
    null_count = df_all_gender.filter(isnull(col(col_name))).count()
    if null_count > 0:
        string_columns_with_null.append(col_name)

# %%
for col_name in string_columns_with_null:
    # It seems that there isn't a built-in function to compute mode
    mode_df = df_all_gender.groupBy(col_name).agg(count(col_name).alias('count')).orderBy(desc('count'))
    mode = mode_df.first()[0]
    
    # fill it
    df_all_gender = df_all_gender.fillna({col_name: mode})

# %%
df_string_filled=df_all_gender

# %%
# Finding cols with nullValues in numeric columns
numeric_columns_with_null = []
for col_name in numeric_columns:
    null_count = df_all_gender.filter(isnull(col(col_name))).count()
    if null_count > 0:
        numeric_columns_with_null.append(col_name)

# %%
# obtain median for integers
for col_name in numeric_columns_with_null:
    median = df_string_filled.approxQuantile(col_name, [0.5], 0.001)[0]
    df_string_filled = df_string_filled.fillna({col_name: median})

# %%
df_filled=df_string_filled

# %%
df_filled.show(4)
# Out:
# +---------+------------+--------------------+----------------+-------+---------+---------+--------+---+----------+---------+---------+------------+-----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+--------------+----------------+--------------+---------+-----------+------------------------+-------------+--------------+---------+------------------+----+--------+-------+---------+---------+------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+----+------+-----------+
# |sofifa_id|  short_name|           long_name|player_positions|overall|potential|value_eur|wage_eur|age|       dob|height_cm|weight_kg|club_team_id|        club_name|         league_name|league_level|club_position|club_jersey_number|club_joined|club_contract_valid_until|nationality_id|nationality_name|preferred_foot|weak_foot|skill_moves|international_reputation|    work_rate|     body_type|real_face|release_clause_eur|pace|shooting|passing|dribbling|defending|physic|attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing|attacking_volleys|skill_dribbling|skill_curve|skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|movement_agility|movement_reactions|movement_balance|power_shot_power|power_jumping|power_stamina|power_strength|power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|mentality_vision|mentality_penalties|mentality_composure|defending_marking_awareness|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes| ls| st| rs| lw| lf| cf| rf| rw|lam|cam|ram| lm|lcm| cm|rcm| rm|lwb|ldm|cdm|rdm|rwb| lb|lcb| cb|rcb| rb| gk|year|gender|  unique_id|
# +---------+------------+--------------------+----------------+-------+---------+---------+--------+---+----------+---------+---------+------------+-----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+--------------+----------------+--------------+---------+-----------+------------------------+-------------+--------------+---------+------------------+----+--------+-------+---------+---------+------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+----+------+-----------+
# |   233442|J. Osei-Tutu|     Jordi Osei-Tutu|          RB, RM|     59|       75|   325000|    7000| 20|1998-10-02|      178|       72|         160|  VfL Bochum 1848|German 2. Bundesliga|           2|           RB|                 6| 2017-07-01|                     2020|            14|         England|         Right|        3|          2|                       1|Medium/Medium|Lean (170-185)|       No|           1300000|  79|      36|     43|       54|       55|    63|                49|                 37|                        44|                     46|               29|             50|         43|               34|                30|                52|                   77|                   80|              72|                58|              69|              33|           62|           68|            63|              35|                  58|                     56|                   49|              44|                 42|                 51|                         55|                       58|                      58|                10|                  13|                  7|                     11|                  10| 50| 50| 50| 52| 50| 50| 50| 52| 51| 51| 51| 55| 50| 50| 50| 55| 60| 55| 55| 55| 60| 60| 58| 58| 58| 60| 18|2020|     1|233442_2020|
# |   244289| K. Bafounta|Kamal Bafounta Or...|             CDM|     59|       78|   550000|    2000| 18|2002-01-08|      193|       81|          22|Borussia Dortmund|German 1. Bundesliga|           1|          RES|                34| 2018-07-01|                     2021|            18|          France|         Right|        3|          3|                       1|Medium/Medium|   Lean (185+)|       No|            698000|  66|      50|     54|       60|       57|    58|                39|                 48|                        61|                     65|               54|             59|         51|               44|                62|                63|                   65|                   66|              65|                49|              50|              57|           59|           52|            60|              46|                  59|                     56|                   55|              47|                 48|                 43|                         54|                       62|                      50|                 8|                  14|                 14|                     13|                  10| 59| 59| 59| 56| 57| 57| 57| 56| 59| 59| 59| 58| 59| 59| 59| 58| 57| 60| 60| 60| 57| 58| 60| 60| 60| 58| 18|2021|     1|244289_2021|
# |   244490|   J. Stanić|         Jozo Stanić|              CB|     59|       72|   525000|    3000| 21|1999-04-06|      188|       80|      110592|      FSV Zwickau|German 3. Bundesliga|           3|          SUB|                 6| 2017-07-01|                     2021|            10|         Croatia|         Right|        3|          2|                       1|Medium/Medium|   Lean (185+)|       No|           1300000|  53|      23|     36|       42|       61|    61|                28|                 19|                        55|                     42|               18|             36|         20|               27|                36|                43|                   53|                   53|              54|                54|              56|              31|           62|           52|            67|              22|                  56|                     57|                   23|              39|                 35|                 40|                         60|                       66|                      62|                 7|                   7|                 12|                      9|                   7| 39| 39| 39| 38| 37| 37| 37| 38| 40| 40| 40| 41| 44| 44| 44| 41| 52| 54| 54| 54| 52| 55| 61| 61| 61| 55| 15|2021|     1|244490_2021|
# |   244494|F. Delaveris|Filip Møller Dela...|     CAM, LM, ST|     59|       73|   525000|    2000| 19|2000-12-10|      185|       81|        1909|          Vitesse|  Holland Eredivisie|           1|          RES|                15| 2020-01-31|                     2023|            36|          Norway|         Right|        3|          3|                       1|Medium/Medium| Normal (185+)|       No|            691000|  69|      54|     56|       64|       20|    58|                58|                 55|                        51|                     58|               52|             64|         57|               54|                43|                63|                   68|                   69|              70|                53|              76|              56|           67|           63|            66|              50|                  27|                     13|                   55|              59|                 45|                 48|                         25|                       11|                      13|                 8|                  11|                  9|                      9|                   7| 60| 60| 60| 60| 59| 59| 59| 60| 61| 61| 61| 62| 54| 54| 54| 62| 45| 41| 41| 41| 45| 42| 35| 35| 35| 42| 16|2021|     1|244494_2021|
# +---------+------------+--------------------+----------------+-------+---------+---------+--------+---+----------+---------+---------+------------+-----------------+--------------------+------------+-------------+------------------+-----------+-------------------------+--------------+----------------+--------------+---------+-----------+------------------------+-------------+--------------+---------+------------------+----+--------+-------+---------+---------+------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+----+------+-----------+
# only showing top 4 rows

# %%
df_filled.show(1,vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 233442
#  short_name                  | J. Osei-Tutu
#  long_name                   | Jordi Osei-Tutu
#  player_positions            | RB, RM
#  overall                     | 59
#  potential                   | 75
#  value_eur                   | 325000
#  wage_eur                    | 7000
#  age                         | 20
#  dob                         | 1998-10-02
#  height_cm                   | 178
#  weight_kg                   | 72
#  club_team_id                | 160
#  club_name                   | VfL Bochum 1848
#  league_name                 | German 2. Bundesliga
#  league_level                | 2
#  club_position               | RB
#  club_jersey_number          | 6
#  club_joined                 | 2017-07-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 14
#  nationality_name            | England
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 1300000
#  pace                        | 79
#  shooting                    | 36
#  passing                     | 43
#  dribbling                   | 54
#  defending                   | 55
#  physic                      | 63
#  attacking_crossing          | 49
#  attacking_finishing         | 37
#  attacking_heading_accuracy  | 44
#  attacking_short_passing     | 46
#  attacking_volleys           | 29
#  skill_dribbling             | 50
#  skill_curve                 | 43
#  skill_fk_accuracy           | 34
#  skill_long_passing          | 30
#  skill_ball_control          | 52
#  movement_acceleration       | 77
#  movement_sprint_speed       | 80
#  movement_agility            | 72
#  movement_reactions          | 58
#  movement_balance            | 69
#  power_shot_power            | 33
#  power_jumping               | 62
#  power_stamina               | 68
#  power_strength              | 63
#  power_long_shots            | 35
#  mentality_aggression        | 58
#  mentality_interceptions     | 56
#  mentality_positioning       | 49
#  mentality_vision            | 44
#  mentality_penalties         | 42
#  mentality_composure         | 51
#  defending_marking_awareness | 55
#  defending_standing_tackle   | 58
#  defending_sliding_tackle    | 58
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 7
#  goalkeeping_positioning     | 11
#  goalkeeping_reflexes        | 10
#  ls                          | 50
#  st                          | 50
#  rs                          | 50
#  lw                          | 52
#  lf                          | 50
#  cf                          | 50
#  rf                          | 50
#  rw                          | 52
#  lam                         | 51
#  cam                         | 51
#  ram                         | 51
#  lm                          | 55
#  lcm                         | 50
#  cm                          | 50
#  rcm                         | 50
#  rm                          | 55
#  lwb                         | 60
#  ldm                         | 55
#  cdm                         | 55
#  rdm                         | 55
#  rwb                         | 60
#  lb                          | 60
#  lcb                         | 58
#  cb                          | 58
#  rcb                         | 58
#  rb                          | 60
#  gk                          | 18
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 233442_2020
# only showing top 1 row

# %%
# Checking whether there are any nullValue

'''missing_values_count = [
    sum(
        when(isnull(c), 1).otherwise(0)
    ).alias(c)
    for c in df_filled.columns
]

df_filled.select(missing_values_count).show()
'''
# Out:
# 'missing_values_count = [\n    sum(\n        when(isnull(c), 1).otherwise(0)\n    ).alias(c)\n    for c in df_filled.columns\n]\n\ndf_filled.select(missing_values_count).show()\n'

# %%
df_cleaned=df_filled

# %%
df_cleaned.describe().show()
# Out:
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+------------------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------+
# |summary|        sofifa_id|short_name|           long_name|player_positions|          overall|        potential|         value_eur|          wage_eur|              age|         height_cm|        weight_kg|      club_team_id|           club_name|         league_name|      league_level|club_position|club_jersey_number|club_joined|club_contract_valid_until|   nationality_id|nationality_name|preferred_foot|         weak_foot|       skill_moves|international_reputation|    work_rate|  body_type|real_face|release_clause_eur|              pace|          shooting|           passing|        dribbling|         defending|           physic|attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing| attacking_volleys|  skill_dribbling|       skill_curve| skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|  movement_agility|movement_reactions|  movement_balance|  power_shot_power|     power_jumping|    power_stamina|    power_strength|  power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|  mentality_vision|mentality_penalties|mentality_composure|defending_marking_awareness|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes|                ls|                st|                rs|                lw|                lf|                cf|                rf|                rw|               lam|               cam|               ram|               lm|               lcm|                cm|               rcm|               rm|              lwb|               ldm|               cdm|               rdm|              rwb|                lb|               lcb|                cb|               rcb|                rb|                gk|              year|            gender|  unique_id|
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+------------------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------+
# |  count|           144323|    144323|              144323|          144323|           144323|           144323|            144323|            144323|           144323|            144323|           144323|            144323|              144323|              144323|            144323|       144323|            144323|     144323|                   144323|           144323|          144323|        144323|            144323|            144323|                  144323|       144323|     144323|   144323|            144323|            144323|            144323|            144323|           144323|            144323|           144323|            144323|             144323|                    144323|                 144323|            144323|           144323|            144323|            144323|            144323|            144323|               144323|               144323|            144323|            144323|            144323|            144323|            144323|           144323|            144323|            144323|              144323|                 144323|               144323|            144323|             144323|             144323|                     144323|                   144323|                  144323|            144323|              144323|             144323|                 144323|              144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|           144323|            144323|            144323|            144323|           144323|           144323|            144323|            144323|            144323|           144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|            144323|     144323|
# |   mean|211967.0790864935|      NULL|                NULL|            NULL|65.87099076377292|70.86494183186325| 1262882.132439043|10922.176991886256|25.13769808000111|181.01369844030404|75.03270441994692| 43342.70739244611|                NULL|                NULL|1.3674119856155984|         NULL|19.911005175890192|       NULL|       2019.9290411091788|55.69959050186041|            NULL|          NULL| 2.941007323849975|2.3306818732980883|      1.1229395176098058|         NULL|       NULL|     NULL| 3330939.614614441| 68.16897514602663|  52.5023038600916|  57.1276788869411|62.24093179881238|  51.7000339516224|65.00577870471096|49.820915585180465|  45.66066392744053|         52.42257990756844|     58.416780416149884| 43.17719975333107|55.25433229630759|47.343181613464246|43.166127367086325| 52.61782252309057| 58.32273442209488|    64.77217075587397|    64.95886310567269| 63.40764119371133|61.800648545276914|   64.035836283891| 56.66906175730826| 65.00749707253868|63.22737193655897| 65.18889574080362| 47.32516646688331|  55.767382884224965|      46.67863750060628|    50.05596474574392| 53.03182444932547|   48.8759934314004| 58.173402714744014|          45.75312320281591|        47.69115802748003|       45.72127796678284|16.578265418540358|  16.326905621418625| 16.187385240051828|     16.334215613588963|  16.690513639544633|55.639544632525656|55.639544632525656|55.639544632525656|55.574690104834296|55.274024237301056|55.274024237301056|55.274024237301056|55.574690104834296| 56.75267282415138| 56.75267282415138| 56.75267282415138|57.42817153191106|56.090311315590725|56.090311315590725|56.090311315590725|57.42817153191106|55.20061944388628| 54.79586067362791| 54.79586067362791| 54.79586067362791|55.20061944388628|54.538264864228154| 53.50648198831787| 53.50648198831787| 53.50648198831787|54.538264864228154|  22.3953701073287|2018.6535687312487|0.9844515427201486|       NULL|
# | stddev|34700.15102127659|      NULL|                NULL|            NULL|7.165768763091349|6.355224353461329|1680216.7493060771|21981.924073673068|4.651591211616676| 6.900499819410027|7.184165890463875|53010.107274168986|                NULL|                NULL|0.7400696834721952|         NULL|16.444055391204607|       NULL|       2.4273514868387376|47.98865708256231|            NULL|          NULL|0.6622066105582084| 0.753631597888462|      0.4193006110730818|         NULL|       NULL|     NULL| 9206404.235527698|10.485010791798151|13.230584938753992|10.005512629861144|9.852782116939386|15.886087433188468|9.183130275532712|18.107046053457225| 19.298064746746654|        17.185308220855124|     14.819393121937035|17.498429194520085|18.65280882473819|18.166695007976408|17.324565424168966|15.375967421332833| 16.64721654130114|   14.681117268180575|   14.413999503125554|14.666365224814886| 9.305932299344253|13.985195065143074|15.840375253442517|11.828016250955157|15.78261010271212|12.625285536233548|19.059216849577485|  17.303372267546745|      20.44735158060652|   19.221942651926597|14.453258499129687| 15.711526044712711| 11.012433092827344|          20.54938167453705|       21.439923679212477|      21.048260468990474| 17.75232106189273|  16.906811174244993|  16.53055312969885|      17.07115084326386|   18.05960087173734|13.603979302805907|13.603979302805907|13.603979302805907|14.446036102123806|14.211419103346614|14.211419103346614|14.211419103346614|14.446036102123806|14.033049860358945|14.033049860358945|14.033049860358945|13.96342232944188| 13.26979149504344| 13.26979149504344| 13.26979149504344|13.96342232944188|13.56328052396174|13.687764044724329|13.687764044724329|13.687764044724329|13.56328052396174|13.880689162741444|14.669554552001522|14.669554552001522|14.669554552001522|13.880689162741444|15.413125952163542| 2.274309403447954|0.1237206887123347|       NULL|
# |    min|                2|     A Lan|A. Benjamin Chiam...|             CAM|               40|               40|              1000|               500|               16|               150|               45|                 1|1. FC Heidenheim ...|Argentina Primera...|                 1|          CAM|                 1| 1991-06-01|                     2014|                1|     Afghanistan|          Left|                 1|                 1|                       1|    High/High|Lean (170-)|       No|              9000|                21|                14|                20|               22|                14|               27|                 5|                  2|                         4|                      7|                 3|                2|                 4|                 3|                 5|                 5|                   11|                   11|                11|                20|                10|                 2|                13|               10|                12|                 3|                   2|                      3|                    2|                 5|                  5|                  3|                          1|                        2|                       3|                 1|                   1|                  1|                      1|                   1|                15|                15|                15|                13|                14|                14|                14|                13|                16|                16|                16|               16|                16|                16|                16|               16|               15|                16|                16|                16|               15|                15|                17|                17|                17|                15|                 4|              2015|                 0|100143_2015|
# |    max|           264640|Ș. Vlădoiu|              李相旭|     ST, RWB, RM|               94|               95|           9500000|            575000|               54|               208|              110|            115820|       Śląsk Wrocław|Venezuelan Primer...|                 5|      Unknown|                99|    Unknown|                     2031|              219|        Zimbabwe|         Right|                 5|                 5|                       5|Medium/Medium|     Unique|      Yes|         373500000|                97|                94|                93|               96|                91|               92|                94|                 95|                        95|                     95|                93|               97|                94|                95|                95|                96|                   97|                   97|                96|                96|                98|                96|                97|               97|                98|                94|                  96|                     93|                   96|                96|                 96|                 96|                         94|                       94|                      95|                91|                  92|                 95|                     92|                  94|                94|                94|                94|                95|                94|                94|                94|                95|                95|                95|                95|               94|                93|                93|                93|               94|               90|                91|                91|                91|               90|                91|                92|                92|                92|                91|                92|              2022|                 1|  9833_2019|
# +-------+-----------------+----------+--------------------+----------------+-----------------+-----------------+------------------+------------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+------------------+-------------+------------------+-----------+-------------------------+-----------------+----------------+--------------+------------------+------------------+------------------------+-------------+-----------+---------+------------------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------------+-----------------------+------------------+-----------------+------------------+------------------+------------------+------------------+---------------------+---------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-----------------------+---------------------+------------------+-------------------+-------------------+---------------------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------+

# %%
df_cleaned.show(vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 233442
#  short_name                  | J. Osei-Tutu
#  long_name                   | Jordi Osei-Tutu
#  player_positions            | RB, RM
#  overall                     | 59
#  potential                   | 75
#  value_eur                   | 325000
#  wage_eur                    | 7000
#  age                         | 20
#  dob                         | 1998-10-02
#  height_cm                   | 178
#  weight_kg                   | 72
#  club_team_id                | 160
#  club_name                   | VfL Bochum 1848
#  league_name                 | German 2. Bundesliga
#  league_level                | 2
#  club_position               | RB
#  club_jersey_number          | 6
#  club_joined                 | 2017-07-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 14
#  nationality_name            | England
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 1300000
#  pace                        | 79
#  shooting                    | 36
#  passing                     | 43
#  dribbling                   | 54
#  defending                   | 55
#  physic                      | 63
#  attacking_crossing          | 49
#  attacking_finishing         | 37
#  attacking_heading_accuracy  | 44
#  attacking_short_passing     | 46
#  attacking_volleys           | 29
#  skill_dribbling             | 50
#  skill_curve                 | 43
#  skill_fk_accuracy           | 34
#  skill_long_passing          | 30
#  skill_ball_control          | 52
#  movement_acceleration       | 77
#  movement_sprint_speed       | 80
#  movement_agility            | 72
#  movement_reactions          | 58
#  movement_balance            | 69
#  power_shot_power            | 33
#  power_jumping               | 62
#  power_stamina               | 68
#  power_strength              | 63
#  power_long_shots            | 35
#  mentality_aggression        | 58
#  mentality_interceptions     | 56
#  mentality_positioning       | 49
#  mentality_vision            | 44
#  mentality_penalties         | 42
#  mentality_composure         | 51
#  defending_marking_awareness | 55
#  defending_standing_tackle   | 58
#  defending_sliding_tackle    | 58
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 7
#  goalkeeping_positioning     | 11
#  goalkeeping_reflexes        | 10
#  ls                          | 50
#  st                          | 50
#  rs                          | 50
#  lw                          | 52
#  lf                          | 50
#  cf                          | 50
#  rf                          | 50
#  rw                          | 52
#  lam                         | 51
#  cam                         | 51
#  ram                         | 51
#  lm                          | 55
#  lcm                         | 50
#  cm                          | 50
#  rcm                         | 50
#  rm                          | 55
#  lwb                         | 60
#  ldm                         | 55
#  cdm                         | 55
#  rdm                         | 55
#  rwb                         | 60
#  lb                          | 60
#  lcb                         | 58
#  cb                          | 58
#  rcb                         | 58
#  rb                          | 60
#  gk                          | 18
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 233442_2020
# -RECORD 1-------------------------------------------
#  sofifa_id                   | 244289
#  short_name                  | K. Bafounta
#  long_name                   | Kamal Bafounta Or...
#  player_positions            | CDM
#  overall                     | 59
#  potential                   | 78
#  value_eur                   | 550000
#  wage_eur                    | 2000
#  age                         | 18
#  dob                         | 2002-01-08
#  height_cm                   | 193
#  weight_kg                   | 81
#  club_team_id                | 22
#  club_name                   | Borussia Dortmund
#  league_name                 | German 1. Bundesliga
#  league_level                | 1
#  club_position               | RES
#  club_jersey_number          | 34
#  club_joined                 | 2018-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 18
#  nationality_name            | France
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (185+)
#  real_face                   | No
#  release_clause_eur          | 698000
#  pace                        | 66
#  shooting                    | 50
#  passing                     | 54
#  dribbling                   | 60
#  defending                   | 57
#  physic                      | 58
#  attacking_crossing          | 39
#  attacking_finishing         | 48
#  attacking_heading_accuracy  | 61
#  attacking_short_passing     | 65
#  attacking_volleys           | 54
#  skill_dribbling             | 59
#  skill_curve                 | 51
#  skill_fk_accuracy           | 44
#  skill_long_passing          | 62
#  skill_ball_control          | 63
#  movement_acceleration       | 65
#  movement_sprint_speed       | 66
#  movement_agility            | 65
#  movement_reactions          | 49
#  movement_balance            | 50
#  power_shot_power            | 57
#  power_jumping               | 59
#  power_stamina               | 52
#  power_strength              | 60
#  power_long_shots            | 46
#  mentality_aggression        | 59
#  mentality_interceptions     | 56
#  mentality_positioning       | 55
#  mentality_vision            | 47
#  mentality_penalties         | 48
#  mentality_composure         | 43
#  defending_marking_awareness | 54
#  defending_standing_tackle   | 62
#  defending_sliding_tackle    | 50
#  goalkeeping_diving          | 8
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 14
#  goalkeeping_positioning     | 13
#  goalkeeping_reflexes        | 10
#  ls                          | 59
#  st                          | 59
#  rs                          | 59
#  lw                          | 56
#  lf                          | 57
#  cf                          | 57
#  rf                          | 57
#  rw                          | 56
#  lam                         | 59
#  cam                         | 59
#  ram                         | 59
#  lm                          | 58
#  lcm                         | 59
#  cm                          | 59
#  rcm                         | 59
#  rm                          | 58
#  lwb                         | 57
#  ldm                         | 60
#  cdm                         | 60
#  rdm                         | 60
#  rwb                         | 57
#  lb                          | 58
#  lcb                         | 60
#  cb                          | 60
#  rcb                         | 60
#  rb                          | 58
#  gk                          | 18
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 244289_2021
# -RECORD 2-------------------------------------------
#  sofifa_id                   | 244490
#  short_name                  | J. Stanić
#  long_name                   | Jozo Stanić
#  player_positions            | CB
#  overall                     | 59
#  potential                   | 72
#  value_eur                   | 525000
#  wage_eur                    | 3000
#  age                         | 21
#  dob                         | 1999-04-06
#  height_cm                   | 188
#  weight_kg                   | 80
#  club_team_id                | 110592
#  club_name                   | FSV Zwickau
#  league_name                 | German 3. Bundesliga
#  league_level                | 3
#  club_position               | SUB
#  club_jersey_number          | 6
#  club_joined                 | 2017-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 10
#  nationality_name            | Croatia
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (185+)
#  real_face                   | No
#  release_clause_eur          | 1300000
#  pace                        | 53
#  shooting                    | 23
#  passing                     | 36
#  dribbling                   | 42
#  defending                   | 61
#  physic                      | 61
#  attacking_crossing          | 28
#  attacking_finishing         | 19
#  attacking_heading_accuracy  | 55
#  attacking_short_passing     | 42
#  attacking_volleys           | 18
#  skill_dribbling             | 36
#  skill_curve                 | 20
#  skill_fk_accuracy           | 27
#  skill_long_passing          | 36
#  skill_ball_control          | 43
#  movement_acceleration       | 53
#  movement_sprint_speed       | 53
#  movement_agility            | 54
#  movement_reactions          | 54
#  movement_balance            | 56
#  power_shot_power            | 31
#  power_jumping               | 62
#  power_stamina               | 52
#  power_strength              | 67
#  power_long_shots            | 22
#  mentality_aggression        | 56
#  mentality_interceptions     | 57
#  mentality_positioning       | 23
#  mentality_vision            | 39
#  mentality_penalties         | 35
#  mentality_composure         | 40
#  defending_marking_awareness | 60
#  defending_standing_tackle   | 66
#  defending_sliding_tackle    | 62
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 7
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 7
#  ls                          | 39
#  st                          | 39
#  rs                          | 39
#  lw                          | 38
#  lf                          | 37
#  cf                          | 37
#  rf                          | 37
#  rw                          | 38
#  lam                         | 40
#  cam                         | 40
#  ram                         | 40
#  lm                          | 41
#  lcm                         | 44
#  cm                          | 44
#  rcm                         | 44
#  rm                          | 41
#  lwb                         | 52
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 52
#  lb                          | 55
#  lcb                         | 61
#  cb                          | 61
#  rcb                         | 61
#  rb                          | 55
#  gk                          | 15
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 244490_2021
# -RECORD 3-------------------------------------------
#  sofifa_id                   | 244494
#  short_name                  | F. Delaveris
#  long_name                   | Filip Møller Dela...
#  player_positions            | CAM, LM, ST
#  overall                     | 59
#  potential                   | 73
#  value_eur                   | 525000
#  wage_eur                    | 2000
#  age                         | 19
#  dob                         | 2000-12-10
#  height_cm                   | 185
#  weight_kg                   | 81
#  club_team_id                | 1909
#  club_name                   | Vitesse
#  league_name                 | Holland Eredivisie
#  league_level                | 1
#  club_position               | RES
#  club_jersey_number          | 15
#  club_joined                 | 2020-01-31
#  club_contract_valid_until   | 2023
#  nationality_id              | 36
#  nationality_name            | Norway
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 691000
#  pace                        | 69
#  shooting                    | 54
#  passing                     | 56
#  dribbling                   | 64
#  defending                   | 20
#  physic                      | 58
#  attacking_crossing          | 58
#  attacking_finishing         | 55
#  attacking_heading_accuracy  | 51
#  attacking_short_passing     | 58
#  attacking_volleys           | 52
#  skill_dribbling             | 64
#  skill_curve                 | 57
#  skill_fk_accuracy           | 54
#  skill_long_passing          | 43
#  skill_ball_control          | 63
#  movement_acceleration       | 68
#  movement_sprint_speed       | 69
#  movement_agility            | 70
#  movement_reactions          | 53
#  movement_balance            | 76
#  power_shot_power            | 56
#  power_jumping               | 67
#  power_stamina               | 63
#  power_strength              | 66
#  power_long_shots            | 50
#  mentality_aggression        | 27
#  mentality_interceptions     | 13
#  mentality_positioning       | 55
#  mentality_vision            | 59
#  mentality_penalties         | 45
#  mentality_composure         | 48
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 11
#  defending_sliding_tackle    | 13
#  goalkeeping_diving          | 8
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 7
#  ls                          | 60
#  st                          | 60
#  rs                          | 60
#  lw                          | 60
#  lf                          | 59
#  cf                          | 59
#  rf                          | 59
#  rw                          | 60
#  lam                         | 61
#  cam                         | 61
#  ram                         | 61
#  lm                          | 62
#  lcm                         | 54
#  cm                          | 54
#  rcm                         | 54
#  rm                          | 62
#  lwb                         | 45
#  ldm                         | 41
#  cdm                         | 41
#  rdm                         | 41
#  rwb                         | 45
#  lb                          | 42
#  lcb                         | 35
#  cb                          | 35
#  rcb                         | 35
#  rb                          | 42
#  gk                          | 16
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 244494_2021
# -RECORD 4-------------------------------------------
#  sofifa_id                   | 244498
#  short_name                  | K. Szymański
#  long_name                   | Karol Szymański
#  player_positions            | GK
#  overall                     | 59
#  potential                   | 60
#  value_eur                   | 190000
#  wage_eur                    | 1000
#  age                         | 27
#  dob                         | 1993-06-25
#  height_cm                   | 192
#  weight_kg                   | 90
#  club_team_id                | 111086
#  club_name                   | Piast Gliwice
#  league_name                 | Polish T-Mobile E...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 33
#  club_joined                 | 2020-07-28
#  club_contract_valid_until   | 2022
#  nationality_id              | 37
#  nationality_name            | Poland
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 185000
#  pace                        | 69
#  shooting                    | 54
#  passing                     | 58
#  dribbling                   | 63
#  defending                   | 56
#  physic                      | 66
#  attacking_crossing          | 18
#  attacking_finishing         | 11
#  attacking_heading_accuracy  | 16
#  attacking_short_passing     | 25
#  attacking_volleys           | 7
#  skill_dribbling             | 9
#  skill_curve                 | 14
#  skill_fk_accuracy           | 12
#  skill_long_passing          | 14
#  skill_ball_control          | 23
#  movement_acceleration       | 20
#  movement_sprint_speed       | 30
#  movement_agility            | 31
#  movement_reactions          | 51
#  movement_balance            | 25
#  power_shot_power            | 45
#  power_jumping               | 39
#  power_stamina               | 23
#  power_strength              | 68
#  power_long_shots            | 8
#  mentality_aggression        | 26
#  mentality_interceptions     | 18
#  mentality_positioning       | 10
#  mentality_vision            | 41
#  mentality_penalties         | 17
#  mentality_composure         | 47
#  defending_marking_awareness | 21
#  defending_standing_tackle   | 15
#  defending_sliding_tackle    | 14
#  goalkeeping_diving          | 61
#  goalkeeping_handling        | 59
#  goalkeeping_kicking         | 60
#  goalkeeping_positioning     | 56
#  goalkeeping_reflexes        | 58
#  ls                          | 26
#  st                          | 26
#  rs                          | 26
#  lw                          | 21
#  lf                          | 23
#  cf                          | 23
#  rf                          | 23
#  rw                          | 21
#  lam                         | 25
#  cam                         | 25
#  ram                         | 25
#  lm                          | 24
#  lcm                         | 26
#  cm                          | 26
#  rcm                         | 26
#  rm                          | 24
#  lwb                         | 24
#  ldm                         | 27
#  cdm                         | 27
#  rdm                         | 27
#  rwb                         | 24
#  lb                          | 24
#  lcb                         | 28
#  cb                          | 28
#  rcb                         | 28
#  rb                          | 24
#  gk                          | 60
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 244498_2021
# -RECORD 5-------------------------------------------
#  sofifa_id                   | 204033
#  short_name                  | N. Devlin
#  long_name                   | Nicholas Devlin
#  player_positions            | RB
#  overall                     | 66
#  potential                   | 67
#  value_eur                   | 925000
#  wage_eur                    | 2000
#  age                         | 26
#  dob                         | 1993-10-17
#  height_cm                   | 183
#  weight_kg                   | 73
#  club_team_id                | 621
#  club_name                   | Livingston FC
#  league_name                 | Scottish Premiership
#  league_level                | 1
#  club_position               | RB
#  club_jersey_number          | 2
#  club_joined                 | 2019-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 42
#  nationality_name            | Scotland
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | High/High
#  body_type                   | Normal (170-185)
#  real_face                   | No
#  release_clause_eur          | 1200000
#  pace                        | 88
#  shooting                    | 52
#  passing                     | 55
#  dribbling                   | 61
#  defending                   | 59
#  physic                      | 78
#  attacking_crossing          | 58
#  attacking_finishing         | 54
#  attacking_heading_accuracy  | 54
#  attacking_short_passing     | 56
#  attacking_volleys           | 40
#  skill_dribbling             | 61
#  skill_curve                 | 55
#  skill_fk_accuracy           | 43
#  skill_long_passing          | 53
#  skill_ball_control          | 56
#  movement_acceleration       | 87
#  movement_sprint_speed       | 89
#  movement_agility            | 71
#  movement_reactions          | 56
#  movement_balance            | 67
#  power_shot_power            | 57
#  power_jumping               | 68
#  power_stamina               | 88
#  power_strength              | 72
#  power_long_shots            | 45
#  mentality_aggression        | 85
#  mentality_interceptions     | 58
#  mentality_positioning       | 57
#  mentality_vision            | 54
#  mentality_penalties         | 50
#  mentality_composure         | 57
#  defending_marking_awareness | 59
#  defending_standing_tackle   | 62
#  defending_sliding_tackle    | 61
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 9
#  goalkeeping_kicking         | 8
#  goalkeeping_positioning     | 11
#  goalkeeping_reflexes        | 14
#  ls                          | 61
#  st                          | 61
#  rs                          | 61
#  lw                          | 61
#  lf                          | 59
#  cf                          | 59
#  rf                          | 59
#  rw                          | 61
#  lam                         | 60
#  cam                         | 60
#  ram                         | 60
#  lm                          | 64
#  lcm                         | 60
#  cm                          | 60
#  rcm                         | 60
#  rm                          | 64
#  lwb                         | 66
#  ldm                         | 63
#  cdm                         | 63
#  rdm                         | 63
#  rwb                         | 66
#  lb                          | 66
#  lcb                         | 65
#  cb                          | 65
#  rcb                         | 65
#  rb                          | 66
#  gk                          | 18
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 204033_2021
# -RECORD 6-------------------------------------------
#  sofifa_id                   | 244508
#  short_name                  | O. Atilgan
#  long_name                   | Osman Atilgan
#  player_positions            | ST, RW
#  overall                     | 59
#  potential                   | 72
#  value_eur                   | 550000
#  wage_eur                    | 1000
#  age                         | 20
#  dob                         | 1999-08-01
#  height_cm                   | 180
#  weight_kg                   | 64
#  club_team_id                | 503
#  club_name                   | SG Dynamo Dresden
#  league_name                 | German 3. Bundesliga
#  league_level                | 3
#  club_position               | RES
#  club_jersey_number          | 8
#  club_joined                 | 2018-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 21
#  nationality_name            | Germany
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 623000
#  pace                        | 76
#  shooting                    | 56
#  passing                     | 51
#  dribbling                   | 63
#  defending                   | 26
#  physic                      | 54
#  attacking_crossing          | 55
#  attacking_finishing         | 61
#  attacking_heading_accuracy  | 55
#  attacking_short_passing     | 55
#  attacking_volleys           | 53
#  skill_dribbling             | 63
#  skill_curve                 | 34
#  skill_fk_accuracy           | 29
#  skill_long_passing          | 42
#  skill_ball_control          | 58
#  movement_acceleration       | 79
#  movement_sprint_speed       | 73
#  movement_agility            | 69
#  movement_reactions          | 59
#  movement_balance            | 76
#  power_shot_power            | 49
#  power_jumping               | 63
#  power_stamina               | 56
#  power_strength              | 55
#  power_long_shots            | 49
#  mentality_aggression        | 45
#  mentality_interceptions     | 24
#  mentality_positioning       | 62
#  mentality_vision            | 56
#  mentality_penalties         | 62
#  mentality_composure         | 52
#  defending_marking_awareness | 24
#  defending_standing_tackle   | 24
#  defending_sliding_tackle    | 17
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 6
#  goalkeeping_kicking         | 13
#  goalkeeping_positioning     | 13
#  goalkeeping_reflexes        | 14
#  ls                          | 61
#  st                          | 61
#  rs                          | 61
#  lw                          | 61
#  lf                          | 60
#  cf                          | 60
#  rf                          | 60
#  rw                          | 61
#  lam                         | 61
#  cam                         | 61
#  ram                         | 61
#  lm                          | 62
#  lcm                         | 54
#  cm                          | 54
#  rcm                         | 54
#  rm                          | 62
#  lwb                         | 47
#  ldm                         | 43
#  cdm                         | 43
#  rdm                         | 43
#  rwb                         | 47
#  lb                          | 45
#  lcb                         | 40
#  cb                          | 40
#  rcb                         | 40
#  rb                          | 45
#  gk                          | 17
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 244508_2021
# -RECORD 7-------------------------------------------
#  sofifa_id                   | 189961
#  short_name                  | V. Kadlec
#  long_name                   | Václav Kadlec
#  player_positions            | ST, RW, LW
#  overall                     | 71
#  potential                   | 72
#  value_eur                   | 2800000
#  wage_eur                    | 800
#  age                         | 27
#  dob                         | 1992-05-20
#  height_cm                   | 181
#  weight_kg                   | 74
#  club_team_id                | 267
#  club_name                   | AC Sparta Praha
#  league_name                 | Czech Republic Ga...
#  league_level                | 1
#  club_position               | RES
#  club_jersey_number          | 14
#  club_joined                 | 2016-09-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 12
#  nationality_name            | Czech Republic
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | High/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 6300000
#  pace                        | 87
#  shooting                    | 69
#  passing                     | 60
#  dribbling                   | 71
#  defending                   | 36
#  physic                      | 62
#  attacking_crossing          | 57
#  attacking_finishing         | 72
#  attacking_heading_accuracy  | 64
#  attacking_short_passing     | 59
#  attacking_volleys           | 65
#  skill_dribbling             | 70
#  skill_curve                 | 63
#  skill_fk_accuracy           | 56
#  skill_long_passing          | 55
#  skill_ball_control          | 70
#  movement_acceleration       | 86
#  movement_sprint_speed       | 87
#  movement_agility            | 82
#  movement_reactions          | 65
#  movement_balance            | 75
#  power_shot_power            | 68
#  power_jumping               | 73
#  power_stamina               | 61
#  power_strength              | 58
#  power_long_shots            | 66
#  mentality_aggression        | 70
#  mentality_interceptions     | 48
#  mentality_positioning       | 72
#  mentality_vision            | 67
#  mentality_penalties         | 59
#  mentality_composure         | 72
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 34
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 11
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 6
#  goalkeeping_positioning     | 7
#  goalkeeping_reflexes        | 6
#  ls                          | 72
#  st                          | 72
#  rs                          | 72
#  lw                          | 70
#  lf                          | 70
#  cf                          | 70
#  rf                          | 70
#  rw                          | 70
#  lam                         | 71
#  cam                         | 71
#  ram                         | 71
#  lm                          | 70
#  lcm                         | 64
#  cm                          | 64
#  rcm                         | 64
#  rm                          | 70
#  lwb                         | 56
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 56
#  lb                          | 54
#  lcb                         | 50
#  cb                          | 50
#  rcb                         | 50
#  rb                          | 54
#  gk                          | 17
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 189961_2020
# -RECORD 8-------------------------------------------
#  sofifa_id                   | 204078
#  short_name                  | R. Wolski
#  long_name                   | Rafał Wolski
#  player_positions            | CAM, CM
#  overall                     | 66
#  potential                   | 67
#  value_eur                   | 975000
#  wage_eur                    | 2000
#  age                         | 27
#  dob                         | 1992-11-10
#  height_cm                   | 180
#  weight_kg                   | 70
#  club_team_id                | 1569
#  club_name                   | Wisła Płock
#  league_name                 | Polish T-Mobile E...
#  league_level                | 1
#  club_position               | RES
#  club_jersey_number          | 21
#  club_joined                 | 2020-03-06
#  club_contract_valid_until   | 2021
#  nationality_id              | 37
#  nationality_name            | Poland
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 4
#  international_reputation    | 1
#  work_rate                   | Medium/Low
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 1100000
#  pace                        | 66
#  shooting                    | 62
#  passing                     | 68
#  dribbling                   | 69
#  defending                   | 34
#  physic                      | 53
#  attacking_crossing          | 69
#  attacking_finishing         | 61
#  attacking_heading_accuracy  | 48
#  attacking_short_passing     | 67
#  attacking_volleys           | 63
#  skill_dribbling             | 68
#  skill_curve                 | 67
#  skill_fk_accuracy           | 67
#  skill_long_passing          | 66
#  skill_ball_control          | 69
#  movement_acceleration       | 71
#  movement_sprint_speed       | 62
#  movement_agility            | 80
#  movement_reactions          | 60
#  movement_balance            | 74
#  power_shot_power            | 68
#  power_jumping               | 69
#  power_stamina               | 47
#  power_strength              | 49
#  power_long_shots            | 61
#  mentality_aggression        | 64
#  mentality_interceptions     | 44
#  mentality_positioning       | 62
#  mentality_vision            | 69
#  mentality_penalties         | 45
#  mentality_composure         | 66
#  defending_marking_awareness | 26
#  defending_standing_tackle   | 32
#  defending_sliding_tackle    | 30
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 10
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 14
#  ls                          | 64
#  st                          | 64
#  rs                          | 64
#  lw                          | 66
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 66
#  lam                         | 67
#  cam                         | 67
#  ram                         | 67
#  lm                          | 67
#  lcm                         | 64
#  cm                          | 64
#  rcm                         | 64
#  rm                          | 67
#  lwb                         | 54
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 54
#  lb                          | 51
#  lcb                         | 46
#  cb                          | 46
#  rcb                         | 46
#  rb                          | 51
# ...
#  short_name                  | L. Bostyn
#  long_name                   | Louis Bostyn
#  player_positions            | GK
#  overall                     | 66
#  potential                   | 69
#  value_eur                   | 850000
#  wage_eur                    | 3000
#  age                         | 26
#  dob                         | 1993-10-04
#  height_cm                   | 196
#  weight_kg                   | 86
#  club_team_id                | 15005
#  club_name                   | SV Zulte Waregem
#  league_name                 | Belgian Jupiler P...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 25
#  club_joined                 | 2014-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 7
#  nationality_name            | Belgium
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 906000
#  pace                        | 69
#  shooting                    | 54
#  passing                     | 58
#  dribbling                   | 63
#  defending                   | 56
#  physic                      | 66
#  attacking_crossing          | 19
#  attacking_finishing         | 5
#  attacking_heading_accuracy  | 5
#  attacking_short_passing     | 20
#  attacking_volleys           | 8
#  skill_dribbling             | 5
#  skill_curve                 | 20
#  skill_fk_accuracy           | 21
#  skill_long_passing          | 19
#  skill_ball_control          | 13
#  movement_acceleration       | 34
#  movement_sprint_speed       | 38
#  movement_agility            | 37
#  movement_reactions          | 58
#  movement_balance            | 32
#  power_shot_power            | 44
#  power_jumping               | 55
#  power_stamina               | 24
#  power_strength              | 65
#  power_long_shots            | 10
#  mentality_aggression        | 36
#  mentality_interceptions     | 13
#  mentality_positioning       | 13
#  mentality_vision            | 32
#  mentality_penalties         | 24
#  mentality_composure         | 35
#  defending_marking_awareness | 13
#  defending_standing_tackle   | 8
#  defending_sliding_tackle    | 7
#  goalkeeping_diving          | 69
#  goalkeeping_handling        | 65
#  goalkeeping_kicking         | 58
#  goalkeeping_positioning     | 67
#  goalkeeping_reflexes        | 66
#  ls                          | 24
#  st                          | 24
#  rs                          | 24
#  lw                          | 20
#  lf                          | 21
#  cf                          | 21
#  rf                          | 21
#  rw                          | 20
#  lam                         | 23
#  cam                         | 23
#  ram                         | 23
#  lm                          | 23
#  lcm                         | 23
#  cm                          | 23
#  rcm                         | 23
#  rm                          | 23
#  lwb                         | 22
#  ldm                         | 23
#  cdm                         | 23
#  rdm                         | 23
#  rwb                         | 22
#  lb                          | 22
#  lcb                         | 24
#  cb                          | 24
#  rcb                         | 24
#  rb                          | 22
#  gk                          | 67
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 201847_2021
# -RECORD 18------------------------------------------
#  sofifa_id                   | 201869
#  short_name                  | R. Teibert
#  long_name                   | Russell Teibert
#  player_positions            | CM, CDM
#  overall                     | 66
#  potential                   | 66
#  value_eur                   | 900000
#  wage_eur                    | 3000
#  age                         | 27
#  dob                         | 1992-12-22
#  height_cm                   | 173
#  weight_kg                   | 66
#  club_team_id                | 101112
#  club_name                   | Vancouver Whiteca...
#  league_name                 | USA Major League ...
#  league_level                | 1
#  club_position               | LCM
#  club_jersey_number          | 31
#  club_joined                 | 2010-07-31
#  club_contract_valid_until   | 2020
#  nationality_id              | 70
#  nationality_name            | Canada
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/High
#  body_type                   | Lean (170-185)
#  real_face                   | Yes
#  release_clause_eur          | 943000
#  pace                        | 56
#  shooting                    | 52
#  passing                     | 67
#  dribbling                   | 68
#  defending                   | 64
#  physic                      | 65
#  attacking_crossing          | 65
#  attacking_finishing         | 51
#  attacking_heading_accuracy  | 46
#  attacking_short_passing     | 73
#  attacking_volleys           | 48
#  skill_dribbling             | 66
#  skill_curve                 | 70
#  skill_fk_accuracy           | 52
#  skill_long_passing          | 65
#  skill_ball_control          | 70
#  movement_acceleration       | 58
#  movement_sprint_speed       | 55
#  movement_agility            | 65
#  movement_reactions          | 67
#  movement_balance            | 90
#  power_shot_power            | 59
#  power_jumping               | 46
#  power_stamina               | 79
#  power_strength              | 57
#  power_long_shots            | 49
#  mentality_aggression        | 70
#  mentality_interceptions     | 62
#  mentality_positioning       | 51
#  mentality_vision            | 62
#  mentality_penalties         | 57
#  mentality_composure         | 67
#  defending_marking_awareness | 70
#  defending_standing_tackle   | 70
#  defending_sliding_tackle    | 53
#  goalkeeping_diving          | 8
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 7
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 11
#  ls                          | 59
#  st                          | 59
#  rs                          | 59
#  lw                          | 62
#  lf                          | 61
#  cf                          | 61
#  rf                          | 61
#  rw                          | 62
#  lam                         | 65
#  cam                         | 65
#  ram                         | 65
#  lm                          | 66
#  lcm                         | 66
#  cm                          | 66
#  rcm                         | 66
#  rm                          | 66
#  lwb                         | 66
#  ldm                         | 66
#  cdm                         | 66
#  rdm                         | 66
#  rwb                         | 66
#  lb                          | 66
#  lcb                         | 65
#  cb                          | 65
#  rcb                         | 65
#  rb                          | 66
#  gk                          | 19
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 201869_2021
# -RECORD 19------------------------------------------
#  sofifa_id                   | 201940
#  short_name                  | Z. MacMath
#  long_name                   | Zac MacMath
#  player_positions            | GK
#  overall                     | 66
#  potential                   | 66
#  value_eur                   | 600000
#  wage_eur                    | 2000
#  age                         | 28
#  dob                         | 1991-08-07
#  height_cm                   | 188
#  weight_kg                   | 88
#  club_team_id                | 111065
#  club_name                   | Real Salt Lake
#  league_name                 | USA Major League ...
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 18
#  club_joined                 | 2019-12-17
#  club_contract_valid_until   | 2020
#  nationality_id              | 95
#  nationality_name            | United States
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 689000
#  pace                        | 69
#  shooting                    | 54
#  passing                     | 58
#  dribbling                   | 63
#  defending                   | 56
#  physic                      | 66
#  attacking_crossing          | 19
#  attacking_finishing         | 18
#  attacking_heading_accuracy  | 14
#  attacking_short_passing     | 29
#  attacking_volleys           | 10
#  skill_dribbling             | 13
#  skill_curve                 | 16
#  skill_fk_accuracy           | 14
#  skill_long_passing          | 38
#  skill_ball_control          | 16
#  movement_acceleration       | 39
#  movement_sprint_speed       | 34
#  movement_agility            | 36
#  movement_reactions          | 62
#  movement_balance            | 44
#  power_shot_power            | 41
#  power_jumping               | 56
#  power_stamina               | 31
#  power_strength              | 56
#  power_long_shots            | 15
#  mentality_aggression        | 38
#  mentality_interceptions     | 14
#  mentality_positioning       | 13
#  mentality_vision            | 41
#  mentality_penalties         | 17
#  mentality_composure         | 48
#  defending_marking_awareness | 18
#  defending_standing_tackle   | 9
#  defending_sliding_tackle    | 8
#  goalkeeping_diving          | 66
#  goalkeeping_handling        | 64
#  goalkeeping_kicking         | 54
#  goalkeeping_positioning     | 67
#  goalkeeping_reflexes        | 67
#  ls                          | 28
#  st                          | 28
#  rs                          | 28
#  lw                          | 25
#  lf                          | 26
#  cf                          | 26
#  rf                          | 26
#  rw                          | 25
#  lam                         | 29
#  cam                         | 29
#  ram                         | 29
#  lm                          | 29
#  lcm                         | 30
#  cm                          | 30
#  rcm                         | 30
#  rm                          | 29
#  lwb                         | 25
#  ldm                         | 29
#  cdm                         | 29
#  rdm                         | 29
#  rwb                         | 25
#  lb                          | 24
#  lcb                         | 26
#  cb                          | 26
#  rcb                         | 26
#  rb                          | 24
#  gk                          | 66
#  year                        | 2021
#  gender                      | 1
#  unique_id                   | 201940_2021
# only showing top 20 rows

# %% [markdown]
# ### **E. Data Ingestion**

# %%
#overwrite it to PostgresSQL database
df_cleaned.write.format("jdbc")\
.mode("overwrite")\
.option("url", db_properties['url'])\
.option("dbtable", 'fifa.fifa_cleaned')\
.option("user", db_properties['username'])\
.option("password", db_properties['password'])\
.option("Driver", db_properties['driver'])\
.save()

# %%
db_properties['table']='fifa.fifa_cleaned'

# %% [markdown]
# ## **TASK II**

# %% [markdown]
# ### **A. Contract Finish**

# %%
df_read = sqlContext.read.format("jdbc")\
    .option("url", db_properties['url'])\
    .option("dbtable", db_properties['table'])\
    .option("user", db_properties['username'])\
    .option("password", db_properties['password'])\
    .option("Driver", db_properties['driver'])\
    .load()
df_read=df_read.filter(col('gender')==1)
df_read.show(1, vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 231131
#  player_url                  | https://sofifa.co...
#  short_name                  | J. McGarry
#  long_name                   | James Robert McGarry
#  player_positions            | LW, LB
#  overall                     | 54
#  potential                   | 64
#  value_eur                   | 110000.0
#  wage_eur                    | 2000.0
#  age                         | 20
#  dob                         | 1998-04-09
#  height_cm                   | 179
#  weight_kg                   | 72
#  club_team_id                | 1907.0
#  club_name                   | Willem II
#  league_name                 | Holland Eredivisie
#  league_level                | 1
#  club_position               | RES
#  club_jersey_number          | 24
#  club_loaned_from            | NULL
#  club_joined                 | 2018-07-11
#  club_contract_valid_until   | 2020
#  nationality_id              | 198
#  nationality_name            | New Zealand
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | High/Medium
#  body_type                   | Normal (170-185)
#  real_face                   | No
#  release_clause_eur          | 182000
#  player_tags                 | NULL
#  player_traits               | Selfish
#  pace                        | 71
#  shooting                    | 48
#  passing                     | 50
#  dribbling                   | 58
#  defending                   | 47
#  physic                      | 53
#  attacking_crossing          | 48
#  attacking_finishing         | 51
#  attacking_heading_accuracy  | 35
#  attacking_short_passing     | 47
#  attacking_volleys           | 35
#  skill_dribbling             | 61
#  skill_curve                 | 54
#  skill_fk_accuracy           | 57
#  skill_long_passing          | 46
#  skill_ball_control          | 53
#  movement_acceleration       | 76
#  movement_sprint_speed       | 66
#  movement_agility            | 59
#  movement_reactions          | 45
#  movement_balance            | 70
#  power_shot_power            | 55
#  power_jumping               | 60
#  power_stamina               | 52
#  power_strength              | 59
#  power_long_shots            | 39
#  mentality_aggression        | 39
#  mentality_interceptions     | 46
#  mentality_positioning       | 46
#  mentality_vision            | 56
#  mentality_penalties         | 44
#  mentality_composure         | 53
#  defending_marking_awareness | 52
#  defending_standing_tackle   | 48
#  defending_sliding_tackle    | 47
#  goalkeeping_diving          | 5
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 6
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 9
#  goalkeeping_speed           | NULL
#  ls                          | 51+1
#  st                          | 51+1
#  rs                          | 51+1
#  lw                          | 54
#  lf                          | 53
#  cf                          | 53
#  rf                          | 53
#  rw                          | 54
#  lam                         | 53+1
#  cam                         | 53+1
#  ram                         | 53+1
#  lm                          | 54+1
#  lcm                         | 50+1
#  cm                          | 50+1
#  rcm                         | 50+1
#  rm                          | 54+1
#  lwb                         | 51+1
#  ldm                         | 49+1
#  cdm                         | 49+1
#  rdm                         | 49+1
#  rwb                         | 51+1
#  lb                          | 50+1
#  lcb                         | 48+1
#  cb                          | 48+1
#  rcb                         | 48+1
#  rb                          | 50+1
#  gk                          | 13+1
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2019
#  gender                      | 1
#  unique_id                   | 231131_2019
# only showing top 1 row

# %%
x = 2015  
y = 5   
z = 2018

# %%
from pyspark.sql import functions as F
df_filter=df_read.filter((df_read['year']==x)&(df_read['club_contract_valid_until']>=z))
df_agg=df_filter.groupBy('club_name').agg(F.count('sofifa_id').alias('player_count'))
df_club_order=df_agg.orderBy(F.desc('player_count')).limit(y)
df_club_order.select('club_name').show()
# Out:
# +----------------+
# |       club_name|
# +----------------+
# |         Unknown|
# |  Fortaleza CEIF|
# |   CD Huachipato|
# | Boyacá Chicó FC|
# |Rionegro Águilas|
# +----------------+

# %% [markdown]
# ### **B. top players count**

# %%
from pyspark.sql import Window
df_agg=df_read.groupBy('year','nationality_name').agg(F.count('sofifa_id').alias('players_count'))
windows=Window.partitionBy('year')
windows_desc=windows.orderBy(F.desc('players_count'))
df_year_nation_rank=df_agg.withColumn('rank',F.row_number().over(windows_desc))
df_rank1=df_year_nation_rank.filter(F.col('rank')==1).select('year', 'nationality_name', 'players_count').show()
# Out:
# +----+----------------+-------------+
# |year|nationality_name|players_count|
# +----+----------------+-------------+
# |2015|         England|         1627|
# |2016|         England|         1519|
# |2017|         England|         1627|
# |2018|         England|         1633|
# |2019|         England|         1625|
# |2020|         England|         1670|
# |2021|         England|         1685|
# |2022|         England|         1719|
# +----+----------------+-------------+

# %% [markdown]
# ### **C. Extreme Average Age**

# %%
df=df_read

# %%
import sys
from pyspark.sql.functions import avg, desc,asc, col
x=5
y=2015
sequence='desc'
if x<=0:
    print('error')
    sys.exit()
df_year=df.filter(df['year']==y)
df_club=df_year.groupBy('club_name')
df_avg=df_club.agg(avg('age').alias('avg_age'))
if sequence=='desc':
    df_seq=df_avg.orderBy(desc('avg_age'))
elif sequence=='asc':
    df_seq=df_avg.orderBy(asc('avg_age'))

# %%
df_rows=df_seq.limit(x).collect()
last_row=df_rows[-1]
df_same=df_seq.filter(col('avg_age')==last_row['avg_age']).collect()

df_other=[row for row in df_rows if row['avg_age']!=last_row['avg_age']]
df_final=df_other+df_same
df_final
# Out:
# [Row(club_name='Cruz Azul', avg_age=28.071428571428573),
#  Row(club_name='Arsenal Tula', avg_age=28.04),
#  Row(club_name='Podbeskidzie Bielsko-Biała', avg_age=27.962962962962962),
#  Row(club_name='Fenerbahçe SK', avg_age=27.88),
#  Row(club_name='Leones Negros de la UdeG', avg_age=27.79310344827586)]

# %% [markdown]
# ## **TASK III**

# %% [markdown]
# ### **A. Read The Data Back**

# %%
# if you have already started a spark session, there is no need to run this cell again
import findspark
findspark.init()
findspark.find()
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SQLContext

# Create Configuration object for Spark.
conf = pyspark.SparkConf()\
 .set('spark.driver.host','127.0.0.1')\
 .setAppName('SPARK-POSTGRES')\
 .setMaster("local[*]")\
 .set("spark.jars", "C:\spark\spark-3.5.2-bin-hadoop3\postgresql-42.7.4.jar")

# need to change the postgresql path 

# Create Spark Context with the new configurations rather than relying on the default 
sc = SparkContext.getOrCreate(conf=conf)
# You need to create SQL Context to conduct some database operations like what we will
sqlContext = SQLContext(sc)
# If you have SQL context, you create the session from the Spark Context
spark = sqlContext.sparkSession.builder.getOrCreate()
# Out:
# C:\spark\spark-3.5.2-bin-hadoop3\python\pyspark\sql\context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
from pyspark.sql.functions import col, when, isnull, count, lit, avg, sum, isnan, desc, row_number, expr, regexp_extract, concat
from pyspark.sql.functions import *
from pyspark.sql import Row
from pyspark.sql.types import StringType, IntegerType, FloatType, DoubleType

import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SQLContext

# %%
# DO this everytime reopening the ipynb
# change the username, password, table name.
db_properties={}
db_properties['username']="postgres"  
#db_properties['password']='714179'
db_properties['password']="YYAAOOdaren200@"
db_properties['url']= "jdbc:postgresql://localhost:5432/postgres"
# db_properties['table']=Your Table name and Schema
db_properties['table']='fifa.fifa_cleaned' 
db_properties['driver']="org.postgresql.Driver"

# %%
df_read = sqlContext.read.format("jdbc")\
    .option("url", db_properties['url'])\
    .option("dbtable", db_properties['table'])\
    .option("user", db_properties['username'])\
    .option("password", db_properties['password'])\
    .option("Driver", db_properties['driver'])\
    .load()
df_read=df_read.filter(col('gender')==1)
df_read.show(1, vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 224189
#  short_name                  | Y. Barbet
#  long_name                   | Yoann Barbet
#  player_positions            | CB, LB
#  overall                     | 71
#  potential                   | 74
#  value_eur                   | 2600000
#  wage_eur                    | 7000
#  age                         | 26
#  dob                         | 1993-05-10
#  height_cm                   | 187
#  weight_kg                   | 81
#  club_team_id                | 15
#  club_name                   | Queens Park Rangers
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | LCB
#  club_jersey_number          | 29
#  club_joined                 | 2019-07-01
#  club_contract_valid_until   | 2022
#  nationality_id              | 18
#  nationality_name            | France
#  preferred_foot              | Left
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 5200000
#  pace                        | 69
#  shooting                    | 50
#  passing                     | 67
#  dribbling                   | 64
#  defending                   | 70
#  physic                      | 72
#  attacking_crossing          | 66
#  attacking_finishing         | 36
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 64
#  attacking_volleys           | 51
#  skill_dribbling             | 63
#  skill_curve                 | 65
#  skill_fk_accuracy           | 75
#  skill_long_passing          | 73
#  skill_ball_control          | 66
#  movement_acceleration       | 67
#  movement_sprint_speed       | 70
#  movement_agility            | 61
#  movement_reactions          | 68
#  movement_balance            | 54
#  power_shot_power            | 68
#  power_jumping               | 60
#  power_stamina               | 70
#  power_strength              | 76
#  power_long_shots            | 58
#  mentality_aggression        | 68
#  mentality_interceptions     | 69
#  mentality_positioning       | 55
#  mentality_vision            | 66
#  mentality_penalties         | 58
#  mentality_composure         | 66
#  defending_marking_awareness | 69
#  defending_standing_tackle   | 72
#  defending_sliding_tackle    | 72
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 13
#  ls                          | 62
#  st                          | 62
#  rs                          | 62
#  lw                          | 61
#  lf                          | 61
#  cf                          | 61
#  rf                          | 61
#  rw                          | 61
#  lam                         | 64
#  cam                         | 64
#  ram                         | 64
#  lm                          | 66
#  lcm                         | 68
#  cm                          | 68
#  rcm                         | 68
#  rm                          | 66
#  lwb                         | 70
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 70
#  lb                          | 71
#  lcb                         | 72
#  cb                          | 72
#  rcb                         | 72
#  rb                          | 71
#  gk                          | 20
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224189_2020
# only showing top 1 row

# %% [markdown]
# ### **B. Phase 2 of Data Engineering**

# %% [markdown]
# #### Run these codes: (1)->(7)

# %% [markdown]
# **(1) Contract year calculation**

# %%
from pyspark.sql import functions as F
df_read = df_read.withColumn("contract_years_remaining", F.col("club_contract_valid_until") - F.year(F.col("club_joined")))
df_read.show(20, vertical = True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 224189
#  short_name                  | Y. Barbet
#  long_name                   | Yoann Barbet
#  player_positions            | CB, LB
#  overall                     | 71
#  potential                   | 74
#  value_eur                   | 2600000
#  wage_eur                    | 7000
#  age                         | 26
#  dob                         | 1993-05-10
#  height_cm                   | 187
#  weight_kg                   | 81
#  club_team_id                | 15
#  club_name                   | Queens Park Rangers
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | LCB
#  club_jersey_number          | 29
#  club_joined                 | 2019-07-01
#  club_contract_valid_until   | 2022
#  nationality_id              | 18
#  nationality_name            | France
#  preferred_foot              | Left
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 5200000
#  pace                        | 69
#  shooting                    | 50
#  passing                     | 67
#  dribbling                   | 64
#  defending                   | 70
#  physic                      | 72
#  attacking_crossing          | 66
#  attacking_finishing         | 36
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 64
#  attacking_volleys           | 51
#  skill_dribbling             | 63
#  skill_curve                 | 65
#  skill_fk_accuracy           | 75
#  skill_long_passing          | 73
#  skill_ball_control          | 66
#  movement_acceleration       | 67
#  movement_sprint_speed       | 70
#  movement_agility            | 61
#  movement_reactions          | 68
#  movement_balance            | 54
#  power_shot_power            | 68
#  power_jumping               | 60
#  power_stamina               | 70
#  power_strength              | 76
#  power_long_shots            | 58
#  mentality_aggression        | 68
#  mentality_interceptions     | 69
#  mentality_positioning       | 55
#  mentality_vision            | 66
#  mentality_penalties         | 58
#  mentality_composure         | 66
#  defending_marking_awareness | 69
#  defending_standing_tackle   | 72
#  defending_sliding_tackle    | 72
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 13
#  ls                          | 62
#  st                          | 62
#  rs                          | 62
#  lw                          | 61
#  lf                          | 61
#  cf                          | 61
#  rf                          | 61
#  rw                          | 61
#  lam                         | 64
#  cam                         | 64
#  ram                         | 64
#  lm                          | 66
#  lcm                         | 68
#  cm                          | 68
#  rcm                         | 68
#  rm                          | 66
#  lwb                         | 70
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 70
#  lb                          | 71
#  lcb                         | 72
#  cb                          | 72
#  rcb                         | 72
#  rb                          | 71
#  gk                          | 20
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224189_2020
#  contract_years_remaining    | 3
# -RECORD 1-------------------------------------------
#  sofifa_id                   | 224317
#  short_name                  | J. Cabrera
#  long_name                   | Marcelo Javier Ca...
#  player_positions            | RM, LM, RW
#  overall                     | 71
#  potential                   | 71
#  value_eur                   | 2500000
#  wage_eur                    | 9000
#  age                         | 27
#  dob                         | 1992-03-18
#  height_cm                   | 167
#  weight_kg                   | 63
#  club_team_id                | 112224
#  club_name                   | Melbourne City FC
#  league_name                 | Australian Hyunda...
#  league_level                | 1
#  club_position               | LM
#  club_jersey_number          | 8
#  club_joined                 | 2019-07-24
#  club_contract_valid_until   | 2021
#  nationality_id              | 60
#  nationality_name            | Uruguay
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Low
#  body_type                   | Normal (170-)
#  real_face                   | No
#  release_clause_eur          | 3100000
#  pace                        | 83
#  shooting                    | 60
#  passing                     | 66
#  dribbling                   | 71
#  defending                   | 32
#  physic                      | 60
#  attacking_crossing          | 74
#  attacking_finishing         | 56
#  attacking_heading_accuracy  | 37
#  attacking_short_passing     | 65
#  attacking_volleys           | 50
#  skill_dribbling             | 73
#  skill_curve                 | 57
#  skill_fk_accuracy           | 43
#  skill_long_passing          | 65
#  skill_ball_control          | 65
#  movement_acceleration       | 81
#  movement_sprint_speed       | 84
#  movement_agility            | 75
#  movement_reactions          | 66
#  movement_balance            | 89
#  power_shot_power            | 65
#  power_jumping               | 59
#  power_stamina               | 70
#  power_strength              | 53
#  power_long_shots            | 62
#  mentality_aggression        | 66
#  mentality_interceptions     | 31
#  mentality_positioning       | 68
#  mentality_vision            | 70
#  mentality_penalties         | 63
#  mentality_composure         | 65
#  defending_marking_awareness | 24
#  defending_standing_tackle   | 33
#  defending_sliding_tackle    | 46
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 6
#  goalkeeping_reflexes        | 10
#  ls                          | 64
#  st                          | 64
#  rs                          | 64
#  lw                          | 69
#  lf                          | 67
#  cf                          | 67
#  rf                          | 67
#  rw                          | 69
#  lam                         | 70
#  cam                         | 70
#  ram                         | 70
#  lm                          | 71
#  lcm                         | 65
#  cm                          | 65
#  rcm                         | 65
#  rm                          | 71
#  lwb                         | 59
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 59
#  lb                          | 56
#  lcb                         | 46
#  cb                          | 46
#  rcb                         | 46
#  rb                          | 56
#  gk                          | 19
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224317_2020
#  contract_years_remaining    | 2
# -RECORD 2-------------------------------------------
#  sofifa_id                   | 224336
#  short_name                  | T. Romanczuk
#  long_name                   | Taras Wiktorowicz...
#  player_positions            | CDM
#  overall                     | 71
#  potential                   | 71
#  value_eur                   | 2200000
#  wage_eur                    | 7000
#  age                         | 27
#  dob                         | 1991-11-14
#  height_cm                   | 186
#  weight_kg                   | 77
#  club_team_id                | 110745
#  club_name                   | Jagiellonia Biały...
#  league_name                 | Polish T-Mobile E...
#  league_level                | 1
#  club_position               | LDM
#  club_jersey_number          | 6
#  club_joined                 | 2014-07-22
#  club_contract_valid_until   | 2023
#  nationality_id              | 37
#  nationality_name            | Poland
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | High/High
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | 3000000
#  pace                        | 64
#  shooting                    | 64
#  passing                     | 65
#  dribbling                   | 62
#  defending                   | 70
#  physic                      | 77
#  attacking_crossing          | 60
#  attacking_finishing         | 65
#  attacking_heading_accuracy  | 66
#  attacking_short_passing     | 70
#  attacking_volleys           | 35
#  skill_dribbling             | 61
#  skill_curve                 | 60
#  skill_fk_accuracy           | 43
#  skill_long_passing          | 67
#  skill_ball_control          | 60
#  movement_acceleration       | 69
#  movement_sprint_speed       | 60
#  movement_agility            | 69
#  movement_reactions          | 74
#  movement_balance            | 62
#  power_shot_power            | 68
#  power_jumping               | 78
#  power_stamina               | 91
#  power_strength              | 72
#  power_long_shots            | 63
#  mentality_aggression        | 71
#  mentality_interceptions     | 73
#  mentality_positioning       | 67
#  mentality_vision            | 64
#  mentality_penalties         | 63
#  mentality_composure         | 64
#  defending_marking_awareness | 71
#  defending_standing_tackle   | 69
#  defending_sliding_tackle    | 65
#  goalkeeping_diving          | 15
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 8
#  goalkeeping_reflexes        | 9
#  ls                          | 67
#  st                          | 67
#  rs                          | 67
#  lw                          | 64
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 64
#  lam                         | 67
#  cam                         | 67
#  ram                         | 67
#  lm                          | 68
#  lcm                         | 70
#  cm                          | 70
#  rcm                         | 70
#  rm                          | 68
#  lwb                         | 71
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 71
#  lb                          | 71
#  lcb                         | 71
#  cb                          | 71
#  rcb                         | 71
#  rb                          | 71
#  gk                          | 20
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224336_2020
#  contract_years_remaining    | 9
# -RECORD 3-------------------------------------------
#  sofifa_id                   | 224348
#  short_name                  | L. Hoyos
#  long_name                   | Lucas Adrián Hoyos
#  player_positions            | GK
#  overall                     | 71
#  potential                   | 72
#  value_eur                   | 1800000
#  wage_eur                    | 8000
#  age                         | 30
#  dob                         | 1989-04-29
#  height_cm                   | 183
#  weight_kg                   | 76
#  club_team_id                | 101088
#  club_name                   | Vélez Sarsfield
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 12
#  club_joined                 | 2018-07-23
#  club_contract_valid_until   | 2022
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (170-185)
#  real_face                   | No
#  release_clause_eur          | 2900000
#  pace                        | 69
#  shooting                    | 54
#  passing                     | 58
#  dribbling                   | 63
#  defending                   | 56
#  physic                      | 66
#  attacking_crossing          | 20
#  attacking_finishing         | 12
#  attacking_heading_accuracy  | 18
#  attacking_short_passing     | 35
#  attacking_volleys           | 20
#  skill_dribbling             | 21
#  skill_curve                 | 18
#  skill_fk_accuracy           | 20
#  skill_long_passing          | 26
#  skill_ball_control          | 29
#  movement_acceleration       | 58
#  movement_sprint_speed       | 54
#  movement_agility            | 50
#  movement_reactions          | 68
#  movement_balance            | 60
#  power_shot_power            | 49
#  power_jumping               | 70
#  power_stamina               | 40
#  power_strength              | 62
#  power_long_shots            | 16
#  mentality_aggression        | 32
#  mentality_interceptions     | 24
#  mentality_positioning       | 17
#  mentality_vision            | 47
#  mentality_penalties         | 26
#  mentality_composure         | 51
#  defending_marking_awareness | 16
#  defending_standing_tackle   | 20
#  defending_sliding_tackle    | 22
#  goalkeeping_diving          | 77
#  goalkeeping_handling        | 68
#  goalkeeping_kicking         | 65
#  goalkeeping_positioning     | 65
#  goalkeeping_reflexes        | 74
#  ls                          | 34
#  st                          | 34
#  rs                          | 34
#  lw                          | 32
#  lf                          | 33
#  cf                          | 33
#  rf                          | 33
#  rw                          | 32
#  lam                         | 36
#  cam                         | 36
#  ram                         | 36
#  lm                          | 36
#  lcm                         | 35
#  cm                          | 35
#  rcm                         | 35
#  rm                          | 36
#  lwb                         | 34
#  ldm                         | 34
#  cdm                         | 34
#  rdm                         | 34
#  rwb                         | 34
#  lb                          | 34
#  lcb                         | 33
#  cb                          | 33
#  rcb                         | 33
#  rb                          | 34
#  gk                          | 72
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224348_2020
#  contract_years_remaining    | 4
# -RECORD 4-------------------------------------------
#  sofifa_id                   | 224444
#  short_name                  | H. Belkebla
#  long_name                   | Haris Belkebla
#  player_positions            | CDM, CM
#  overall                     | 71
#  potential                   | 75
#  value_eur                   | 2800000
#  wage_eur                    | 11000
#  age                         | 25
#  dob                         | 1994-01-28
#  height_cm                   | 177
#  weight_kg                   | 68
#  club_team_id                | 378
#  club_name                   | Stade Brestois 29
#  league_name                 | French Ligue 1
#  league_level                | 1
#  club_position               | RCM
#  club_jersey_number          | 7
#  club_joined                 | 2018-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 97
#  nationality_name            | Algeria
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 5700000
#  pace                        | 64
#  shooting                    | 54
#  passing                     | 67
#  dribbling                   | 71
#  defending                   | 66
#  physic                      | 71
#  attacking_crossing          | 57
#  attacking_finishing         | 52
#  attacking_heading_accuracy  | 55
#  attacking_short_passing     | 72
#  attacking_volleys           | 47
#  skill_dribbling             | 72
#  skill_curve                 | 56
#  skill_fk_accuracy           | 64
#  skill_long_passing          | 72
#  skill_ball_control          | 72
#  movement_acceleration       | 64
#  movement_sprint_speed       | 64
#  movement_agility            | 61
#  movement_reactions          | 67
#  movement_balance            | 72
#  power_shot_power            | 61
#  power_jumping               | 52
#  power_stamina               | 85
#  power_strength              | 65
#  power_long_shots            | 51
#  mentality_aggression        | 75
#  mentality_interceptions     | 66
#  mentality_positioning       | 61
#  mentality_vision            | 70
#  mentality_penalties         | 65
#  mentality_composure         | 69
#  defending_marking_awareness | 67
#  defending_standing_tackle   | 70
#  defending_sliding_tackle    | 65
#  goalkeeping_diving          | 8
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 16
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 15
#  ls                          | 64
#  st                          | 64
#  rs                          | 64
#  lw                          | 65
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 65
#  lam                         | 69
#  cam                         | 69
#  ram                         | 69
#  lm                          | 70
#  lcm                         | 72
#  cm                          | 72
#  rcm                         | 72
#  rm                          | 70
#  lwb                         | 70
#  ldm                         | 72
#  cdm                         | 72
#  rdm                         | 72
#  rwb                         | 70
#  lb                          | 69
#  lcb                         | 68
#  cb                          | 68
#  rcb                         | 68
#  rb                          | 69
#  gk                          | 21
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224444_2020
#  contract_years_remaining    | 3
# -RECORD 5-------------------------------------------
#  sofifa_id                   | 224461
#  short_name                  | W. Montoya
#  long_name                   | Walter Iván Alexi...
#  player_positions            | RM, CM
#  overall                     | 71
#  potential                   | 72
#  value_eur                   | 2800000
#  wage_eur                    | 16000
#  age                         | 25
#  dob                         | 1993-07-21
#  height_cm                   | 175
#  weight_kg                   | 73
#  club_team_id                | 101085
#  club_name                   | Racing Club
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 32
#  club_joined                 | 2017-07-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (170-185)
#  real_face                   | No
#  release_clause_eur          | 1300000
#  pace                        | 78
#  shooting                    | 60
#  passing                     | 66
#  dribbling                   | 74
#  defending                   | 38
#  physic                      | 59
#  attacking_crossing          | 66
#  attacking_finishing         | 54
#  attacking_heading_accuracy  | 46
#  attacking_short_passing     | 64
#  attacking_volleys           | 48
#  skill_dribbling             | 78
#  skill_curve                 | 65
#  skill_fk_accuracy           | 52
#  skill_long_passing          | 65
#  skill_ball_control          | 69
#  movement_acceleration       | 79
#  movement_sprint_speed       | 78
#  movement_agility            | 76
#  movement_reactions          | 66
#  movement_balance            | 72
#  power_shot_power            | 62
#  power_jumping               | 61
#  power_stamina               | 65
#  power_strength              | 59
#  power_long_shots            | 77
#  mentality_aggression        | 53
#  mentality_interceptions     | 28
#  mentality_positioning       | 68
#  mentality_vision            | 74
#  mentality_penalties         | 51
#  mentality_composure         | 60
#  defending_marking_awareness | 39
#  defending_standing_tackle   | 40
#  defending_sliding_tackle    | 38
#  goalkeeping_diving          | 9
#  goalkeeping_handling        | 10
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 15
#  goalkeeping_reflexes        | 13
#  ls                          | 65
#  st                          | 65
#  rs                          | 65
#  lw                          | 70
#  lf                          | 69
#  cf                          | 69
#  rf                          | 69
#  rw                          | 70
#  lam                         | 72
#  cam                         | 72
#  ram                         | 72
#  lm                          | 72
#  lcm                         | 67
#  cm                          | 67
#  rcm                         | 67
#  rm                          | 72
#  lwb                         | 58
#  ldm                         | 55
#  cdm                         | 55
#  rdm                         | 55
#  rwb                         | 58
#  lb                          | 55
#  lcb                         | 49
#  cb                          | 49
#  rcb                         | 49
#  rb                          | 55
#  gk                          | 20
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224461_2020
#  contract_years_remaining    | 3
# -RECORD 6-------------------------------------------
#  sofifa_id                   | 224524
#  short_name                  | E. Burgos
#  long_name                   | Esteban Rodrigo B...
#  player_positions            | CB
#  overall                     | 71
#  potential                   | 74
#  value_eur                   | 2600000
#  wage_eur                    | 13000
#  age                         | 27
#  dob                         | 1992-01-09
#  height_cm                   | 190
#  weight_kg                   | 80
#  club_team_id                | 467
#  club_name                   | SD Eibar
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 2
#  club_joined                 | 2019-07-01
#  club_contract_valid_until   | 2022
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/High
#  body_type                   | Lean (185+)
#  real_face                   | No
#  release_clause_eur          | 5600000
#  pace                        | 48
#  shooting                    | 34
#  passing                     | 46
#  dribbling                   | 52
#  defending                   | 71
#  physic                      | 80
#  attacking_crossing          | 35
#  attacking_finishing         | 23
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 61
#  attacking_volleys           | 32
#  skill_dribbling             | 48
#  skill_curve                 | 35
#  skill_fk_accuracy           | 26
#  skill_long_passing          | 48
#  skill_ball_control          | 57
#  movement_acceleration       | 49
#  movement_sprint_speed       | 48
#  movement_agility            | 53
#  movement_reactions          | 69
#  movement_balance            | 46
#  power_shot_power            | 61
#  power_jumping               | 52
#  power_stamina               | 79
#  power_strength              | 87
#  power_long_shots            | 30
#  mentality_aggression        | 73
#  mentality_interceptions     | 73
#  mentality_positioning       | 32
#  mentality_vision            | 35
#  mentality_penalties         | 54
#  mentality_composure         | 62
#  defending_marking_awareness | 70
#  defending_standing_tackle   | 70
#  defending_sliding_tackle    | 70
#  goalkeeping_diving          | 15
#  goalkeeping_handling        | 9
#  goalkeeping_kicking         | 13
#  goalkeeping_positioning     | 7
#  goalkeeping_reflexes        | 12
#  ls                          | 51
#  st                          | 51
#  rs                          | 51
#  lw                          | 46
#  lf                          | 47
#  cf                          | 47
#  rf                          | 47
#  rw                          | 46
#  lam                         | 49
#  cam                         | 49
#  ram                         | 49
#  lm                          | 51
#  lcm                         | 55
#  cm                          | 55
#  rcm                         | 55
#  rm                          | 51
#  lwb                         | 64
#  ldm                         | 68
#  cdm                         | 68
#  rdm                         | 68
#  rwb                         | 64
#  lb                          | 66
#  lcb                         | 72
#  cb                          | 72
#  rcb                         | 72
#  rb                          | 66
#  gk                          | 19
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224524_2020
#  contract_years_remaining    | 3
# -RECORD 7-------------------------------------------
#  sofifa_id                   | 224542
#  short_name                  | N. Leyes
#  long_name                   | Nery Francisco Leyes
#  player_positions            | CDM, CM
#  overall                     | 71
#  potential                   | 71
#  value_eur                   | 2000000
#  wage_eur                    | 3000
#  age                         | 29
#  dob                         | 1989-09-05
#  height_cm                   | 181
#  weight_kg                   | 78
#  club_team_id                | 112533
#  club_name                   | CD Antofagasta
#  league_name                 | Chilian Campeonat...
#  league_level                | 1
#  club_position               | CDM
#  club_jersey_number          | 16
#  club_joined                 | 2019-01-01
#  club_contract_valid_until   | 2024
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Low/Medium
#  body_type                   | Normal (170-185)
#  real_face                   | No
#  release_clause_eur          | 2700000
#  pace                        | 61
#  shooting                    | 49
#  passing                     | 62
#  dribbling                   | 61
#  defending                   | 71
#  physic                      | 80
#  attacking_crossing          | 58
#  attacking_finishing         | 39
#  attacking_heading_accuracy  | 62
#  attacking_short_passing     | 68
#  attacking_volleys           | 38
#  skill_dribbling             | 58
#  skill_curve                 | 59
#  skill_fk_accuracy           | 46
#  skill_long_passing          | 62
#  skill_ball_control          | 66
#  movement_acceleration       | 62
#  movement_sprint_speed       | 61
#  movement_agility            | 59
#  movement_reactions          | 65
#  movement_balance            | 53
#  power_shot_power            | 62
#  power_jumping               | 64
#  power_stamina               | 81
#  power_strength              | 81
#  power_long_shots            | 60
#  mentality_aggression        | 80
#  mentality_interceptions     | 72
#  mentality_positioning       | 54
#  mentality_vision            | 59
#  mentality_penalties         | 45
#  mentality_composure         | 55
#  defending_marking_awareness | 74
#  defending_standing_tackle   | 72
#  defending_sliding_tackle    | 67
#  goalkeeping_diving          | 16
#  goalkeeping_handling        | 7
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 16
#  goalkeeping_reflexes        | 9
#  ls                          | 60
#  st                          | 60
#  rs                          | 60
#  lw                          | 59
#  lf                          | 59
#  cf                          | 59
#  rf                          | 59
#  rw                          | 59
#  lam                         | 62
#  cam                         | 62
#  ram                         | 62
#  lm                          | 63
#  lcm                         | 66
#  cm                          | 66
#  rcm                         | 66
#  rm                          | 63
#  lwb                         | 70
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 70
#  lb                          | 70
#  lcb                         | 71
#  cb                          | 71
#  rcb                         | 71
#  rb                          | 70
#  gk                          | 20
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 224542_2020
#  contract_years_remaining    | 5
# -RECORD 8-------------------------------------------
#  sofifa_id                   | 224796
#  short_name                  | J. Rodríguez
#  long_name                   | Jorge Agustín Rod...
#  player_positions            | CB, RB
#  overall                     | 71
#  potential                   | 78
#  value_eur                   | 3000000
#  wage_eur                    | 8000
#  age                         | 23
#  dob                         | 1995-09-15
#  height_cm                   | 187
#  weight_kg                   | 84
#  club_team_id                | 110404
#  club_name                   | Club Atlético Ban...
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | RCM
#  club_jersey_number          | 30
#  club_joined                 | 2014-07-01
#  club_contract_valid_until   | 2021
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Low/High
#  body_type                   | Stocky (185+)
#  real_face                   | No
#  release_clause_eur          | 5100000
#  pace                        | 58
#  shooting                    | 34
#  passing                     | 45
#  dribbling                   | 48
#  defending                   | 70
#  physic                      | 74
#  attacking_crossing          | 35
#  attacking_finishing         | 30
#  attacking_heading_accuracy  | 75
#  attacking_short_passing     | 65
#  attacking_volleys           | 28
#  skill_dribbling             | 37
#  skill_curve                 | 23
#  skill_fk_accuracy           | 26
#  skill_long_passing          | 48
#  skill_ball_control          | 63
#  movement_acceleration       | 52
#  movement_sprint_speed       | 62
#  movement_agility            | 53
#  movement_reactions          | 66
#  movement_balance            | 46
#  power_shot_power            | 49
#  power_jumping               | 83
#  power_stamina               | 67
#  power_strength              | 79
#  power_long_shots            | 24
#  mentality_aggression        | 67
#  mentality_interceptions     | 67
#  mentality_positioning       | 44
#  mentality_vision            | 26
#  mentality_penalties         | 37
#  mentality_composure         | 53
#  defending_marking_awareness | 67
#  defending_standing_tackle   | 74
#  defending_sliding_tackle    | 66
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 12
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 15
#  goalkeeping_reflexes        | 6
#  ls                          | 53
#  st                          | 53
#  rs                          | 53
#  lw                          | 47
#  lf                          | 48
#  cf                          | 48
#  rf                          | 48
#  rw                          | 47
#  lam                         | 50
#  cam                         | 50
#  ram                         | 50
#  lm                          | 51
#  lcm                         | 55
#  cm                          | 55
#  rcm                         | 55
#  rm                          | 51
#  lwb                         | 63
#  ldm                         | 66
# ...
#  overall                     | 71
#  potential                   | 79
#  value_eur                   | 3500000
#  wage_eur                    | 16000
#  age                         | 23
#  dob                         | 1996-03-30
#  height_cm                   | 167
#  weight_kg                   | 60
#  club_team_id                | 483
#  club_name                   | Villarreal CF
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 22
#  club_joined                 | 2015-01-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 52
#  nationality_name            | Argentina
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 4
#  international_reputation    | 1
#  work_rate                   | Medium/Low
#  body_type                   | Lean (170-)
#  real_face                   | Yes
#  release_clause_eur          | 8000000
#  pace                        | 65
#  shooting                    | 68
#  passing                     | 73
#  dribbling                   | 76
#  defending                   | 23
#  physic                      | 35
#  attacking_crossing          | 75
#  attacking_finishing         | 70
#  attacking_heading_accuracy  | 54
#  attacking_short_passing     | 74
#  attacking_volleys           | 59
#  skill_dribbling             | 75
#  skill_curve                 | 75
#  skill_fk_accuracy           | 70
#  skill_long_passing          | 70
#  skill_ball_control          | 74
#  movement_acceleration       | 69
#  movement_sprint_speed       | 61
#  movement_agility            | 84
#  movement_reactions          | 66
#  movement_balance            | 89
#  power_shot_power            | 65
#  power_jumping               | 72
#  power_stamina               | 35
#  power_strength              | 31
#  power_long_shots            | 70
#  mentality_aggression        | 36
#  mentality_interceptions     | 15
#  mentality_positioning       | 68
#  mentality_vision            | 73
#  mentality_penalties         | 62
#  mentality_composure         | 68
#  defending_marking_awareness | 23
#  defending_standing_tackle   | 22
#  defending_sliding_tackle    | 11
#  goalkeeping_diving          | 11
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 6
#  goalkeeping_positioning     | 15
#  goalkeeping_reflexes        | 7
#  ls                          | 68
#  st                          | 68
#  rs                          | 68
#  lw                          | 72
#  lf                          | 70
#  cf                          | 70
#  rf                          | 70
#  rw                          | 72
#  lam                         | 74
#  cam                         | 74
#  ram                         | 74
#  lm                          | 72
#  lcm                         | 66
#  cm                          | 66
#  rcm                         | 66
#  rm                          | 72
#  lwb                         | 49
#  ldm                         | 47
#  cdm                         | 47
#  rdm                         | 47
#  rwb                         | 49
#  lb                          | 45
#  lcb                         | 36
#  cb                          | 36
#  rcb                         | 36
#  rb                          | 45
#  gk                          | 19
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 225591_2020
#  contract_years_remaining    | 5
# -RECORD 18------------------------------------------
#  sofifa_id                   | 225652
#  short_name                  | G. Pușcaș
#  long_name                   | George Alexandru ...
#  player_positions            | ST
#  overall                     | 71
#  potential                   | 78
#  value_eur                   | 3400000
#  wage_eur                    | 14000
#  age                         | 23
#  dob                         | 1996-04-08
#  height_cm                   | 188
#  weight_kg                   | 78
#  club_team_id                | 1793
#  club_name                   | Reading
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | ST
#  club_jersey_number          | 47
#  club_joined                 | 2019-08-07
#  club_contract_valid_until   | 2024
#  nationality_id              | 39
#  nationality_name            | Romania
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | 7100000
#  pace                        | 68
#  shooting                    | 68
#  passing                     | 51
#  dribbling                   | 70
#  defending                   | 36
#  physic                      | 71
#  attacking_crossing          | 47
#  attacking_finishing         | 70
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 53
#  attacking_volleys           | 68
#  skill_dribbling             | 70
#  skill_curve                 | 62
#  skill_fk_accuracy           | 62
#  skill_long_passing          | 43
#  skill_ball_control          | 70
#  movement_acceleration       | 69
#  movement_sprint_speed       | 68
#  movement_agility            | 65
#  movement_reactions          | 69
#  movement_balance            | 71
#  power_shot_power            | 77
#  power_jumping               | 65
#  power_stamina               | 65
#  power_strength              | 78
#  power_long_shots            | 55
#  mentality_aggression        | 62
#  mentality_interceptions     | 28
#  mentality_positioning       | 74
#  mentality_vision            | 52
#  mentality_penalties         | 69
#  mentality_composure         | 71
#  defending_marking_awareness | 29
#  defending_standing_tackle   | 39
#  defending_sliding_tackle    | 28
#  goalkeeping_diving          | 9
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 11
#  goalkeeping_positioning     | 7
#  goalkeeping_reflexes        | 10
#  ls                          | 72
#  st                          | 72
#  rs                          | 72
#  lw                          | 65
#  lf                          | 67
#  cf                          | 67
#  rf                          | 67
#  rw                          | 65
#  lam                         | 65
#  cam                         | 65
#  ram                         | 65
#  lm                          | 65
#  lcm                         | 59
#  cm                          | 59
#  rcm                         | 59
#  rm                          | 65
#  lwb                         | 52
#  ldm                         | 50
#  cdm                         | 50
#  rdm                         | 50
#  rwb                         | 52
#  lb                          | 51
#  lcb                         | 51
#  cb                          | 51
#  rcb                         | 51
#  rb                          | 51
#  gk                          | 18
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 225652_2020
#  contract_years_remaining    | 5
# -RECORD 19------------------------------------------
#  sofifa_id                   | 225668
#  short_name                  | K. Grant
#  long_name                   | Karlan Ahearne-Grant
#  player_positions            | ST
#  overall                     | 71
#  potential                   | 82
#  value_eur                   | 4100000
#  wage_eur                    | 18000
#  age                         | 21
#  dob                         | 1997-09-18
#  height_cm                   | 183
#  weight_kg                   | 70
#  club_team_id                | 1939
#  club_name                   | Huddersfield Town
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | ST
#  club_jersey_number          | 16
#  club_joined                 | 2019-01-30
#  club_contract_valid_until   | 2022
#  nationality_id              | 14
#  nationality_name            | England
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | High/Medium
#  body_type                   | Normal (170-185)
#  real_face                   | Yes
#  release_clause_eur          | 8700000
#  pace                        | 88
#  shooting                    | 69
#  passing                     | 49
#  dribbling                   | 68
#  defending                   | 36
#  physic                      | 60
#  attacking_crossing          | 38
#  attacking_finishing         | 71
#  attacking_heading_accuracy  | 61
#  attacking_short_passing     | 64
#  attacking_volleys           | 61
#  skill_dribbling             | 68
#  skill_curve                 | 39
#  skill_fk_accuracy           | 35
#  skill_long_passing          | 31
#  skill_ball_control          | 68
#  movement_acceleration       | 86
#  movement_sprint_speed       | 89
#  movement_agility            | 71
#  movement_reactions          | 69
#  movement_balance            | 60
#  power_shot_power            | 69
#  power_jumping               | 72
#  power_stamina               | 68
#  power_strength              | 64
#  power_long_shots            | 68
#  mentality_aggression        | 35
#  mentality_interceptions     | 25
#  mentality_positioning       | 70
#  mentality_vision            | 53
#  mentality_penalties         | 65
#  mentality_composure         | 58
#  defending_marking_awareness | 53
#  defending_standing_tackle   | 23
#  defending_sliding_tackle    | 24
#  goalkeeping_diving          | 11
#  goalkeeping_handling        | 10
#  goalkeeping_kicking         | 13
#  goalkeeping_positioning     | 15
#  goalkeeping_reflexes        | 14
#  ls                          | 72
#  st                          | 72
#  rs                          | 72
#  lw                          | 67
#  lf                          | 69
#  cf                          | 69
#  rf                          | 69
#  rw                          | 67
#  lam                         | 68
#  cam                         | 68
#  ram                         | 68
#  lm                          | 67
#  lcm                         | 58
#  cm                          | 58
#  rcm                         | 58
#  rm                          | 67
#  lwb                         | 53
#  ldm                         | 48
#  cdm                         | 48
#  rdm                         | 48
#  rwb                         | 53
#  lb                          | 52
#  lcb                         | 47
#  cb                          | 47
#  rcb                         | 47
#  rb                          | 52
#  gk                          | 21
#  year                        | 2020
#  gender                      | 1
#  unique_id                   | 225668_2020
#  contract_years_remaining    | 3
# only showing top 20 rows

# %% [markdown]
# **(2) furtherly drop unnecessary features**

# %%
delete_features = ['gender','nationality_id', 'nationality_name', 'work_rate', 'body_type', 'real_face', 'short_name', 'long_name','sofifa_id','unique_id','year','player_positions', 'dob', 'club_joined','club_name']
df_read = df_read.drop(*delete_features)
df_read.show(2,vertical = True)
# Out:
# -RECORD 0-------------------------------------------
#  overall                     | 71
#  potential                   | 74
#  value_eur                   | 2600000
#  wage_eur                    | 7000
#  age                         | 26
#  height_cm                   | 187
#  weight_kg                   | 81
#  club_team_id                | 15
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | LCB
#  club_jersey_number          | 29
#  club_contract_valid_until   | 2022
#  preferred_foot              | Left
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  release_clause_eur          | 5200000
#  pace                        | 69
#  shooting                    | 50
#  passing                     | 67
#  dribbling                   | 64
#  defending                   | 70
#  physic                      | 72
#  attacking_crossing          | 66
#  attacking_finishing         | 36
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 64
#  attacking_volleys           | 51
#  skill_dribbling             | 63
#  skill_curve                 | 65
#  skill_fk_accuracy           | 75
#  skill_long_passing          | 73
#  skill_ball_control          | 66
#  movement_acceleration       | 67
#  movement_sprint_speed       | 70
#  movement_agility            | 61
#  movement_reactions          | 68
#  movement_balance            | 54
#  power_shot_power            | 68
#  power_jumping               | 60
#  power_stamina               | 70
#  power_strength              | 76
#  power_long_shots            | 58
#  mentality_aggression        | 68
#  mentality_interceptions     | 69
#  mentality_positioning       | 55
#  mentality_vision            | 66
#  mentality_penalties         | 58
#  mentality_composure         | 66
#  defending_marking_awareness | 69
#  defending_standing_tackle   | 72
#  defending_sliding_tackle    | 72
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 13
#  ls                          | 62
#  st                          | 62
#  rs                          | 62
#  lw                          | 61
#  lf                          | 61
#  cf                          | 61
#  rf                          | 61
#  rw                          | 61
#  lam                         | 64
#  cam                         | 64
#  ram                         | 64
#  lm                          | 66
#  lcm                         | 68
#  cm                          | 68
#  rcm                         | 68
#  rm                          | 66
#  lwb                         | 70
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 70
#  lb                          | 71
#  lcb                         | 72
#  cb                          | 72
#  rcb                         | 72
#  rb                          | 71
#  gk                          | 20
#  contract_years_remaining    | 3
# -RECORD 1-------------------------------------------
#  overall                     | 71
#  potential                   | 71
#  value_eur                   | 2500000
#  wage_eur                    | 9000
#  age                         | 27
#  height_cm                   | 167
#  weight_kg                   | 63
#  club_team_id                | 112224
#  league_name                 | Australian Hyunda...
#  league_level                | 1
#  club_position               | LM
#  club_jersey_number          | 8
#  club_contract_valid_until   | 2021
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  release_clause_eur          | 3100000
#  pace                        | 83
#  shooting                    | 60
#  passing                     | 66
#  dribbling                   | 71
#  defending                   | 32
#  physic                      | 60
#  attacking_crossing          | 74
#  attacking_finishing         | 56
#  attacking_heading_accuracy  | 37
#  attacking_short_passing     | 65
#  attacking_volleys           | 50
#  skill_dribbling             | 73
#  skill_curve                 | 57
#  skill_fk_accuracy           | 43
#  skill_long_passing          | 65
#  skill_ball_control          | 65
#  movement_acceleration       | 81
#  movement_sprint_speed       | 84
#  movement_agility            | 75
#  movement_reactions          | 66
#  movement_balance            | 89
#  power_shot_power            | 65
#  power_jumping               | 59
#  power_stamina               | 70
#  power_strength              | 53
#  power_long_shots            | 62
#  mentality_aggression        | 66
#  mentality_interceptions     | 31
#  mentality_positioning       | 68
#  mentality_vision            | 70
#  mentality_penalties         | 63
#  mentality_composure         | 65
#  defending_marking_awareness | 24
#  defending_standing_tackle   | 33
#  defending_sliding_tackle    | 46
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 6
#  goalkeeping_reflexes        | 10
#  ls                          | 64
#  st                          | 64
#  rs                          | 64
#  lw                          | 69
#  lf                          | 67
#  cf                          | 67
#  rf                          | 67
#  rw                          | 69
#  lam                         | 70
#  cam                         | 70
#  ram                         | 70
#  lm                          | 71
#  lcm                         | 65
#  cm                          | 65
#  rcm                         | 65
#  rm                          | 71
#  lwb                         | 59
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 59
#  lb                          | 56
#  lcb                         | 46
#  cb                          | 46
#  rcb                         | 46
#  rb                          | 56
#  gk                          | 19
#  contract_years_remaining    | 2
# only showing top 2 rows

# %% [markdown]
# **(3) Define Columns Type**

# %%
continuous_cols = ['overall','potential','wage_eur','age','height_cm', 'weight_kg', 'league_level','weak_foot', 'skill_moves','international_reputation',
                  'release_clause_eur','pace', "shooting", "passing", "dribbling", "defending", "physic", "attacking_crossing", "attacking_finishing", 
                   "attacking_heading_accuracy", "attacking_short_passing", "attacking_volleys", "skill_dribbling", "skill_curve",
                   "skill_fk_accuracy", "skill_long_passing", "skill_ball_control", "movement_acceleration", "movement_sprint_speed",
                   "movement_agility", "movement_reactions", "movement_balance", "power_shot_power", "power_jumping", "power_stamina",
                   "power_strength", "power_long_shots", "mentality_aggression", "mentality_interceptions", "mentality_positioning",
                   "mentality_vision", "mentality_penalties", "mentality_composure", "defending_marking_awareness", "defending_standing_tackle",
                   "defending_sliding_tackle", "goalkeeping_diving", "goalkeeping_handling", "goalkeeping_kicking", "goalkeeping_positioning", 
                   "goalkeeping_reflexes", "ls", "st", "rs", "lw", "lf", "cf", "rf", "rw", "lam", "cam", "ram", "lm", "lcm", "cm", "rcm", "rm", 
                   "lwb", "ldm", "cdm", "rdm", "rwb", "lb", "lcb", "cb", "rcb", "rb", "gk",'contract_years_remaining',
                    'overall','club_team_id', 'club_jersey_number', 'club_contract_valid_until']
nominal_cols = []
binary_cols = ['preferred_foot']

# %% [markdown]
# **(4) Transfer binary_cols**

# %%
from pyspark.sql.functions import when, col

df_read = df_read.withColumn(
    "preferred_foot", 
    when(col("preferred_foot") == "Left", 0.0)
    .when(col("preferred_foot") == "Right", 1.0)
    .otherwise(None)  
)
df_read.show(1,vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  overall                     | 71
#  potential                   | 74
#  value_eur                   | 2600000
#  wage_eur                    | 7000
#  age                         | 26
#  height_cm                   | 187
#  weight_kg                   | 81
#  club_team_id                | 15
#  league_name                 | English League Ch...
#  league_level                | 2
#  club_position               | LCB
#  club_jersey_number          | 29
#  club_contract_valid_until   | 2022
#  preferred_foot              | 0.0
#  weak_foot                   | 2
#  skill_moves                 | 3
#  international_reputation    | 1
#  release_clause_eur          | 5200000
#  pace                        | 69
#  shooting                    | 50
#  passing                     | 67
#  dribbling                   | 64
#  defending                   | 70
#  physic                      | 72
#  attacking_crossing          | 66
#  attacking_finishing         | 36
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 64
#  attacking_volleys           | 51
#  skill_dribbling             | 63
#  skill_curve                 | 65
#  skill_fk_accuracy           | 75
#  skill_long_passing          | 73
#  skill_ball_control          | 66
#  movement_acceleration       | 67
#  movement_sprint_speed       | 70
#  movement_agility            | 61
#  movement_reactions          | 68
#  movement_balance            | 54
#  power_shot_power            | 68
#  power_jumping               | 60
#  power_stamina               | 70
#  power_strength              | 76
#  power_long_shots            | 58
#  mentality_aggression        | 68
#  mentality_interceptions     | 69
#  mentality_positioning       | 55
#  mentality_vision            | 66
#  mentality_penalties         | 58
#  mentality_composure         | 66
#  defending_marking_awareness | 69
#  defending_standing_tackle   | 72
#  defending_sliding_tackle    | 72
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 13
#  ls                          | 62
#  st                          | 62
#  rs                          | 62
#  lw                          | 61
#  lf                          | 61
#  cf                          | 61
#  rf                          | 61
#  rw                          | 61
#  lam                         | 64
#  cam                         | 64
#  ram                         | 64
#  lm                          | 66
#  lcm                         | 68
#  cm                          | 68
#  rcm                         | 68
#  rm                          | 66
#  lwb                         | 70
#  ldm                         | 71
#  cdm                         | 71
#  rdm                         | 71
#  rwb                         | 70
#  lb                          | 71
#  lcb                         | 72
#  cb                          | 72
#  rcb                         | 72
#  rb                          | 71
#  gk                          | 20
#  contract_years_remaining    | 3
# only showing top 1 row

# %% [markdown]
# **(5) The transformer pipeline**

# %%
import findspark
findspark.init()
findspark.find()
import pyspark
from pyspark.sql import SparkSession, SQLContext
from pyspark.ml import Pipeline,Transformer
from pyspark.ml.feature import Imputer,StandardScaler,StringIndexer,OneHotEncoder, VectorAssembler

from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np

class OutcomeCreater(Transformer): # this defines a transformer that creates the outcome column
    
    def __init__(self):
        super().__init__()

    def _transform(self, dataset):                             
        output_df = dataset.withColumn('outcome', col('value_eur')).drop("value_eur")  
        output_df = output_df.withColumn('outcome', col('outcome').cast(DoubleType()))
        return output_df

class FeatureTypeCaster(Transformer): # this transformer will cast the columns as appropriate types  
    def __init__(self):
        super().__init__()

    def _transform(self, dataset):
        output_df = dataset
        for col_name in binary_cols + continuous_cols:
            output_df = output_df.withColumn(col_name,col(col_name).cast(DoubleType()))

        return output_df
class ColumnDropper(Transformer): # this transformer drops unnecessary columns
    def __init__(self, columns_to_drop = None):
        super().__init__()
        self.columns_to_drop=columns_to_drop
    def _transform(self, dataset):
        output_df = dataset
        for col_name in self.columns_to_drop:
            output_df = output_df.drop(col_name)
        return output_df

def get_preprocess_pipeline():
    # Stage where columns are casted as appropriate types
    stage_typecaster = FeatureTypeCaster()
    
    # Stage where nominal columns are transformed to index columns using StringIndexer
    nominal_id_cols = [x+"_index" for x in nominal_cols]
    nominal_onehot_cols = [x+"_encoded" for x in nominal_cols]
    stage_nominal_indexer = StringIndexer(inputCols = nominal_cols, outputCols = nominal_id_cols ) # actually there's no nominal cols to transfer

    # Stage where the index columns are further transformed using OneHotEncoder
    stage_nominal_onehot_encoder = OneHotEncoder(inputCols=nominal_id_cols, outputCols=nominal_onehot_cols)

    # Stage where all relevant features are assembled into a vector (and dropping a few)
    feature_cols = continuous_cols+binary_cols+nominal_onehot_cols
    corelated_cols_to_remove = ['overall','club_team_id', 'club_jersey_number', 'club_contract_valid_until']

    for col_name in corelated_cols_to_remove:
        feature_cols.remove(col_name)
    stage_vector_assembler = VectorAssembler(inputCols=feature_cols, outputCol="vectorized_features")
    
    # Stage where we scale the columns
    stage_scaler = StandardScaler(inputCol= 'vectorized_features', outputCol= 'features')
    


    # Creating the outcome and conduct standardization
    stage_outcome = OutcomeCreater()
    assembler_outcome = VectorAssembler(inputCols=['outcome'], outputCol='assembled_outcome')
    scaler_outcome = StandardScaler(inputCol='assembled_outcome', outputCol='scaled_outcome', withMean=True, withStd=True)
    # Removing all unnecessary columbs, only keeping the 'features' and 'outcome' columns
    stage_column_dropper = ColumnDropper(columns_to_drop = nominal_cols+nominal_id_cols+
        nominal_onehot_cols+ binary_cols + continuous_cols + ['vectorized_features'])
    # Connect the columns into a pipeline
    pipeline = Pipeline(stages=[stage_typecaster,stage_nominal_indexer,stage_nominal_onehot_encoder,
        stage_vector_assembler,stage_scaler, stage_outcome,assembler_outcome, scaler_outcome,stage_column_dropper])
    return pipeline

# %% [markdown]
# ### **C. Model Construction**

# %% [markdown]
# ## **TASK III SPARK**
#
# Cont. Data Engineering

# %% [markdown]
# **cont. (6) Split Train and Test Data**

# %%
train_df, test_df = df_read.randomSplit([0.8, 0.2], seed=42)
train_df.count()
# Out:
# 113535

# %% [markdown]
# **cont. (7) Fit & Transform**

# %%
preprocess_pipeline = get_preprocess_pipeline()
preprocess_pipeline_model = preprocess_pipeline.fit(train_df)
from pyspark.ml.functions import vector_to_array
df_train = preprocess_pipeline_model.transform(train_df)
df_test = preprocess_pipeline_model.transform(test_df)
df_train = df_train.drop('outcome')
df_test = df_test.drop('outcome')

#vector_to_array is necessary since the standardization process transfers the outcome to a vector
df_train = df_train.withColumn('outcome',vector_to_array(col('scaled_outcome'))[0])
df_train = df_train.drop('scaled_outcome','assembled_outcome','league_name','club_position')

df_test = df_test.withColumn('outcome',vector_to_array(col('scaled_outcome'))[0])
df_test = df_test.drop('scaled_outcome','assembled_outcome','league_name','club_position')

# %% [markdown]
# ### **1. SPARK GBT**

# %%
from pyspark.ml.regression import GBTRegressor

gbt = GBTRegressor(featuresCol='features', labelCol='outcome',maxDepth=15)
gbt_model = gbt.fit(df_train)
df_train_pred = gbt_model.transform(df_train)
df_train_pred.select("features", "outcome", "prediction").show(1)
# Out:
# +--------------------+-------------------+-------------------+
# |            features|            outcome|         prediction|
# +--------------------+-------------------+-------------------+
# |[6.37226665552176...|-0.3674073809222563|-0.3727299250372219|
# +--------------------+-------------------+-------------------+
# only showing top 1 row

# %%
df_test_pred = gbt_model.transform(df_test)
df_test_pred.show(1)
# Out:
# +--------------------+-------------------+-------------------+
# |            features|            outcome|         prediction|
# +--------------------+-------------------+-------------------+
# |[7.9653333194022,...|-0.7438377371334567|-0.7369265342950481|
# +--------------------+-------------------+-------------------+
# only showing top 1 row

# %%
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
# Initialize the evaluator
evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")

# Evaluate RMSE on the training dataset
train_rmse = evaluator.evaluate(df_train_pred)
print(f"Train RMSE: {train_rmse}")

# Evaluate RMSE on the test dataset
test_rmse = evaluator.evaluate(df_test_pred)
print(f"Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 0.049785970118829945
# Test RMSE: 0.4404536667784305

# %%
gbt = GBTRegressor(featuresCol='features', labelCol='outcome')

paramGrid = ParamGridBuilder() \
    .addGrid(gbt.maxIter, [10, 50]) \
    .addGrid(gbt.maxDepth, [10]) \
    .addGrid(gbt.stepSize, [0.05, 0.2]) \
    .build()

evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")

crossval = CrossValidator(estimator=gbt,
                          estimatorParamMaps=paramGrid,
                          evaluator=evaluator,
                          numFolds=3)

cv_model = crossval.fit(df_train)

best_model = cv_model.bestModel
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\hp\anaconda3\envs\torch_11_3\lib\multiprocessing\pool.py:853, in IMapIterator.next(self, timeout)
#     852 try:
# --> 853     item = self._items.popleft()
#     854 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 16
#       9 evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")
#      11 crossval = CrossValidator(estimator=gbt,
#      12                           estimatorParamMaps=paramGrid,
#      13                           evaluator=evaluator,
#      14                           numFolds=3)
# ---> 16 cv_model = crossval.fit(df_train)
#      18 best_model = cv_model.bestModel
#
# File C:\spark\spark-3.5.2-bin-hadoop3\python\pyspark\ml\base.py:205, in Estimator.fit(self, dataset, params)
#     203         return self.copy(params)._fit(dataset)
#     204     else:
# --> 205         return self._fit(dataset)
#     206 else:
#     207     raise TypeError(
#     208         "Params must be either a param map or a list/tuple of param maps, "
#     209         "but got %s." % type(params)
#     210     )
#
# File C:\spark\spark-3.5.2-bin-hadoop3\python\pyspark\ml\tuning.py:847, in CrossValidator._fit(self, dataset)
#     841 train = datasets[i][0].cache()
#     843 tasks = map(
#     844     inheritable_thread_target,
#     845     _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam),
#     846 )
# --> 847 for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     848     metrics_all[i][j] = metric
#     849     if collectSubModelsParam:
#
# File c:\Users\hp\anaconda3\envs\torch_11_3\lib\multiprocessing\pool.py:858, in IMapIterator.next(self, timeout)
#     856     self._pool = None
#     857     raise StopIteration from None
# --> 858 self._cond.wait(timeout)
#     859 try:
#     860     item = self._items.popleft()
#
# File c:\Users\hp\anaconda3\envs\torch_11_3\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
avg_losses = cv_model.avgMetrics


print("Cross-validation average loss:", avg_losses)

# %%
df_train_pred = best_model.transform(df_train)
df_test_pred = best_model.transform(df_test)

df_test_pred.show(1)
# Initialize the evaluator
evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")

# Evaluate RMSE on the training dataset
train_rmse = evaluator.evaluate(df_train_pred)
print(f"Train RMSE: {train_rmse}")

# Evaluate RMSE on the test dataset
test_rmse = evaluator.evaluate(df_test_pred)
print(f"Test RMSE: {test_rmse}")

# %% [markdown]
# ### **2. Random Forest**
# hypertuning rf

# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
rf = RandomForestRegressor(featuresCol='features', labelCol='outcome')

paramGrid = ParamGridBuilder() \
    .addGrid(rf.numTrees, [50, 75]) \
    .addGrid(rf.maxDepth, [12]) \
    .addGrid(rf.maxBins, [32, 64]) \
    .build()

evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")

crossval = CrossValidator(estimator=rf,
                          estimatorParamMaps=paramGrid,
                          evaluator=evaluator,
                          numFolds=3)

cv_model = crossval.fit(df_train)

best_model = cv_model.bestModel

# %%
df_train_pred = best_model.transform(df_train)
df_test_pred = best_model.transform(df_test)

df_test_pred.show(1)
# Initialize the evaluator
evaluator = RegressionEvaluator(labelCol="outcome", predictionCol="prediction", metricName="rmse")

# Evaluate RMSE on the training dataset
train_rmse = evaluator.evaluate(df_train_pred)
print(f"Train RMSE: {train_rmse}")

# Evaluate RMSE on the test dataset
test_rmse = evaluator.evaluate(df_test_pred)
print(f"Test RMSE: {test_rmse}")

# %% [markdown]
# ## TASK III PyTorch

# %% [markdown]
# **cont. (6) Fit & Transform**

# %%
train_df, test_df, validate_df = df_read.randomSplit([0.8, 0.1, 0.1], seed=42)

# 打印每个数据集的长度（可选）
print(f"训练集长度: {train_df.count()}")
print(f"测试集长度: {test_df.count()}")
print(f"验证集长度: {validate_df.count()}")
# Out:
# 训练集长度: 113535
# 测试集长度: 14192
# 验证集长度: 14352

# %%
preprocess_pipeline = get_preprocess_pipeline()
preprocess_pipeline_model = preprocess_pipeline.fit(train_df)  # only fit the training data
from pyspark.ml.functions import vector_to_array
train_tran = preprocess_pipeline_model.transform(train_df)
test_tran = preprocess_pipeline_model.transform(test_df)
validate_tran = preprocess_pipeline_model.transform(validate_df)
# df_tran = df_tran.drop('outcome')
# #vector_to_array is necessary since the standardization process transfers the outcome to a vector
# df_final = df_tran.withColumn('outcome',vector_to_array(col('scaled_outcome'))[0])
# df = df_final.drop('scaled_outcome','assembled_outcome','league_name','club_position')

# %%
def process_transformed_df(df_transformed):

    df_tran = df_transformed.drop('outcome')
    df_final = df_tran.withColumn('outcome', vector_to_array(col('scaled_outcome'))[0])
    df_final = df_final.drop('scaled_outcome', 'assembled_outcome', 'league_name', 'club_position')
    
    return df_final


train_final = process_transformed_df(train_tran)
test_final = process_transformed_df(test_tran)
validate_final = process_transformed_df(validate_tran)

# %%
test_final.show(5)
# Out:
# +--------------------+-------------------+
# |            features|            outcome|
# +--------------------+-------------------+
# |[7.9653333194022,...|-0.7438377371334567|
# |[7.9653333194022,...|-0.7408737185806126|
# |[8.92117331773046...| -0.723089607263548|
# |[9.39909331689459...|-0.7408737185806126|
# |[9.71770664967068...|-0.7171615701578598|
# +--------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# **cont. (7) Create Torch's Dataset**

# %%
pandas_train_df = train_final.toPandas()
pandas_test_df = test_final.toPandas()
pandas_validate_df = validate_final.toPandas()

# %%
# 转换为 NumPy 数组
import numpy as np

X_train = np.stack(pandas_train_df['features'].values)
y_train = pandas_train_df['outcome'].values

X_test = np.stack(pandas_test_df['features'].values)
y_test = pandas_test_df['outcome'].values

X_validate = np.stack(pandas_validate_df['features'].values)
y_validate = pandas_validate_df['outcome'].values

# 转换为 PyTorch 张量
import torch
from torch.utils.data import Dataset, DataLoader

class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# 创建 PyTorch 数据集
dataset_train = MyDataset(X_train, y_train)
dataset_test = MyDataset(X_test, y_test)
dataset_validate = MyDataset(X_validate, y_validate)

# 打印数据集长度（可选）
print("train dataset length:", len(dataset_train))
print("test dataset length:", len(dataset_test))
print("val dataset length:", len(dataset_validate))
# Out:
# train dataset length: 113535
# test dataset length: 14192
# val dataset length: 14352

# %% [markdown]
# ### **PyTorch Model 1**

# %% [markdown]
# #### **1 ADAM optimizer**
#
# ##### 1.1 NN definition

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch import nn
import torch.nn.functional as F
class NN_Model_1(nn.Module):
    def __init__(self, input_size=X_train.shape[1], output_size=1, hidden_size=32, num_hidden_layers=5, activation_function='ReLU', dropout_p=0.3):
        super().__init__()
        layers = []
        activation_class = getattr(nn, activation_function)
        
        # input layer
        layers.append(nn.Linear(input_size, hidden_size))
        layers.append(activation_class())
        layers.append(nn.Dropout(dropout_p))
        
        # hidden layer
        for _ in range(num_hidden_layers - 1):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(activation_class())
            layers.append(nn.Dropout(dropout_p))
        
        # output layer
        layers.append(nn.Linear(hidden_size, output_size))
        
        self.sequential = nn.Sequential(*layers)
    
    def forward(self, x):
        y = self.sequential(x)
        return y

# %% [markdown]
# **The best model hyperparameter for adam optimizer is used below**

# %%
# I used the best params for ADAM here (I didn't find this parameter at first)
model = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0.1).to(device)
batch_size = 256
num_epochs = 100
best_val_loss = np.inf
patience = 60
counter = 0
lr = 5e-4 # five times ten to the negative fourth power
weight_decay=1e-7
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True) 
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# Start training
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)



train_hist_iter = []
train_hist = []
val_hist = []



for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0


    for inputs, targets in train_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        outputs = model(inputs).squeeze(-1)
        # outputs = model(inputs).squeeze()
        loss = criterion(outputs, targets)
        # calculate the gradient
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_hist_iter.append(loss.item()) # use item() because we don't need to pull them back from GPU
        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(dataset_train)
    train_hist.append(epoch_loss)


    model.eval()
    val_loss = 0.0
    # reset the indicators

    with torch.no_grad():
        for inputs, targets in validate_dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
            outputs = model(inputs).squeeze(-1)
            loss = criterion(outputs, targets)
            val_loss += loss.item() * inputs.size(0)


    val_loss /= len(dataset_validate)
    val_hist.append(val_loss)
    scheduler.step(val_loss)

    # early stop
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        print(f'new best model: Epoch {epoch+1}/{num_epochs}, training_loss: {epoch_loss:.4f}, val_loss: {val_loss:.4f}')
        torch.save(model.state_dict(), 'best_model.pth') # save the best model
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break
    
    
    if (epoch+1) % 2 == 0 or epoch == 0:
        print(f'Epoch {epoch+1}/{num_epochs}, training_loss: {epoch_loss:.4f}, val_loss: {val_loss:.4f}')
        
print('training finished')
# Out:
# new best model: Epoch 1/100, training_loss: 0.5377, val_loss: 0.3532
# Epoch 1/100, training_loss: 0.5377, val_loss: 0.3532
# new best model: Epoch 2/100, training_loss: 0.3406, val_loss: 0.3329
# Epoch 2/100, training_loss: 0.3406, val_loss: 0.3329
# new best model: Epoch 4/100, training_loss: 0.3059, val_loss: 0.2953
# Epoch 4/100, training_loss: 0.3059, val_loss: 0.2953
# new best model: Epoch 5/100, training_loss: 0.2902, val_loss: 0.2499
# Epoch 6/100, training_loss: 0.2862, val_loss: 0.2598
# Epoch 8/100, training_loss: 0.2733, val_loss: 0.2835
# new best model: Epoch 9/100, training_loss: 0.2744, val_loss: 0.2474
# Epoch 10/100, training_loss: 0.2740, val_loss: 0.2706
# new best model: Epoch 12/100, training_loss: 0.2690, val_loss: 0.2411
# Epoch 12/100, training_loss: 0.2690, val_loss: 0.2411
# new best model: Epoch 13/100, training_loss: 0.2624, val_loss: 0.2359
# Epoch 14/100, training_loss: 0.2601, val_loss: 0.2755
# new best model: Epoch 15/100, training_loss: 0.2576, val_loss: 0.2276
# Epoch 16/100, training_loss: 0.2553, val_loss: 0.2696
# Epoch 18/100, training_loss: 0.2532, val_loss: 0.2709
# Epoch 20/100, training_loss: 0.2567, val_loss: 0.3289
# Epoch 22/100, training_loss: 0.2502, val_loss: 0.2482
# new best model: Epoch 24/100, training_loss: 0.2488, val_loss: 0.2204
# Epoch 24/100, training_loss: 0.2488, val_loss: 0.2204
# Epoch 26/100, training_loss: 0.2505, val_loss: 0.2572
# Epoch 28/100, training_loss: 0.2395, val_loss: 0.2286
# Epoch 30/100, training_loss: 0.2375, val_loss: 0.2226
# Epoch 32/100, training_loss: 0.2381, val_loss: 0.2347
# new best model: Epoch 33/100, training_loss: 0.2372, val_loss: 0.2198
# Epoch 34/100, training_loss: 0.2335, val_loss: 0.2506
# Epoch 36/100, training_loss: 0.2351, val_loss: 0.2379
# Epoch 38/100, training_loss: 0.2401, val_loss: 0.2355
# new best model: Epoch 40/100, training_loss: 0.2297, val_loss: 0.2126
# Epoch 40/100, training_loss: 0.2297, val_loss: 0.2126
# Epoch 42/100, training_loss: 0.2307, val_loss: 0.2259
# new best model: Epoch 43/100, training_loss: 0.2325, val_loss: 0.2093
# Epoch 44/100, training_loss: 0.2289, val_loss: 0.2366
# Epoch 46/100, training_loss: 0.2314, val_loss: 0.2124
# Epoch 48/100, training_loss: 0.2284, val_loss: 0.2427
# Epoch 50/100, training_loss: 0.3491, val_loss: 0.3195
# Epoch 52/100, training_loss: 0.2602, val_loss: 0.2251
# Epoch 54/100, training_loss: 0.2408, val_loss: 0.2217
# Epoch 56/100, training_loss: 0.2347, val_loss: 0.2112
# Epoch 58/100, training_loss: 0.2316, val_loss: 0.2441
# Epoch 60/100, training_loss: 0.2123, val_loss: 0.2231
# new best model: Epoch 62/100, training_loss: 0.2125, val_loss: 0.2050
# Epoch 62/100, training_loss: 0.2125, val_loss: 0.2050
# new best model: Epoch 64/100, training_loss: 0.2099, val_loss: 0.2017
# Epoch 64/100, training_loss: 0.2099, val_loss: 0.2017
# Epoch 66/100, training_loss: 0.2080, val_loss: 0.2227
# new best model: Epoch 68/100, training_loss: 0.2038, val_loss: 0.2004
# Epoch 68/100, training_loss: 0.2038, val_loss: 0.2004
# new best model: Epoch 70/100, training_loss: 0.2049, val_loss: 0.1970
# Epoch 70/100, training_loss: 0.2049, val_loss: 0.1970
# Epoch 72/100, training_loss: 0.2062, val_loss: 0.2143
# Epoch 74/100, training_loss: 0.2027, val_loss: 0.2400
# new best model: Epoch 75/100, training_loss: 0.2022, val_loss: 0.1955
# new best model: Epoch 76/100, training_loss: 0.1996, val_loss: 0.1948
# Epoch 76/100, training_loss: 0.1996, val_loss: 0.1948
# Epoch 78/100, training_loss: 0.2030, val_loss: 0.2040
# new best model: Epoch 79/100, training_loss: 0.1992, val_loss: 0.1939
# Epoch 80/100, training_loss: 0.1964, val_loss: 0.2172
# Epoch 82/100, training_loss: 0.2004, val_loss: 0.2018
# Epoch 84/100, training_loss: 0.1975, val_loss: 0.1988
# Epoch 86/100, training_loss: 0.1985, val_loss: 0.2011
# new best model: Epoch 87/100, training_loss: 0.1950, val_loss: 0.1916
# Epoch 88/100, training_loss: 0.1970, val_loss: 0.2026
# Epoch 90/100, training_loss: 0.1944, val_loss: 0.2051
# new best model: Epoch 91/100, training_loss: 0.1941, val_loss: 0.1894
# Epoch 92/100, training_loss: 0.1951, val_loss: 0.1968
# Epoch 94/100, training_loss: 0.1985, val_loss: 0.2088
# Epoch 96/100, training_loss: 0.1971, val_loss: 0.2254
# new best model: Epoch 98/100, training_loss: 0.1937, val_loss: 0.1862
# Epoch 98/100, training_loss: 0.1937, val_loss: 0.1862
# Epoch 100/100, training_loss: 0.1908, val_loss: 0.1941
# training finished

# %%
import matplotlib.pyplot as plt


# visualization
plt.figure(figsize=(10,5))
plt.plot(train_hist, label='Training Loss')
plt.plot(val_hist, label='Validation Loss')
plt.ylim([0,1])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# visualization
plt.figure(figsize=(10,5))
plt.plot(train_hist_iter, label='Training Loss')
plt.ylim([0,1])
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The result has some randomness, so we should use the saved models.

# %%
# torch.save(model.state_dict(), 'best_model_adam_11_11.pth')

# %% [markdown]
# #### 1.2 Hyperparameter Tuning (Grid Search)
#
# The code below is really time-consuming. The Demo should just skip this part.

# %%
batch_size = 256
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True) 
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# %%
param_grid = {
    'hidden_size':[256],
    'depth':[5,10,15],
    'dropout_p':[0.1,0.2,0.3],
    'lr':[5e-5,1e-4,5e-4],
    'activation_function':['LeakyReLU'],
    'weight_decay':[1e-7]
}



import itertools

keys = param_grid.keys()
values = param_grid.values()
param_combinations = [dict(zip(keys,v)) for v in itertools.product(*values)]

# %%
def train(model,train_dataloader,validate_dataloader,lr=1e-3,num_epochs=500,weight_decay=1e-6,params={}):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)
    best_val_loss = np.inf
    patience = 60
    counter = 0
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            outputs = model(inputs).squeeze(-1)
            loss = criterion(outputs, targets)
            # calculate the gradient
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataset_train)

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for inputs, targets in validate_dataloader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                outputs = model(inputs).squeeze(-1)
                loss = criterion(outputs, targets)
                val_loss += loss.item() * inputs.size(0)


        val_loss /= len(dataset_validate)
        scheduler.step(val_loss)

        # early stop
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print("Early stopping triggered")
                break
        
        
    print(f'{params}:final train | val loss: {epoch_loss:.4f} | {val_loss:.4f}')
    return val_loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_params = None
batch_size = 256
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True) 
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# %%
import torch
best_val_loss_total = 200000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_params = None
batch_size = 256
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True) 
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
for params in param_combinations:
    model_adam_1 = NN_Model_1(hidden_size=params['hidden_size'],num_hidden_layers=params['depth'],activation_function=params['activation_function'],dropout_p=params['dropout_p']).to(device)
    val_loss_final = train(model_adam_1,train_dataloader,validate_dataloader,lr=params['lr'],num_epochs=200,weight_decay=params['weight_decay'],params=params)
    if val_loss_final < best_val_loss_total:
        best_train_loss = val_loss_final
        best_params = params
        torch.save(model_adam_1, 'best_model_adam_1.pth')
# Out:
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1348 | 0.1997
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1235 | 0.1974
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1421 | 0.1797
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.2, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1874 | 0.2058
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.2, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1509 | 0.2041
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.2, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1706 | 0.1949
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.3, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2117 | 0.2283
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.3, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1958 | 0.2175
# Early stopping triggered
# {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.3, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1816 | 0.1961
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.1, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1261 | 0.2038
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.1, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1187 | 0.2004
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1416 | 0.1851
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.2, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2040 | 0.2212
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.2, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1576 | 0.2099
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.2, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.3313 | 0.2810
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.3, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2040 | 0.2345
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.3, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2013 | 0.2231
# Early stopping triggered
# {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.3, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1974 | 0.2357
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.1, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1568 | 0.2058
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.1, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1118 | 0.2117
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1646 | 0.1892
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.2, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1840 | 0.2194
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.2, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1662 | 0.2239
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.2, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1917 | 0.2250
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.3, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2156 | 0.2307
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.3, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.2066 | 0.2464
# Early stopping triggered
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.3, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.3433 | 0.3712
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### **Grid Search Conclusions:**
#
# Among these parameter combinations, these are the parameters that achieved relatively good results. They all showed a early sign of overfitting. In terms of overfitting, the third one has the best performance (lowest val loss). Then, the fourth one has the second best performance. The 4th model is special because it is the only model that didn't trigger early stop. If I gave it more epochs, or a slightly higher lr, its performance maybe even better.
#
# 1. {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 5e-05, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1348 | 0.1997
# 2. {'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1235 | 0.1974
# 3. **{'hidden_size': 256, 'depth': 5, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1421 | 0.1797**
# 4. **_{'hidden_size': 256, 'depth': 10, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1416 | 0.1851_**
# 5. {'hidden_size': 256, 'depth': 10, 'dropout_p': 0.1, 'lr': 0.0001, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1187 | 0.2004
#
# There is also another model that didn't trigger early stopping.
#
# {'hidden_size': 256, 'depth': 15, 'dropout_p': 0.1, 'lr': 0.0005, 'activation_function': 'LeakyReLU', 'weight_decay': 1e-07}:final train | val loss: 0.1646 | 0.1892
#
# **It seems that 5e-4 is the best learning rate for Adam optimizer trained model, since 3 of the high performance models use `lr` = 5e-4**
#
# On the other hand, the models training loss is still very high, so overfitting may not be the primary problem. These models may still lack the capability to learn enough paterns of the data.

# %% [markdown]
# Let's check the best model's r2 score

# %%
import matplotlib.pyplot as plt
def train_visualization(model,train_dataloader,validate_dataloader,lr=1e-3,num_epochs=500,weight_decay=1e-6):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)
    best_val_loss = np.inf
    patience = 500
    counter = 0
    train_hist = []
    val_hist = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            outputs = model(inputs).squeeze(-1)
            loss = criterion(outputs, targets)
            # calculate the gradient
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataset_train)
        train_hist.append(epoch_loss)
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for inputs, targets in validate_dataloader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                outputs = model(inputs).squeeze(-1)
                loss = criterion(outputs, targets)
                val_loss += loss.item() * inputs.size(0)


        val_loss /= len(dataset_validate)
        val_hist.append(val_loss)
        scheduler.step(val_loss)

        # early stop
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print("Early stopping triggered")
                break
        
        if epoch % 10 == 0:
            print(f'{epoch} train | val loss: {epoch_loss:.4f} | {val_loss:.4f}')
    # visualization
    plt.figure(figsize=(10,5))
    plt.plot(train_hist, label='Training Loss')
    plt.plot(val_hist, label='Validation Loss')
    plt.ylim([0,1])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    
    return val_loss

# %%
model_adam_v1 = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0.1).to(device)
val_loss_final = train_visualization(model_adam_v1,train_dataloader,validate_dataloader,lr=5e-4,num_epochs=10,weight_decay=1e-7)
# Out:
# 0 train | val loss: 0.5254 | 0.3698

# %%
criterion = nn.MSELoss()

# %%
from sklearn.metrics import r2_score
val_loss = 0 
train_loss = 0
r2_train = 0
r2 = 0
with torch.no_grad():
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_adam_v1(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        train_loss += loss.item() * inputs.size(0)
        r2_train += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)

r2_train /= len(dataset_train)
train_loss /= len(dataset_train)
print(f'train_loss: {train_loss} | train_r2_score: {r2_train}')

with torch.no_grad():
    for inputs, targets in validate_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_adam_v1(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        val_loss += loss.item() * inputs.size(0)
        r2 += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)
r2 /= len(dataset_validate)
val_loss /= len(dataset_validate)

print(f'val_loss: {val_loss} | val_r2_score: {r2}')
# Out:
# train_loss: 0.23342279807240401 | train_r2_score: 0.7653963374545592
# val_loss: 0.24687415554106168 | val_r2_score: 0.7551536981902081

# %% [markdown]
# Based on this model, I tried to decrease / increase its anti-overfit parameter.

# %% [markdown]
# - I found that 5e-4 may be too high, which caused the model to oscillate. The model reaches a very low val_loss at first, which causes a constant drop on the lr (because I used `torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.9, patience=15)` and the model cannot reach the low val loss the model achieved at the first epochs after the oscillation.)
# - After decreasing the anti-overfitting parameters, the model still can't obtain a validation loss lower than 0.18. When I set a really low learning rate and weight_decay, the model stars to overfit. Maybe I should try a deeper model?

# %%
# decrease the param (also changed the scheduler's factor as 0.9)
model_adam_v1_d = NN_Model_1(hidden_size=256,num_hidden_layers=15,activation_function='LeakyReLU',dropout_p=0.1).to(device)
val_loss_final = train_visualization(model_adam_v1,train_dataloader,validate_dataloader,lr=3e-4,num_epochs=400,weight_decay=1e-7)
# Out:
# 0 train | val loss: 0.1653 | 0.2088
# 10 train | val loss: 0.1527 | 0.2004
# 20 train | val loss: 0.1531 | 0.2197
# 30 train | val loss: 0.1418 | 0.2172
# 40 train | val loss: 0.1353 | 0.2132
# 50 train | val loss: 0.1285 | 0.2147
# 60 train | val loss: 0.1234 | 0.2218
# 70 train | val loss: 0.1427 | 0.2465
# 80 train | val loss: 0.2117 | 0.2012
# 90 train | val loss: 0.1470 | 0.2093
# 100 train | val loss: 0.1225 | 0.2135
# 110 train | val loss: 0.1447 | 0.2282
# 120 train | val loss: 0.1044 | 0.2287
# 130 train | val loss: 0.1054 | 0.2056
# 140 train | val loss: 0.1267 | 0.2208
# 150 train | val loss: 0.0919 | 0.2121
# 160 train | val loss: 0.0905 | 0.2116
# 170 train | val loss: 0.1005 | 0.2217
# 180 train | val loss: 0.0811 | 0.2240
# 190 train | val loss: 0.0831 | 0.2137
# 200 train | val loss: 0.1077 | 0.2119
# 210 train | val loss: 0.0750 | 0.2211
# 220 train | val loss: 0.0744 | 0.2298
# 230 train | val loss: 0.0687 | 0.2288
# 240 train | val loss: 0.0719 | 0.2373
# 250 train | val loss: 0.0650 | 0.2371
# 260 train | val loss: 0.0635 | 0.2424
# 270 train | val loss: 0.0637 | 0.2493
# 280 train | val loss: 0.0618 | 0.2255
# 290 train | val loss: 0.0566 | 0.2289
# 300 train | val loss: 0.0544 | 0.2384
# 310 train | val loss: 0.0582 | 0.2318
# 320 train | val loss: 0.0538 | 0.2357
# 330 train | val loss: 0.0535 | 0.2424
# 340 train | val loss: 0.0520 | 0.2347
# 350 train | val loss: 0.0540 | 0.2342
# 360 train | val loss: 0.0500 | 0.2396
# 370 train | val loss: 0.0509 | 0.2371
# 380 train | val loss: 0.0487 | 0.2421
# 390 train | val loss: 0.0485 | 0.2451

# %% [markdown]
# **This one is overfitted**
#
# I used this model for the ensemble NN. Adam optimizer is more robust agains gradient vanishing, so it can handle with deeper NNs without using other deep NN strategies.
#
# model_adam_v1_d = NN_Model_1(hidden_size=256,num_hidden_layers=15,activation_function='LeakyReLU',dropout_p=0.1).to(device)
#
# val_loss_final = train_visualization(model_adam_v1,train_dataloader,validate_dataloader,lr=3e-4,num_epochs=400,weight_decay=1e-7)

# %%
# increase the anti-overfitting param with a deeper NN
model_adam_v1_i = NN_Model_1(hidden_size=256,num_hidden_layers=18,activation_function='LeakyReLU',dropout_p=0.3).to(device)
val_loss_final = train_visualization(model_adam_v1_i,train_dataloader,validate_dataloader,lr=5e-4,num_epochs=300,weight_decay=1e-6)
# Out:
# 0 train | val loss: 0.7470 | 0.5725
# 10 train | val loss: 0.3381 | 0.2945
# 20 train | val loss: 0.3244 | 0.2865
# 30 train | val loss: 0.3340 | 0.2841
# 40 train | val loss: 0.3164 | 0.3045
# 50 train | val loss: 0.2763 | 0.2572
# 60 train | val loss: 0.3852 | 0.2981
# 70 train | val loss: 0.2885 | 0.2567
# 80 train | val loss: 0.2646 | 0.2517
# 90 train | val loss: 0.2520 | 0.2376
# 100 train | val loss: 0.2421 | 0.2319
# 110 train | val loss: 0.2369 | 0.2374
# 120 train | val loss: 80.2071 | 0.2692
# 130 train | val loss: 0.2933 | 0.2553
# 140 train | val loss: 0.2707 | 0.2525
# 150 train | val loss: 0.2589 | 0.2468
# 160 train | val loss: 0.2504 | 0.2509
# 170 train | val loss: 0.2432 | 0.2351
# 180 train | val loss: 0.2328 | 0.2297
# 190 train | val loss: 0.2298 | 0.2304
# 200 train | val loss: 0.2276 | 0.2274
# 210 train | val loss: 0.2250 | 0.2275
# 220 train | val loss: 0.2262 | 0.2274
# 230 train | val loss: 0.2267 | 0.2276
# 240 train | val loss: 0.2260 | 0.2268
# 250 train | val loss: 0.2260 | 0.2268
# 260 train | val loss: 0.2258 | 0.2267
# 270 train | val loss: 0.2256 | 0.2266
# 280 train | val loss: 0.2235 | 0.2266
# 290 train | val loss: 0.2252 | 0.2266

# %%
from sklearn.metrics import r2_score
val_loss = 0 
train_loss = 0
r2_train = 0
r2 = 0
with torch.no_grad():
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_adam_v1_d(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        train_loss += loss.item() * inputs.size(0)
        r2_train += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)

r2_train /= len(dataset_train)
train_loss /= len(dataset_train)
print(f'train_loss: {train_loss} | train_r2_score: {r2_traain}')

with torch.no_grad():
    for inputs, targets in validate_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_adam_v1_d(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        val_loss += loss.item() * inputs.size(0)
        r2 += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)
r2 /= len(dataset_validate)
val_loss /= len(dataset_validate)

print(f'val_loss: {val_loss} | val_r2_score: {r2}')
# Out:
# train_loss: 1.0010721789692782 | train_r2_score: -0.007828885646281137
# val_loss: 0.9945766771063697 | val_r2_score: -0.007897325960088885

# %% [markdown]
# #### **2 SGD Optimizer**

# %% [markdown]
# let's try the SGD optimizer

# %% [markdown]
# ##### 2.1 SGD Optimizer Training Function

# %%
import matplotlib.pyplot as plt
def train_visualization_SGD(model,train_dataloader,validate_dataloader,lr=1e-2,num_epochs=500,sche_patience = 20):
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum= 0.95)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=sche_patience)
    best_val_loss = np.inf
    patience = 50
    counter = 0
    train_hist = []
    val_hist = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            outputs = model(inputs).squeeze(-1)
            loss = criterion(outputs, targets)
            # calculate the gradient
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataset_train)
        train_hist.append(epoch_loss)
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for inputs, targets in validate_dataloader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                outputs = model(inputs).squeeze(-1)
                loss = criterion(outputs, targets)
                val_loss += loss.item() * inputs.size(0)


        val_loss /= len(dataset_validate)
        val_hist.append(val_loss)
        scheduler.step(val_loss)

        # early stop
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print("Early stopping triggered")
                break
        
        if epoch % 10 == 0:
            print(f'{epoch} train | val loss: {epoch_loss:.4f} | {val_loss:.4f}')
    # visualization
    plt.figure(figsize=(10,5))
    plt.plot(train_hist, label='Training Loss')
    plt.plot(val_hist, label='Validation Loss')
    plt.ylim([0,1])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    
    return val_loss

# %%
# increase the anti-overfitting param with a deeper NN
model_SGD_1 = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0).to(device)
train_visualization_SGD(model_SGD_1,train_dataloader,validate_dataloader,lr=1e-3,num_epochs=300,sche_patience = 20)
# Out:
# 0 train | val loss: 1.0001 | 1.0227
# 10 train | val loss: 0.3000 | 0.3069
# 20 train | val loss: 0.2773 | 0.2693
# 30 train | val loss: 0.2304 | 0.2349
# 40 train | val loss: 0.2471 | 0.2329
# 50 train | val loss: 0.2227 | 0.2463
# 60 train | val loss: 0.2135 | 0.2211
# 70 train | val loss: 0.2303 | 0.2314
# 80 train | val loss: 0.2004 | 0.2185
# 90 train | val loss: 0.2001 | 0.1959
# 100 train | val loss: 0.2021 | 0.2154
# 110 train | val loss: 0.2175 | 0.3255
# 120 train | val loss: 0.2033 | 0.2037
# 130 train | val loss: 0.1950 | 0.2062
# 140 train | val loss: 0.1969 | 0.1990
# 150 train | val loss: 0.1862 | 0.1934
# 160 train | val loss: 0.1842 | 0.1985
# 170 train | val loss: 0.1721 | 0.1778
# 180 train | val loss: 0.1643 | 0.1800
# 190 train | val loss: 0.1563 | 0.2118
# 200 train | val loss: 0.1564 | 0.2081
# 210 train | val loss: 0.1579 | 0.1793
# 220 train | val loss: 0.1616 | 0.1844
# 230 train | val loss: 0.1432 | 0.1713
# 240 train | val loss: 0.1377 | 0.1723
# 250 train | val loss: 0.1353 | 0.2360
# 260 train | val loss: 0.1346 | 0.1836
# 270 train | val loss: 0.1182 | 0.1816
# 280 train | val loss: 0.1165 | 0.1834
# Early stopping triggered
# 0.17393998639739078

# %%
model_SGD_2 = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0.1).to(device)
train_visualization_SGD(model_SGD_1,train_dataloader,validate_dataloader,lr=8e-4,num_epochs=300,sche_patience=10)
# Out:
# 0 train | val loss: 0.2186 | 0.2587
# 10 train | val loss: 0.1930 | 0.1851
# 20 train | val loss: 0.1616 | 0.1791
# 30 train | val loss: 0.1742 | 0.1774
# 40 train | val loss: 0.1689 | 0.1963
# 50 train | val loss: 0.1443 | 0.1683
# 60 train | val loss: 0.1296 | 0.1787
# 70 train | val loss: 0.1265 | 0.1661
# 80 train | val loss: 0.1149 | 0.1663
# 90 train | val loss: 0.1077 | 0.1699
# 100 train | val loss: 0.1029 | 0.1693
# 110 train | val loss: 0.1012 | 0.1694
# 120 train | val loss: 0.0993 | 0.1686
# Early stopping triggered
# 0.16885267793010908

# %% [markdown]
# ##### 2.2 **BEST Model 1**

# %%
# decrease the patience
model_SGD_1 = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0).to(device)
train_visualization_SGD(model_SGD_1,train_dataloader,validate_dataloader,lr=1e-3,num_epochs=50,sche_patience=10)
# Out:
# 0 train | val loss: 1.0001 | 1.0227
# 10 train | val loss: 0.3244 | 0.3013
# 20 train | val loss: 0.2661 | 0.2986
# 30 train | val loss: 0.2450 | 0.2747
# 40 train | val loss: 0.2171 | 0.2497
# 0.22811777629747307

# %%
from sklearn.metrics import r2_score
val_loss = 0 
train_loss = 0
r2_train = 0
r2 = 0
criterion = nn.MSELoss()
with torch.no_grad():
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_SGD_1(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        train_loss += loss.item() * inputs.size(0)
        r2_train += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)

r2_train /= len(dataset_train)
train_loss /= len(dataset_train)
print(f'train_loss: {train_loss} | train_r2_score: {r2_train}')

with torch.no_grad():
    for inputs, targets in validate_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = model_SGD_1(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        val_loss += loss.item() * inputs.size(0)
        r2 += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)
r2 /= len(dataset_validate)
val_loss /= len(dataset_validate)

print(f'val_loss: {val_loss} | val_r2_score: {r2}')
# Out:
# train_loss: 0.21493219049636705 | train_r2_score: 0.782019062663747
# val_loss: 0.22811777672108466 | val_r2_score: 0.7737839765628896

# %% [markdown]
# Based on these experiments, I can preliminarily conclude that, after hyperparameter tuning, **the Adam optimizer achieves a validation loss of approximately 0.18 on this dataset.** In contrast, the SGD optimizer delivers improved performance, reaching a validation loss of around 0.16 when using a subset of the optimal parameters identified through the Adam tuning process, such as network width and depth. **For this model, the validation R² score has reached 0.835, which is an acceptable level.**

# %%
# SAVE THE MODEL
# torch.save(model_SGD_1.state_dict(), 'NN_model_1.pth')

# %%
# showing the structure of the model
print(model_SGD_1)
# Out:
# NN_Model_1(
#   (sequential): Sequential(
#     (0): Linear(in_features=80, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0, inplace=False)
#     (3): Linear(in_features=256, out_features=256, bias=True)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): Dropout(p=0, inplace=False)
#     (6): Linear(in_features=256, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Dropout(p=0, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): LeakyReLU(negative_slope=0.01)
#     (11): Dropout(p=0, inplace=False)
#     (12): Linear(in_features=256, out_features=256, bias=True)
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): Dropout(p=0, inplace=False)
#     (15): Linear(in_features=256, out_features=256, bias=True)
#     (16): LeakyReLU(negative_slope=0.01)
#     (17): Dropout(p=0, inplace=False)
#     (18): Linear(in_features=256, out_features=256, bias=True)
#     (19): LeakyReLU(negative_slope=0.01)
#     (20): Dropout(p=0, inplace=False)
#     (21): Linear(in_features=256, out_features=256, bias=True)
#     (22): LeakyReLU(negative_slope=0.01)
#     (23): Dropout(p=0, inplace=False)
#     (24): Linear(in_features=256, out_features=256, bias=True)
#     (25): LeakyReLU(negative_slope=0.01)
#     (26): Dropout(p=0, inplace=False)
#     (27): Linear(in_features=256, out_features=256, bias=True)
#     (28): LeakyReLU(negative_slope=0.01)
#     (29): Dropout(p=0, inplace=False)
#     (30): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ##### RUN THIS CODE TO READ THE BEST MODEL 1 BACK

# %% [markdown]
# The result has a little difference because the training process has some randomness.

# %%
NN_model_1_read = NN_Model_1(hidden_size=256,num_hidden_layers=10,activation_function='LeakyReLU',dropout_p=0).to(device)
state_dict = torch.load('NN_model_1.pth',weights_only=True)
NN_model_1_read.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
from sklearn.metrics import r2_score
val_loss = 0 
train_loss = 0
r2_train = 0
r2 = 0
NN_model_1_read.to(device)
criterion = nn.MSELoss()
with torch.no_grad():
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = NN_model_1_read(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        train_loss += loss.item() * inputs.size(0)
        r2_train += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)

r2_train /= len(dataset_train)
train_loss /= len(dataset_train)
print(f'train_loss: {train_loss} | train_r2_score: {r2_train}')

with torch.no_grad():
    for inputs, targets in validate_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = NN_model_1_read(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        val_loss += loss.item() * inputs.size(0)
        r2 += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)
r2 /= len(dataset_validate)
val_loss /= len(dataset_validate)

print(f'val_loss: {val_loss} | val_r2_score: {r2}')
# Out:
# train_loss: 0.09847660465226264 | train_r2_score: 0.8996980764415611
# val_loss: 0.1688526788915413 | val_r2_score: 0.8312420498093644

# %%
with torch.no_grad():
    for inputs, targets in test_dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        outputs = NN_model_1_read(inputs).squeeze(-1)
        loss = criterion(outputs, targets)
        val_loss += loss.item() * inputs.size(0)
        r2 += r2_score(targets.cpu(),outputs.cpu()) * inputs.size(0)
r2 /= len(dataset_test)
val_loss /= len(dataset_test)

print(f'test_loss: {val_loss} | test_r2_score: {r2}')
# Out:
# test_loss: 0.16169414739776905 | test_r2_score: 0.8418665868183641

# %% [markdown]
# ### **PyTorch Model 2**

# %% [markdown]
# **Ensembled NN**

# %% [markdown]
# I trained multiple NN models with different features and data. Then, these models's predictions' mean will be the ensembled NN's final prediction.

# %% [markdown]
# This model is overfitted, which could be used for ensemble models' parameters

# %%
# model_adam_overfitted = NN_Model_1(hidden_size=256,num_hidden_layers=15,activation_function='LeakyReLU',dropout_p=0).to(device)
# val_loss_final = train_visualization(model_adam_overfitted,train_dataloader,validate_dataloader,lr=3e-4,num_epochs=400,weight_decay=1e-7)

# %%
batch_size = 256
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True) 
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### **1 Model training**

# %%
import matplotlib.pyplot as plt

# %%
import torch._dynamo

n_estimators = 15 
num_epochs = 3
feature_subsample_size = int(X_train.shape[1] * 0.8)  
models = []
histories = []

test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True) 
validate_dataloader = DataLoader(dataset_validate, batch_size=batch_size, shuffle=True) 
criterion = nn.MSELoss()  # Choose the appropriate loss function

for idx in range(n_estimators):
    # Randomly select feature indices
    feature_indices = np.random.choice(X_train.shape[1], feature_subsample_size, replace=False)
    # Randomly select sample indices (optional)
    sample_indices = np.random.choice(len(X_train), size=int(len(X_train)*0.8), replace=True)
    
    X_subset = X_train[sample_indices][:, feature_indices]
    y_subset = y_train[sample_indices]
    
    dataset_partial = MyDataset(X_subset, y_subset)
    train_partial_dataloader = DataLoader(dataset_partial, batch_size=256, shuffle=True)
    
    # Define the model
    num_features_subset = X_subset.shape[1]  # Input size corresponds to the number of selected features
    model = NN_Model_1(input_size=num_features_subset, hidden_size=256, num_hidden_layers=15,
                       activation_function='LeakyReLU', dropout_p=0).to(device)
    criterion = nn.MSELoss()  # Choose appropriate loss function according to task
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay=1e-7)
    
    # Train the model
    train_hist = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_partial_dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            outputs = model(inputs).squeeze(-1)
            loss = criterion(outputs, targets)
            # Zero the parameter gradients
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataset_partial)
        train_hist.append(epoch_loss)

    print(f'Model {idx+1} training finished | Training Loss: {epoch_loss}')
    
    # Save the model, corresponding feature indices, and training history
    models.append((model, feature_indices))
    histories.append(train_hist)
# Out:
# Model 1 training finished | Training Loss: 0.29689516144106054
# Model 2 training finished | Training Loss: 0.31458553370886816
# Model 3 training finished | Training Loss: 0.2979342565790279
# Model 4 training finished | Training Loss: 0.296453382539514
# Model 5 training finished | Training Loss: 0.3223141290940754
# Model 6 training finished | Training Loss: 0.3743694365134814
# Model 7 training finished | Training Loss: 0.3138658817372381
# Model 8 training finished | Training Loss: 0.2964874371350108
# Model 9 training finished | Training Loss: 0.31970246239152006
# Model 10 training finished | Training Loss: 0.313521381756817
# Model 11 training finished | Training Loss: 0.31852458792979743
# Model 12 training finished | Training Loss: 0.4401068779062699
# Model 13 training finished | Training Loss: 0.3286678503614575
# Model 14 training finished | Training Loss: 0.33754271762859406
# Model 15 training finished | Training Loss: 0.3078338343873387

# %%
models_1 = models

# %%
# Plot training loss curves
fig, axes = plt.subplots(3, 5, figsize=(20, 8))
axes = axes.flatten()

for i, history in enumerate(histories):
    axes[i].plot(history)
    axes[i].set_title(f'Model {i+1} Training Loss')
    axes[i].set_xlabel('Epoch')
    axes[i].set_ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **2 Saving Model 2**

# %%
# import os

# # Create a directory to save models
# os.makedirs('saved_models', exist_ok=True)

# for idx, (model, feature_indices) in enumerate(models):
#     # Save the model's state_dict
#     model_path = f'saved_models/model_{idx+1}_state_dict.pth'
#     torch.save(model.state_dict(), model_path)
    
#     # Save the feature indices
#     feature_indices_path = f'saved_models/model_{idx+1}_feature_indices.npy'
#     np.save(feature_indices_path, feature_indices)
    
#     print(f'Model {idx+1} and feature indices saved.')
# Out:
# Model 1 and feature indices saved.
# Model 2 and feature indices saved.
# Model 3 and feature indices saved.
# Model 4 and feature indices saved.
# Model 5 and feature indices saved.
# Model 6 and feature indices saved.
# Model 7 and feature indices saved.
# Model 8 and feature indices saved.
# Model 9 and feature indices saved.
# Model 10 and feature indices saved.
# Model 11 and feature indices saved.
# Model 12 and feature indices saved.
# Model 13 and feature indices saved.
# Model 14 and feature indices saved.
# Model 15 and feature indices saved.

# %% [markdown]
# #### **3 Read the Ensemble NN model Back**

# %%
# Load models and feature indices
loaded_models = []
n_estimators = 15  
feature_subsample_size = int(X_train.shape[1] * 0.8)  
for idx in range(n_estimators):
    # Load the model's state_dict
    model_path = f'saved_models/model_{idx+1}_state_dict.pth'
    state_dict = torch.load(model_path,weights_only=True)
    
    # Create a new model instance
    model = NN_Model_1(input_size=64, hidden_size=256, num_hidden_layers=15,
                       activation_function='LeakyReLU', dropout_p=0).to(device)
    model.load_state_dict(state_dict)
    model.eval()
    
    # Load the feature indices
    feature_indices_path = f'saved_models/model_{idx+1}_feature_indices.npy'
    feature_indices = np.load(feature_indices_path)
    
    # Append to the list
    loaded_models.append((model, feature_indices))
    
    print(f'Model {idx+1} and feature indices loaded.')
# Out:
# Model 1 and feature indices loaded.
# Model 2 and feature indices loaded.
# Model 3 and feature indices loaded.
# Model 4 and feature indices loaded.
# Model 5 and feature indices loaded.
# Model 6 and feature indices loaded.
# Model 7 and feature indices loaded.
# Model 8 and feature indices loaded.
# Model 9 and feature indices loaded.
# Model 10 and feature indices loaded.
# Model 11 and feature indices loaded.
# Model 12 and feature indices loaded.
# Model 13 and feature indices loaded.
# Model 14 and feature indices loaded.
# Model 15 and feature indices loaded.

# %% [markdown]
# #### **4 Prediction Function for Ensemble NN**

# %%
from sklearn.metrics import mean_squared_error, r2_score

def ensemble_predict(models, dataloader, device='cpu'):
    """
    Make predictions using an ensemble of neural network models.

    Parameters:
    - models: list of tuples (model, feature_indices)
    - dataloader: PyTorch DataLoader providing input data
    - device: 'cpu' or 'cuda'

    Returns:
    - ensemble_predictions: numpy array of ensemble predictions
    - targets: numpy array of true target values
    """
    import numpy as np
    ensemble_predictions = []
    targets = []
    
    # Initialize a list to hold predictions from each model
    model_predictions_list = [[] for _ in models]
    
    with torch.no_grad():
        for batch_idx, (inputs, batch_targets) in enumerate(dataloader):
            inputs = inputs.to(device)
            batch_predictions = []
            
            for model_idx, (model, feature_indices) in enumerate(models):
                model.eval()
                inputs_subset = inputs[:, feature_indices]
                outputs = model(inputs_subset).squeeze(-1)
                model_predictions_list[model_idx].append(outputs.cpu().numpy())
            
            # Collect targets once
            if batch_idx == 0:
                targets = batch_targets.numpy()
            else:
                targets = np.concatenate((targets, batch_targets.numpy()))
    
    # Concatenate predictions from each model and average
    for model_idx in range(len(models)):
        model_preds = np.concatenate(model_predictions_list[model_idx])
        ensemble_predictions.append(model_preds)
    
    # Compute the mean prediction across all models
    ensemble_predictions = np.mean(ensemble_predictions, axis=0)
    
    return ensemble_predictions, targets


    

# 使用函数进行预测
ensemble_preds, true_targets = ensemble_predict(loaded_models, test_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Ensemble MSE: {mse:.4f}')
print(f'Ensemble R² Score: {r2:.4f}')
# Out:
# Ensemble MSE: 0.1662
# Ensemble R² Score: 0.8381

# %%
ensemble_preds, true_targets = ensemble_predict(loaded_models, train_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Training Ensemble MSE: {mse:.4f}')
print(f'Training Ensemble R² Score: {r2:.4f}')

ensemble_preds, true_targets = ensemble_predict(loaded_models, validate_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Validation Ensemble MSE: {mse:.4f}')
print(f'Validation Ensemble R² Score: {r2:.4f}')

ensemble_preds, true_targets = ensemble_predict(loaded_models, test_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Test Ensemble MSE: {mse:.4f}')
print(f'Test Ensemble R² Score: {r2:.4f}')
# Out:
# Training Ensemble MSE: 0.0724
# Training Ensemble R² Score: 0.9276
# Validation Ensemble MSE: 0.1787
# Validation Ensemble R² Score: 0.8253
# Test Ensemble MSE: 0.1662
# Test Ensemble R² Score: 0.8381

# %%
ensemble_preds, true_targets = ensemble_predict(models, train_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Training Ensemble MSE: {mse:.4f}')
print(f'Training Ensemble R² Score: {r2:.4f}')

ensemble_preds, true_targets = ensemble_predict(models, validate_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Validation Ensemble MSE: {mse:.4f}')
print(f'Validation Ensemble R² Score: {r2:.4f}')

ensemble_preds, true_targets = ensemble_predict(models, test_dataloader, device=device)

# 计算 MSE 和 R² 分数
mse = mean_squared_error(true_targets, ensemble_preds)
r2 = r2_score(true_targets, ensemble_preds)
print(f'Test Ensemble MSE: {mse:.4f}')
print(f'Test Ensemble R² Score: {r2:.4f}')
# Out:
# Training Ensemble MSE: 0.2620
# Training Ensemble R² Score: 0.7380
# Validation Ensemble MSE: 0.2771
# Validation Ensemble R² Score: 0.7291
# Test Ensemble MSE: 0.2660
# Test Ensemble R² Score: 0.7408
